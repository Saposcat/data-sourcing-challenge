# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
# I could not create one that was a .env file, so using .txt instead.
load_dotenv("api_keys.env.txt")

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'
# this filter query still seems not to work for me as it will return stuff that does not have "love" in the title

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = f'{url}api-key={nyt_api_key}&fq={filter_query}&begin_date={begin_date}&end_date={end_date}&fl={field_list}'
reviews = requests.get(query_url).json()
reviews
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'web_url': 'https://www.nytimes.com/2018/01/18/movies/kangaroo-a-love-hate-story-review.html',
#     'snippet': 'The documentary looks at the mass killings of kangaroos for pet-food companies, leather processors and ranchers in Australia.',
#     'source': 'The New York Times',
#     'headline': {'main': 'Review: ‘Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacre',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Kangaroo: A Love-Hate Story',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'creative_works',
#       'value': 'Kangaroo: A Love-Hate Story (Movie)',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Kangaroos', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Animal Abuse, Rights and Welfare',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': 'McIntyre Clere, Kate',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'McIntyre, Mick', 'rank': 5, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Documentary Films and Programs',
#       'rank': 6,
#       'major': 'N'},
#      {'name': 'glocations', 'value': 'Australia', 'rank': 7, 'major': 'N'}],
#     'pub_date': '2018-01-18T12:00:23+0000',
#     'byline': {'original': 'By Ken Jaworowski',
#      'person': [{'firstname': 'Ken',
#        'middlename': None,
#        'lastname': 'Jaworowski',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 263},
#    {'web_url': 'https://www.nytimes.com/2013/09/20/movies/jewtopia-a-comedy-directed-by-bryan-fogel.html',
#     'snippet': 'In “Jewtopia,” a young man asks a childhood friend to help him “act Jewish” so he can romance the girl of his dreams.',
#     'source': 'The New York Times',
#     'headline': {'main': 'Love’s Eternal Masquerade',
#      'kicker': 'Movie Review',
#      'content_kicker': None,
#      'print_headline': 'Jewtopia',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Movies',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Sergei, Ivan', 'rank': 2, 'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'Jewtopia (Movie)',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Fogel, Bryan', 'rank': 4, 'major': 'N'}],
#     'pub_date': '2013-09-19T23:33:15+0000',
#     'byline': {'original': 'By David DeWitt',
#      'person': [{'firstname': 'David',
#        'middlename': None,
#        'lastname': 'DeWitt',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 272},
#    {'web_url': 'https://www.nytimes.com/2019/05/21/movies/the-tomorrow-man-review.html',
#     'snippet': 'Blythe Danner and John Lithgow strain to elevate this twee late-life romance.',
#     'source': 'The New York Times',
#     'headline': {'main': '‘The Tomorrow Man’ Review: Love Among the Neuroses',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'They Whirl, They Twirl, They Tango',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Movies',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'The Tomorrow Man (Movie)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Danner, Blythe', 'rank': 3, 'major': 'N'},
#      {'name': 'persons', 'value': 'Lithgow, John', 'rank': 4, 'major': 'N'},
#      {'name': 'persons', 'value': 'Jones, Noble', 'rank': 5, 'major': 'N'}],
#     'pub_date': '2019-05-21T11:00:01+0000',
#     'byline': {'original': 'By Jeannette Catsoulis',
#      'person': [{'firstname': 'Jeannette',
#        'middlename': None,
#        'lastname': 'Catsoulis',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 280},
#    {'web_url': 'https://www.nytimes.com/2019/11/05/movies/marriage-story-review.html',
#     'snippet': 'Adam Driver and Scarlett Johansson self-consciously uncouple in Noah Baumbach’s tender, stinging tale of divorce.',
#     'source': 'The New York Times',
#     'headline': {'main': '‘Marriage Story’ Review: Dance Me to the End of Love',
#      'kicker': 'critic’s pick',
#      'content_kicker': None,
#      'print_headline': 'Friendly Split, Shattering Break',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Movies',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Baumbach, Noah', 'rank': 2, 'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'Marriage Story (Movie)',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Driver, Adam', 'rank': 4, 'major': 'N'},
#      {'name': 'persons',
#       'value': 'Johansson, Scarlett',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'ALDA, ALAN', 'rank': 6, 'major': 'N'},
#      {'name': 'persons', 'value': 'Dern, Laura', 'rank': 7, 'major': 'N'},
#      {'name': 'persons', 'value': 'Liotta, Ray', 'rank': 8, 'major': 'N'}],
#     'pub_date': '2019-11-05T19:01:02+0000',
#     'byline': {'original': 'By A.O. Scott',
#      'person': [{'firstname': 'A.',
#        'middlename': 'O.',
#        'lastname': 'Scott',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 1244},
#    {'web_url': 'https://www.nytimes.com/2022/11/17/movies/bones-and-all-review.html',
#     'snippet': 'Luca Guadagnino’s latest stars Timothée Chalamet and Taylor Russell as young cannibals on the run.',
#     'source': 'The New York Times',
#     'headline': {'main': '‘Bones and All’ Review: You Eat What You Are',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'It’s Eat, Prey, Love on a Journey of Self-Discovery',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Movies',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'Bones and All (Movie)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Guadagnino, Luca', 'rank': 3, 'major': 'N'},
#      {'name': 'persons',
#       'value': 'Chalamet, Timothee (1995- )',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': 'Russell, Taylor (1994- )',
#       'rank': 5,
#       'major': 'N'}],
#     'pub_date': '2022-11-17T12:00:06+0000',
#     'byline': {'original': 'By A.O. Scott',
#      'person': [{'firstname': 'A.',
#        'middlename': 'O.',
#        'lastname': 'Scott',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 710},
#    {'web_url': 'https://www.nytimes.com/2019/08/08/movies/love-anthosa-review.html',
#     'snippet': 'Anton Yelchin, who played Chekov in the J.J. Abrams-produced “Star Trek” films, assembled an eclectic filmography before his death at 27 in 2016.',
#     'source': 'The New York Times',
#     'headline': {'main': '‘Love, Antosha’ Review: A Heartbreaking Look at an Actor’s Too-Short Life',
#      'kicker': 'Critic’s Pick',
#      'content_kicker': None,
#      'print_headline': 'Love, Antosha',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Documentary Films and Programs',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'Love, Antosha (Movie)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Price, Garret', 'rank': 3, 'major': 'N'},
#      {'name': 'persons', 'value': 'Yelchin, Anton', 'rank': 4, 'major': 'N'}],
#     'pub_date': '2019-08-08T09:00:10+0000',
#     'byline': {'original': 'By Glenn Kenny',
#      'person': [{'firstname': 'Glenn',
#        'middlename': None,
#        'lastname': 'Kenny',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 319},
#    {'web_url': 'https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html',
#     'snippet': 'Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.',
#     'source': 'The New York Times',
#     'headline': {'main': '‘You Can Live Forever’ Review: Do You Love Me Now?',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'You Can Live Forever',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Movies',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'You Can Live Forever (Movie)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Slutsky, Mark', 'rank': 3, 'major': 'N'},
#      {'name': 'persons',
#       'value': 'Watts, Sarah (Film Director)',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': "O'Driscoll, Anwen",
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': 'Laporte, June (Actor)',
#       'rank': 6,
#       'major': 'N'}],
#     'pub_date': '2023-05-04T11:00:08+0000',
#     'byline': {'original': 'By Elisabeth Vincentelli',
#      'person': [{'firstname': 'Elisabeth',
#        'middlename': None,
#        'lastname': 'Vincentelli',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 294},
#    {'web_url': 'https://www.nytimes.com/2015/11/16/movies/review-prem-ratan-dhan-payo-a-bollywood-tale-of-a-prince-and-plebe-double.html',
#     'snippet': 'Sooraj R. Barjatya’s film stars Salman Khan as a decent and playful fellow who intervenes in the power battles of a royal family.',
#     'source': 'The New York Times',
#     'headline': {'main': 'Review: ‘Prem Ratan Dhan Payo,’ a Bollywood Tale of a Prince-and-Plebe Double',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Love and War in a Palace of Mirrors',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Movies',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': 'Barjatya, Sooraj R (1964- )',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Khan, Salman', 'rank': 3, 'major': 'N'},
#      {'name': 'persons', 'value': 'Kapoor, Sonam', 'rank': 4, 'major': 'N'}],
#     'pub_date': '2015-11-15T22:34:57+0000',
#     'byline': {'original': 'By Rachel Saltz',
#      'person': [{'firstname': 'Rachel',
#        'middlename': None,
#        'lastname': 'Saltz',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 363},
#    {'web_url': 'https://www.nytimes.com/2013/10/18/movies/ja-rule-in-im-in-love-with-a-church-girl.html',
#     'snippet': 'The rapper Ja Rule stars as a stylish concert publicist in “I’m in Love With a Church Girl,” written by a pastor who plays a pastor in the film.',
#     'source': 'The New York Times',
#     'headline': {'main': 'A Promoter Finds a New Cause: God',
#      'kicker': 'Movie Review',
#      'content_kicker': None,
#      'print_headline': 'I’m in Love With a Church Girl',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Movies',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Ja Rule', 'rank': 2, 'major': 'N'},
#      {'name': 'creative_works',
#       'value': "I'm in Love with a Church Girl (Movie)",
#       'rank': 3,
#       'major': 'N'}],
#     'pub_date': '2013-10-17T23:05:39+0000',
#     'byline': {'original': 'By Miriam Bale',
#      'person': [{'firstname': 'Miriam',
#        'middlename': None,
#        'lastname': 'Bale',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 271},
#    {'web_url': 'https://www.nytimes.com/2014/02/07/movies/zoe-kazan-plays-disparate-twins-in-the-pretty-one.html',
#     'snippet': '“The Pretty One” stars Zoe Kazan as a pair of twins, one mousy and insecure, the other vivacious. When the popular twin dies in a car accident, her sister decides to assume her identity.',
#     'source': 'The New York Times',
#     'headline': {'main': 'Now They’ll Love Me, a Twin Sister Schemes',
#      'kicker': 'Movie Review',
#      'content_kicker': None,
#      'print_headline': 'Now They’ll Love Me, a Twin Sister Schemes',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Movies',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Kazan, Zoe', 'rank': 2, 'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'The Pretty One (Movie)',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'LeMarque, Jenee', 'rank': 4, 'major': 'N'}],
#     'pub_date': '2014-02-07T00:05:06+0000',
#     'byline': {'original': 'By A.O. Scott',
#      'person': [{'firstname': 'A.',
#        'middlename': 'O.',
#        'lastname': 'Scott',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 369}],
#   'meta': {'hits': 344, 'offset': 0, 'time': 17}}}

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(0,20):
    
    # create query with a page number
    # API results show 10 articles at a time
    query_url = f'{url}api-key={nyt_api_key}&fq={filter_query}&begin_date={begin_date}&end_date={end_date}&fl={field_list}&page={page}'
    #print(page)
    # Make a "GET" request and retrieve the JSON
    reviews = requests.get(query_url).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    completion = ((page)/20) * 100
    print("Retrieval in process. loading:", completion,"%")
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        # loop through the reviews["response"]["docs"] and append each review to the list
        reviews_list.append(reviews["response"]["docs"])
        # Print the page that was just retrieved
        print(reviews)

        # Print the page number that had no results then break from the loop
    except:
        print("ERROR ENCOUNTERED - try increasing time between queries. The page where the error occured was:",page)
        break
print("... done")
# Out:
# Retrieval in process. loading: 0.0 %
# {'status': 'OK', 'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2018/01/18/movies/kangaroo-a-love-hate-story-review.html', 'snippet': 'The documentary looks at the mass killings of kangaroos for pet-food companies, leather processors and ranchers in Australia.', 'source': 'The New York Times', 'headline': {'main': 'Review: ‘Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacre', 'kicker': None, 'content_kicker': None, 'print_headline': 'Kangaroo: A Love-Hate Story', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'creative_works', 'value': 'Kangaroo: A Love-Hate Story (Movie)', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Kangaroos', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Animal Abuse, Rights and Welfare', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'McIntyre Clere, Kate', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'McIntyre, Mick', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 6, 'major': 'N'}, {'name': 'glocations', 'value': 'Australia', 'rank': 7, 'major': 'N'}], 'pub_date': '2018-01-18T12:00:23+0000', 'byline': {'original': 'By Ken Jaworowski', 'person': [{'firstname': 'Ken', 'middlename': None, 'lastname': 'Jaworowski', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 263}, {'web_url': 'https://www.nytimes.com/2013/09/20/movies/jewtopia-a-comedy-directed-by-bryan-fogel.html', 'snippet': 'In “Jewtopia,” a young man asks a childhood friend to help him “act Jewish” so he can romance the girl of his dreams.', 'source': 'The New York Times', 'headline': {'main': 'Love’s Eternal Masquerade', 'kicker': 'Movie Review', 'content_kicker': None, 'print_headline': 'Jewtopia', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Sergei, Ivan', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'Jewtopia (Movie)', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Fogel, Bryan', 'rank': 4, 'major': 'N'}], 'pub_date': '2013-09-19T23:33:15+0000', 'byline': {'original': 'By David DeWitt', 'person': [{'firstname': 'David', 'middlename': None, 'lastname': 'DeWitt', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 272}, {'web_url': 'https://www.nytimes.com/2019/05/21/movies/the-tomorrow-man-review.html', 'snippet': 'Blythe Danner and John Lithgow strain to elevate this twee late-life romance.', 'source': 'The New York Times', 'headline': {'main': '‘The Tomorrow Man’ Review: Love Among the Neuroses', 'kicker': None, 'content_kicker': None, 'print_headline': 'They Whirl, They Twirl, They Tango', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'The Tomorrow Man (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Danner, Blythe', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Lithgow, John', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Jones, Noble', 'rank': 5, 'major': 'N'}], 'pub_date': '2019-05-21T11:00:01+0000', 'byline': {'original': 'By Jeannette Catsoulis', 'person': [{'firstname': 'Jeannette', 'middlename': None, 'lastname': 'Catsoulis', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 280}, {'web_url': 'https://www.nytimes.com/2019/11/05/movies/marriage-story-review.html', 'snippet': 'Adam Driver and Scarlett Johansson self-consciously uncouple in Noah Baumbach’s tender, stinging tale of divorce.', 'source': 'The New York Times', 'headline': {'main': '‘Marriage Story’ Review: Dance Me to the End of Love', 'kicker': 'critic’s pick', 'content_kicker': None,  ...
# Retrieval in process. loading: 5.0 %
# {'status': 'OK', 'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2018/11/01/movies/theyll-love-me-when-im-dead-review-documentary.html', 'snippet': 'Morgan Neville’s movie tells the tumultuous behind-the-scenes story of the making and near-unmaking of “The Other Side of the Wind.”', 'source': 'The New York Times', 'headline': {'main': 'Review: ‘They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Film', 'kicker': None, 'content_kicker': None, 'print_headline': 'The Legend Behind The Scenes', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': "They'll Love Me When I'm Dead (Movie)", 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Neville, Morgan', 'rank': 3, 'major': 'N'}, {'name': 'creative_works', 'value': 'The Other Side of the Wind (Movie)', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Welles, Orson', 'rank': 5, 'major': 'N'}], 'pub_date': '2018-11-01T13:56:39+0000', 'byline': {'original': 'By Manohla Dargis', 'person': [{'firstname': 'Manohla', 'middlename': None, 'lastname': 'Dargis', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 794}, {'web_url': 'https://www.nytimes.com/2021/12/23/movies/a-journal-for-jordan-review.html', 'snippet': 'The actors Michael B. Jordan and Chanté Adams bring a compelling chemistry to the screen as opposites who fall for each other.', 'source': 'The New York Times', 'headline': {'main': '‘A Journal for Jordan’ Review: Reflections on Love Built and Lost', 'kicker': None, 'content_kicker': None, 'print_headline': 'Reflections on Love That’s Built and Lost', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'A Journal for Jordan (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Washington, Denzel', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Jordan, Michael B', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Adams, Chante', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Books and Literature', 'rank': 6, 'major': 'N'}, {'name': 'creative_works', 'value': 'A Journal for Jordan: A Story of Love and Honor (Book)', 'rank': 7, 'major': 'N'}, {'name': 'persons', 'value': 'Canedy, Dana', 'rank': 8, 'major': 'N'}, {'name': 'subject', 'value': 'Black People', 'rank': 9, 'major': 'N'}, {'name': 'subject', 'value': 'Blacks', 'rank': 10, 'major': 'N'}], 'pub_date': '2021-12-23T18:54:12+0000', 'byline': {'original': 'By Lisa Kennedy', 'person': [{'firstname': 'Lisa', 'middlename': None, 'lastname': 'Kennedy', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 505}, {'web_url': 'https://www.nytimes.com/2017/02/09/movies/review-a-united-kingdom-with-love-that-tested-racial-tolerance.html', 'snippet': 'This romance illustrates the struggle for African independence from colonialism, under the shadow of apartheid.', 'source': 'The New York Times', 'headline': {'main': 'Review: ‘A United Kingdom’ With Love That Tested Racial Tolerance', 'kicker': None, 'content_kicker': None, 'print_headline': 'Not Your Typical Fairy-Tale Romance', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'A United Kingdom (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Oyelowo, David', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Pike, Rosamund', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Asante, Amma', 'rank': 5, 'major': 'N'}], 'pub_date': '2017-02-09T10:00:16+0000', 'byline': {'original': 'By Glenn Kenny', 'person': [{'firstname': 'Glenn', 'middlename': ...
# Retrieval in process. loading: 10.0 %
# {'status': 'OK', 'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2016/06/24/movies/from-this-day-forward-review.html', 'snippet': 'Sharon Shattuck’s documentary tells her family story of growing up with a transgender parent.', 'source': 'The New York Times', 'headline': {'main': 'Review: ‘From This Day Forward’ Attests to Love’s Adaptability', 'kicker': None, 'content_kicker': None, 'print_headline': 'Review: ‘From This Day Forward’ Attests to Love’s Adaptability', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Shattuck, Sharon', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Transgender and Transsexuals', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Movies', 'rank': 5, 'major': 'N'}], 'pub_date': '2016-06-23T21:11:31+0000', 'byline': {'original': 'By Andy Webster', 'person': [{'firstname': 'Andy', 'middlename': None, 'lastname': 'Webster', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 252}, {'web_url': 'https://www.nytimes.com/2016/07/15/movies/how-he-fell-in-love-review.html', 'snippet': 'This Marc Meyers film focuses on how the relationship between a young musician and a middle-age woman affects them and others in their orbit.', 'source': 'The New York Times', 'headline': {'main': 'Review: In ‘How He Fell in Love,’ an Extramarital Bond Unfolds', 'kicker': None, 'content_kicker': None, 'print_headline': None, 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Meyers, Marc (Director)', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'How He Fell in Love (Movie)', 'rank': 3, 'major': 'N'}], 'pub_date': '2016-07-14T21:15:47+0000', 'byline': {'original': 'By Helen T. Verongos', 'person': [{'firstname': 'Helen', 'middlename': 'T.', 'lastname': 'Verongos', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 273}, {'web_url': 'https://www.nytimes.com/2013/11/08/movies/how-i-live-now-a-dystopian-drama-starring-saoirse-ronan.html', 'snippet': 'In “How I Live Now,” based on the novel by Meg Rosoff, a surly American teenager finds herself caught in World War III in Britain.', 'source': 'The New York Times', 'headline': {'main': 'Young Love, Interrupted by a Nuclear Bomb', 'kicker': 'Movie Review', 'content_kicker': None, 'print_headline': 'How I Live Now', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Ronan, Saoirse', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'How I Live Now (Movie)', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Macdonald, Kevin', 'rank': 4, 'major': 'N'}], 'pub_date': '2013-11-08T00:59:34+0000', 'byline': {'original': 'By Jeannette Catsoulis', 'person': [{'firstname': 'Jeannette', 'middlename': None, 'lastname': 'Catsoulis', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 264}, {'web_url': 'https://www.nytimes.com/2015/11/13/movies/review-in-love-the-coopers-a-dysfunctional-family-sits-down-to-christmas-dinner.html', 'snippet': 'Diane Keaton and John Goodman play a long-married couple who have big news to deliver to the family once it gathers, in Jessie Nelson’s film.', 'source': 'The New York Times', 'headline': {'main': 'Review: In ‘Love the Coopers,’ a Dysfunctional Family Sits Down to Christmas Dinner', 'kicker': None, 'content_kicker': None, 'print_headline': 'Review: In ‘Love the Coopers,’ a Dysfunctional Family Sits Down to Christmas Dinner', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subjec ...
# Retrieval in process. loading: 15.0 %
# {'status': 'OK', 'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2021/10/14/movies/hard-luck-love-song-review.html', 'snippet': 'Drawn from the plotline of a Todd Snider song, the film follows a pool shark and an escort, taking twists that are both violent and silly.', 'source': 'The New York Times', 'headline': {'main': '‘Hard Luck Love Song’ Review: A Glossy Take on a Gritty Tune', 'kicker': None, 'content_kicker': None, 'print_headline': 'Hard Luck Love Song', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Dorman, Michael (1981- )', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'Hard Luck Love Song (Movie)', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Bush, Sophia (1982- )', 'rank': 4, 'major': 'N'}], 'pub_date': '2021-10-14T12:27:03+0000', 'byline': {'original': 'By Glenn Kenny', 'person': [{'firstname': 'Glenn', 'middlename': None, 'lastname': 'Kenny', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 320}, {'web_url': 'https://www.nytimes.com/2022/04/18/movies/see-you-then-review.html', 'snippet': 'Former lovers reconnect, litigating the past and present, in this drama from Mari Walker.', 'source': 'The New York Times', 'headline': {'main': '‘See You Then’ Review: The More Things Stay the Same', 'kicker': None, 'content_kicker': None, 'print_headline': 'The Persistent Melancholy of Love', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'See You Then (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Walker, Mari', 'rank': 3, 'major': 'N'}], 'pub_date': '2022-04-18T11:00:03+0000', 'byline': {'original': 'By Kyle Turner', 'person': [{'firstname': 'Kyle', 'middlename': None, 'lastname': 'Turner', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 300}, {'web_url': 'https://www.nytimes.com/2019/04/19/movies/kalank-review.html', 'snippet': 'Abhishek Varman’s maximalist melodrama delivers spectacle (some of it mind-numbing) but fails to tell a gripping story.', 'source': 'The New York Times', 'headline': {'main': '‘Kalank’ Review: A Bollywood Love Story in the Shadow of Partition', 'kicker': None, 'content_kicker': None, 'print_headline': 'An Extravagant Spectacle', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'Kalank (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Varman, Abhishek', 'rank': 3, 'major': 'N'}], 'pub_date': '2019-04-19T15:38:08+0000', 'byline': {'original': 'By Rachel Saltz', 'person': [{'firstname': 'Rachel', 'middlename': None, 'lastname': 'Saltz', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 479}, {'web_url': 'https://www.nytimes.com/2015/08/28/movies/review-in-z-for-zachariah-an-end-of-days-love-triangle.html', 'snippet': 'Margot Robbie stars in Craig Zobel’s post-apocalyptic film about three survivors of the nuclear holocaust caught in a triangle.', 'source': 'The New York Times', 'headline': {'main': 'Review: In ‘Z for Zachariah,’ an End-of-Days Love Triangle', 'kicker': None, 'content_kicker': None, 'print_headline': 'When a Woman Finds 2 Friends for the End of the World', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Zobel, R Craig', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Robbie, Margot', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Ejiofor, Chiwetel', 'rank': 4, 'major': 'N'}, {'name': ' ...
# Retrieval in process. loading: 20.0 %
# {'status': 'OK', 'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2019/08/29/movies/falling-inn-love-review.html', 'snippet': 'It’s hard to find a reliable, talented, reasonably priced, eco-friendly contractor these days.', 'source': 'The New York Times', 'headline': {'main': '‘Falling Inn Love’ Review: A Prize That Needs Some Work', 'kicker': 'Streaming Movie Review', 'content_kicker': None, 'print_headline': 'A Fine Romance to Watch While Sorting Socks', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'organizations', 'value': 'Netflix Inc', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Kumble, Roger', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Milian, Christina', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Demos, Adam', 'rank': 5, 'major': 'N'}, {'name': 'creative_works', 'value': 'Falling Inn Love (Movie)', 'rank': 6, 'major': 'N'}], 'pub_date': '2019-08-29T14:56:44+0000', 'byline': {'original': 'By Helen T. Verongos', 'person': [{'firstname': 'Helen', 'middlename': 'T.', 'lastname': 'Verongos', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 374}, {'web_url': 'https://www.nytimes.com/2015/11/27/movies/review-in-tamasha-finding-a-path-to-love-show-business-and-adulation.html', 'snippet': 'A Bollywood melodrama about a boy, a girl, storytelling and make-believe.', 'source': 'The New York Times', 'headline': {'main': 'Review: In ‘Tamasha,’ Finding a Path to Love, Show Business and Adulation', 'kicker': None, 'content_kicker': None, 'print_headline': 'Review: In ‘Tamasha,’ Finding a Path to Love, Show Business and Adulation', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Ali, Imtiaz', 'rank': 2, 'major': 'N'}], 'pub_date': '2015-11-26T21:37:30+0000', 'byline': {'original': 'By Andy Webster', 'person': [{'firstname': 'Andy', 'middlename': None, 'lastname': 'Webster', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 260}, {'web_url': 'https://www.nytimes.com/2019/05/15/movies/the-sun-is-also-a-star-review.html', 'snippet': 'Yara Shahidi and Charles Melton play teenagers falling in love on a hectic, sunny day in New York.', 'source': 'The New York Times', 'headline': {'main': '‘The Sun Is Also a Star’ Review: A Charming, if Generic, Adolescent Love Story', 'kicker': None, 'content_kicker': None, 'print_headline': 'A Beautiful Day for Young Hearts', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'The Sun Is also a Star (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Russo-Young, Ry', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Shahidi, Yara (2000- )', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Yoon, Nicola (Author)', 'rank': 5, 'major': 'N'}, {'name': 'persons', 'value': 'Melton, Charles (1991- )', 'rank': 6, 'major': 'N'}], 'pub_date': '2019-05-15T16:01:27+0000', 'byline': {'original': 'By A.O. Scott', 'person': [{'firstname': 'A.', 'middlename': 'O.', 'lastname': 'Scott', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 697}, {'web_url': 'https://www.nytimes.com/2015/05/01/movies/review-in-cathedrals-of-culture-buildings-to-love.html', 'snippet': 'A two-part program of short films by directors including Wim Wenders and Robert Redford tours structures that transcend mere architectural concerns.', 'source': 'The New York Times', 'headline': {'main': 'Review: In ‘Cathedrals of Culture,’ Buildings to Love', 'kicker': None, 'content_kicker': None, 'print_he ...
# Retrieval in process. loading: 25.0 %
# {'status': 'OK', 'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2019/10/17/movies/cyrano-my-love-review.html', 'snippet': 'This superficial take on the writing and initial staging of “Cyrano de Bergerac” is a whirlwind of soapy declarations and backstage chaos.', 'source': 'The New York Times', 'headline': {'main': '‘Cyrano, My Love’ Review: A Nose for Romance', 'kicker': None, 'content_kicker': None, 'print_headline': 'Cyrano, My Love', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'Cyrano, My Love (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Michalik, Alexis', 'rank': 3, 'major': 'N'}], 'pub_date': '2019-10-17T11:00:03+0000', 'byline': {'original': 'By Jeannette Catsoulis', 'person': [{'firstname': 'Jeannette', 'middlename': None, 'lastname': 'Catsoulis', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 291}, {'web_url': 'https://www.nytimes.com/2018/09/20/movies/quincy-review-quincy-jones.html', 'snippet': 'A documentary reveals its octogenarian subject as still busy and productive, and not a little haunted by memories of friends now gone.', 'source': 'The New York Times', 'headline': {'main': 'Review: ‘Quincy’ Captures a Lifelong Love Affair With Music', 'kicker': None, 'content_kicker': None, 'print_headline': 'The Man Behind the Music', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'creative_works', 'value': 'Quincy (Movie)', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Jones, Quincy', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Jones, Rashida', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Hicks, Alan', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Music', 'rank': 6, 'major': 'N'}, {'name': 'organizations', 'value': 'Netflix Inc', 'rank': 7, 'major': 'N'}], 'pub_date': '2018-09-20T14:00:01+0000', 'byline': {'original': 'By Glenn Kenny', 'person': [{'firstname': 'Glenn', 'middlename': None, 'lastname': 'Kenny', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 460}, {'web_url': 'https://www.nytimes.com/2021/09/16/movies/wife-of-a-spy-review-trust-or-fear-in-love-and-war.html', 'snippet': 'In this latest work by Kiyoshi Kurosawa, a Japanese couple’s relationship is shaped by the forces of churning nationalism that surround it.', 'source': 'The New York Times', 'headline': {'main': '‘Wife of a Spy’ Review: Trust or Fear in Love and War?', 'kicker': 'Critic’s Pick', 'content_kicker': None, 'print_headline': 'Marriage Amid Nationalism', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Kurosawa, Kiyoshi', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'Wife of a Spy (Movie)', 'rank': 3, 'major': 'N'}], 'pub_date': '2021-09-16T11:00:07+0000', 'byline': {'original': 'By Glenn Kenny', 'person': [{'firstname': 'Glenn', 'middlename': None, 'lastname': 'Kenny', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 448}, {'web_url': 'https://www.nytimes.com/2017/10/05/movies/the-mountain-between-us-review-kate-winslet-idris-elba.html', 'snippet': 'Idris Elba and Kate Winslet crash into a mountain — and each other — in this drama.', 'source': 'The New York Times', 'headline': {'main': 'Review: Love in a Cold Climate in ‘The Mountain Between Us’', 'kicker': None, 'content_kicker': None, 'print_headline': 'The Mountain Between Us', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major ...
# Retrieval in process. loading: 30.0 %
# {'status': 'OK', 'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2013/11/22/movies/detroit-unleaded-a-low-octane-comedy.html', 'snippet': 'A gas station looms large in “Detroit Unleaded,” a soft-spoken Arab-American romantic comedy.', 'source': 'The New York Times', 'headline': {'main': 'Love Among the Gas Pumps', 'kicker': 'Movie Review', 'content_kicker': None, 'print_headline': 'Detroit Unleaded', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'Detroit Unleaded (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Nashef, Rola', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Shouhayib, Nada', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Assi, E J', 'rank': 5, 'major': 'N'}], 'pub_date': '2013-11-21T23:52:02+0000', 'byline': {'original': 'By Neil Genzlinger', 'person': [{'firstname': 'Neil', 'middlename': None, 'lastname': 'Genzlinger', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 237}, {'web_url': 'https://www.nytimes.com/2014/06/09/movies/holiday-follows-a-soldier-on-home-leave-in-mumbai.html', 'snippet': 'In remake of 2012 Tamil hit, Akshay Kumar stars as a captain on home leave in “Holiday.”', 'source': 'The New York Times', 'headline': {'main': 'A Paragon of Honor, With a Little Time Off for Love', 'kicker': 'Movie Review', 'content_kicker': None, 'print_headline': 'A Paragon of Honor, With a Little Time Off for Love', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Kumar, Akshay', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Murugadoss, A R', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Sinha, Sonakshi', 'rank': 5, 'major': 'N'}], 'pub_date': '2014-06-08T21:55:43+0000', 'byline': {'original': 'By Rachel Saltz', 'person': [{'firstname': 'Rachel', 'middlename': None, 'lastname': 'Saltz', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 355}, {'web_url': 'https://www.nytimes.com/2017/11/09/movies/review-in-thelma-a-woman-in-love-can-burn-down-the-world.html', 'snippet': 'In Joachim Trier’s sly psychological thriller “Thelma,” a child-woman finds love and discovers that behaving like a good girl can be a very bad idea.', 'source': 'The New York Times', 'headline': {'main': 'Review: In ‘Thelma,’ a Woman in Love Can Burn Down the World', 'kicker': None, 'content_kicker': None, 'print_headline': 'A Woman in Love Can Burn Down the World', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'Thelma (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Trier, Joachim', 'rank': 3, 'major': 'N'}], 'pub_date': '2017-11-09T20:08:31+0000', 'byline': {'original': 'By Manohla Dargis', 'person': [{'firstname': 'Manohla', 'middlename': None, 'lastname': 'Dargis', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 757}, {'web_url': 'https://www.nytimes.com/2016/05/20/movies/-almost-holy-review.html', 'snippet': 'This documentary by Steve Hoover examines Gennadiy Mokhnenko, a pastor in Ukraine who rehabilitates homeless children at his center, Pilgrim Republic.', 'source': 'The New York Times', 'headline': {'main': 'Review: ‘Almost Holy’ Demonstrates a Pastor’s Tough Love for Street Kids in Ukraine', 'kicker': None, 'content_kicker': None, 'print_headline': 'Review: ‘Almost Holy’ Demonstrates a Pastor’s Tough Love for Street Kids in Ukraine', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': ...
# Retrieval in process. loading: 35.0 %
# {'status': 'OK', 'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2019/03/14/movies/five-feet-apart-review.html', 'snippet': 'Haley Lu Richardson and Cole Sprouse navigate the rules of attraction and of a hospital in this film about living with cystic fibrosis.', 'source': 'The New York Times', 'headline': {'main': '‘Five Feet Apart’ Review: Ailing Teenagers Live Dangerously for Love', 'kicker': None, 'content_kicker': None, 'print_headline': 'Five Feet Apart', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'Five Feet Apart (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Baldoni, Justin', 'rank': 3, 'major': 'N'}], 'pub_date': '2019-03-14T13:00:07+0000', 'byline': {'original': 'By Ben Kenigsberg', 'person': [{'firstname': 'Ben', 'middlename': None, 'lastname': 'Kenigsberg', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 258}, {'web_url': 'https://www.nytimes.com/2016/08/19/movies/kampai-for-the-love-of-sake-review.html', 'snippet': 'Mirai Konishi’s light documentary focuses on brewery experts and others who have devoted their lives to this complex rice-based beverage.', 'source': 'The New York Times', 'headline': {'main': 'Review: ‘Kampai! For the Love of Sake’ Celebrates Japan’s Best-Known Libation', 'kicker': None, 'content_kicker': None, 'print_headline': None, 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Konishi, Mirai (1971- )', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Sake', 'rank': 4, 'major': 'N'}, {'name': 'glocations', 'value': 'Japan', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Movies', 'rank': 6, 'major': 'N'}], 'pub_date': '2016-08-18T20:30:32+0000', 'byline': {'original': 'By Andy Webster', 'person': [{'firstname': 'Andy', 'middlename': None, 'lastname': 'Webster', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 263}, {'web_url': 'https://www.nytimes.com/2021/02/04/movies/two-of-us-review-thwarted-love.html', 'snippet': 'An older lesbian couple is met with unexpected devastation in this aching romantic drama by Filippo Meneghetti.', 'source': 'The New York Times', 'headline': {'main': '‘Two of Us’ Review: Thwarted Love', 'kicker': None, 'content_kicker': None, 'print_headline': 'Two of Us', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Sukowa, Barbara', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'Two of Us (Movie)', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Meneghetti, Filippo', 'rank': 4, 'major': 'N'}], 'pub_date': '2021-02-04T12:00:03+0000', 'byline': {'original': 'By Beatrice Loayza', 'person': [{'firstname': 'Beatrice', 'middlename': None, 'lastname': 'Loayza', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 313}, {'web_url': 'https://www.nytimes.com/2013/04/05/movies/upstream-color-directed-by-shane-carruth.html', 'snippet': 'In “Upstream Color,” a man and a woman find each other as part of a plot where little is straightforward.', 'source': 'The New York Times', 'headline': {'main': 'Worms, a Botanist and Pigs. Sounds Like a Love Story.', 'kicker': 'Movie Review', 'content_kicker': None, 'print_headline': 'Worms, a Botanist And Pigs. Sounds Like a Love Story.', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'persons', 'value': 'Carruth, Shane', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Movies', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': ' ...
# Retrieval in process. loading: 40.0 %
# {'status': 'OK', 'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2022/08/04/movies/i-love-my-dad-review.html', 'snippet': 'This comedy is a daddy-issues movie with a queasy premise truly made for these times.', 'source': 'The New York Times', 'headline': {'main': '‘I Love My Dad’ Review: A Father Catfishes His Son', 'kicker': None, 'content_kicker': None, 'print_headline': 'A Father Catfishes His Son. We Just Wait for the Ick.', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Oswalt, Patton', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'I Love My Dad (Movie)', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Morosini, James', 'rank': 4, 'major': 'N'}], 'pub_date': '2022-08-04T11:00:05+0000', 'byline': {'original': 'By Glenn Kenny', 'person': [{'firstname': 'Glenn', 'middlename': None, 'lastname': 'Kenny', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 418}, {'web_url': 'https://www.nytimes.com/2016/05/20/movies/maggies-plan-review-greta-gerwig.html', 'snippet': 'This film, the fifth from Rebecca Miller, stars Ms. Gerwig as a millennial who, on the way to finding a sperm donor, falls for a part-time professor.', 'source': 'The New York Times', 'headline': {'main': 'Review: In ‘Maggie’s Plan,’ Greta Gerwig Aspires to Motherhood on Her Terms', 'kicker': None, 'content_kicker': None, 'print_headline': 'Wanting a Child but Finding Love', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Miller, Rebecca', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Gerwig, Greta', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Hawke, Ethan', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Fimmel, Travis', 'rank': 5, 'major': 'N'}, {'name': 'persons', 'value': 'Moore, Julianne', 'rank': 6, 'major': 'N'}, {'name': 'creative_works', 'value': "Maggie's Plan (Movie)", 'rank': 7, 'major': 'N'}], 'pub_date': '2016-05-19T21:57:55+0000', 'byline': {'original': 'By A.O. Scott', 'person': [{'firstname': 'A.', 'middlename': 'O.', 'lastname': 'Scott', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 959}, {'web_url': 'https://www.nytimes.com/2020/02/12/movies/ordinary-love-review.html', 'snippet': 'Lesley Manville and Liam Neeson play a married couple facing a cancer diagnosis.', 'source': 'The New York Times', 'headline': {'main': '‘Ordinary Love’ Review: In Sickness and in Health', 'kicker': None, 'content_kicker': None, 'print_headline': 'Old-Sweater Lives', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'Ordinary Love (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Neeson, Liam', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Manville, Lesley', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': "D'Sa, Lisa Barros", 'rank': 5, 'major': 'N'}, {'name': 'persons', 'value': 'Leyburn, Glenn', 'rank': 6, 'major': 'N'}], 'pub_date': '2020-02-12T19:46:45+0000', 'byline': {'original': 'By A.O. Scott', 'person': [{'firstname': 'A.', 'middlename': 'O.', 'lastname': 'Scott', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 569}, {'web_url': 'https://www.nytimes.com/2013/11/14/movies/adrian-manzanos-sex-love-salsa.html', 'snippet': 'A dancer juggles a busy love life in “Sex, Love & Salsa.”', 'source': 'The New York Times', 'headline': {'main': 'A Dancer Tries Out Many Moves', 'kicker': 'Movie Review', 'content_kicker': None, 'print_headline': 'Sex, Love & Salsa', 'name': ...
# Retrieval in process. loading: 45.0 %
# {'status': 'OK', 'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2019/05/16/movies/asako-i-and-ii-review.html', 'snippet': 'The Japanese director Ryusuke Hamaguchi follows up his marathon “Happy Hour” with a story of love among young urbanites.', 'source': 'The New York Times', 'headline': {'main': '‘Asako I & II’ Review: Double the Love (and the Heartbreak)', 'kicker': 'Critic’s Pick', 'content_kicker': None, 'print_headline': 'Falling For a Drifter And His Lookalike', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'Asako I & II (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Hamaguchi, Ryusuke', 'rank': 3, 'major': 'N'}], 'pub_date': '2019-05-16T11:00:01+0000', 'byline': {'original': 'By Glenn Kenny', 'person': [{'firstname': 'Glenn', 'middlename': None, 'lastname': 'Kenny', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 547}, {'web_url': 'https://www.nytimes.com/2013/03/01/movies/here-i-learned-to-love-holocaust-documentary-by-avi-angel.html', 'snippet': 'Two brothers in their 70s tap memories to retrace their Holocaust childhoods in “Here I Learned to Love,” directed by Avi Angel.', 'source': 'The New York Times', 'headline': {'main': 'Brothers Retrace Their Holocaust Childhoods', 'kicker': 'Movie Review', 'content_kicker': None, 'print_headline': 'Here I Learned to Love', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Angel, Avi', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 5, 'major': 'N'}], 'pub_date': '2013-03-01T00:44:19+0000', 'byline': {'original': 'By Daniel M. Gold', 'person': [{'firstname': 'Daniel', 'middlename': None, 'lastname': None, 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 280}, {'web_url': 'https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html', 'snippet': 'A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.', 'source': 'The New York Times', 'headline': {'main': '‘The Attachment Diaries’ Review: Love, Sick', 'kicker': None, 'content_kicker': None, 'print_headline': 'The Attachment Diaries', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'The Attachment Diaries (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Diment, Valentin Javier', 'rank': 3, 'major': 'N'}], 'pub_date': '2023-05-25T11:00:03+0000', 'byline': {'original': 'By Jeannette Catsoulis', 'person': [{'firstname': 'Jeannette', 'middlename': None, 'lastname': 'Catsoulis', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 295}, {'web_url': 'https://www.nytimes.com/2015/01/09/movies/beloved-sisters-directed-by-dominik-graf.html', 'snippet': '“Beloved Sisters” imagines a fraught ménage à trois among the German poet and dramatist Friedrich Schiller and the sisters Charlotte von Lengefeld and Caroline von Lengefeld.', 'source': 'The New York Times', 'headline': {'main': 'A Literary Triumvirate of Love and Lust', 'kicker': 'Movie Review', 'content_kicker': None, 'print_headline': 'A Literary Triumvirate of Love and Lust', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Graf, Dominik', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Herzsprung, Hannah', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Stetter, Florian', 'rank': 4, 'major':  ...
# Retrieval in process. loading: 50.0 %
# {'status': 'OK', 'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2020/11/12/movies/ammonite-review.html', 'snippet': 'Kate Winslet’s fossil hunter and Saoirse Ronan’s convalescent embark on a forbidden seaside romance.', 'source': 'The New York Times', 'headline': {'main': '‘Ammonite’ Review: Love on the Rocks', 'kicker': 'Critic’s Pick', 'content_kicker': None, 'print_headline': 'Love on the Rocks', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Ronan, Saoirse', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Winslet, Kate', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Lee, Francis (1969- )', 'rank': 4, 'major': 'N'}, {'name': 'creative_works', 'value': 'Ammonite (Movie)', 'rank': 5, 'major': 'N'}], 'pub_date': '2020-11-12T12:00:04+0000', 'byline': {'original': 'By Jeannette Catsoulis', 'person': [{'firstname': 'Jeannette', 'middlename': None, 'lastname': 'Catsoulis', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 510}, {'web_url': 'https://www.nytimes.com/2021/08/05/movies/annette-review.html', 'snippet': 'Adam Driver and Marion Cotillard are star-crossed lovers in this hallucinatory musical, written by Sparks and directed by Leos Carax.', 'source': 'The New York Times', 'headline': {'main': '‘Annette’ Review: Love Hurts', 'kicker': 'Critic’s Pick', 'content_kicker': None, 'print_headline': 'A Star Is Born. You Won’t Like Him.', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Carax, Leos', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Cotillard, Marion', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Driver, Adam', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Mael, Ron', 'rank': 5, 'major': 'N'}, {'name': 'persons', 'value': 'Mael, Russell', 'rank': 6, 'major': 'N'}, {'name': 'creative_works', 'value': 'Annette (Movie)', 'rank': 7, 'major': 'N'}, {'name': 'organizations', 'value': 'Sparks (Music Group)', 'rank': 8, 'major': 'N'}], 'pub_date': '2021-08-05T11:00:07+0000', 'byline': {'original': 'By A.O. Scott', 'person': [{'firstname': 'A.', 'middlename': 'O.', 'lastname': 'Scott', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 1069}, {'web_url': 'https://www.nytimes.com/2022/07/21/movies/alone-together-review.html', 'snippet': 'Katie Holmes writes, directs and stars in this minor-key rom-com set in 2020.', 'source': 'The New York Times', 'headline': {'main': '‘Alone Together’ Review: Finding Love in a Pandemic Retreat', 'kicker': None, 'content_kicker': None, 'print_headline': 'Alone Together', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Holmes, Katie', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'Alone Together (Movie)', 'rank': 3, 'major': 'N'}], 'pub_date': '2022-07-21T15:37:18+0000', 'byline': {'original': 'By Teo Bugbee', 'person': [{'firstname': 'Teo', 'middlename': None, 'lastname': 'Bugbee', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 254}, {'web_url': 'https://www.nytimes.com/2016/03/11/movies/city-of-gold-review.html', 'snippet': 'Laura Gabbert’s documentary follows the food critic Jonathan Gold in his pursuit of excellence, which can lead to a taco truck or a high-end restaurant.', 'source': 'The New York Times', 'headline': {'main': 'Review: Tastes of Los Angeles in ‘City of Gold’', 'kicker': None, 'content_kicker': None, 'print_headline': 'He Loves L.A., Especially Its Food Scene', 'name': None, 'seo': None, 'sub': None},  ...
# Retrieval in process. loading: 55.00000000000001 %
# ...
# Retrieval in process. loading: 85.0 %
# {'status': 'OK', 'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2015/03/13/movies/review-in-eva-robot-designer-loves-cute-kid.html', 'snippet': 'In Kike Maíllo’s Spanish drama, a prodigy returns to his hometown to work on programming an android with the emotional life of a real child.', 'source': 'The New York Times', 'headline': {'main': 'Review: In ‘Eva,’ Robot Designer Loves Cute Kid', 'kicker': None, 'content_kicker': None, 'print_headline': 'In ‘Eva,’ Robot Designer Loves Cute Kid', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Maillo, Kike', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'Eva (Movie)', 'rank': 3, 'major': 'N'}], 'pub_date': '2015-03-13T02:39:35+0000', 'byline': {'original': 'By Neil Genzlinger', 'person': [{'firstname': 'Neil', 'middlename': None, 'lastname': 'Genzlinger', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 216}, {'web_url': 'https://www.nytimes.com/2014/03/21/movies/in-it-felt-like-love-a-teenager-flirts-with-danger.html', 'snippet': '“It Felt Like Love” considers the dangers of teenage desire through the experiences of a coltish 14-year-old girl who randomly fixes on a weed-smoking tough guy.', 'source': 'The New York Times', 'headline': {'main': 'Pursuing Sex With a Bad Boy', 'kicker': 'Movie Review', 'content_kicker': None, 'print_headline': 'It Felt Like Love', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'It Felt Like Love (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Hittman, Eliza', 'rank': 3, 'major': 'N'}], 'pub_date': '2014-03-20T20:53:46+0000', 'byline': {'original': 'By Jeannette Catsoulis', 'person': [{'firstname': 'Jeannette', 'middlename': None, 'lastname': 'Catsoulis', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 260}, {'web_url': 'https://www.nytimes.com/2022/02/03/movies/lingui-the-sacred-bonds-review.html', 'snippet': 'In this electric liberation story from Chad, a mother struggles to protect her daughter’s future and finds both herself and a world of possibility.', 'source': 'The New York Times', 'headline': {'main': '‘Lingui, the Sacred Bonds’ Review: Love, Ferocious and Limitless', 'kicker': 'Critic’s Pick', 'content_kicker': None, 'print_headline': 'Love, Ferocious and Limitless', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Haroun, Mahamat-Saleh', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'Lingui, the Sacred Bonds (Movie)', 'rank': 3, 'major': 'N'}], 'pub_date': '2022-02-03T19:21:56+0000', 'byline': {'original': 'By Manohla Dargis', 'person': [{'firstname': 'Manohla', 'middlename': None, 'lastname': 'Dargis', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 852}, {'web_url': 'https://www.nytimes.com/2014/05/23/movies/the-love-punch-stars-pierce-brosnan-and-emma-thompson.html', 'snippet': 'In the comedy “The Love Punch,” a couple worried about their nest egg decide to steal a diamond.', 'source': 'The New York Times', 'headline': {'main': 'Anything to Save Their Pensions', 'kicker': 'Movie Review', 'content_kicker': None, 'print_headline': 'The Love Punch', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'The Love Punch (Movie)', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Brosnan, Pierce', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Thompson, Emma', 'ran ...
# Retrieval in process. loading: 90.0 %
# {'status': 'OK', 'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2019/02/14/movies/a-tuba-to-cuba-review.html', 'snippet': 'This joyous documentary follows the Preservation Hall Jazz Band to Cuba for a celebration of musical history and common bonds.', 'source': 'The New York Times', 'headline': {'main': '‘A Tuba to Cuba’ Review: A New Orleans Jazz Band Makes a Caribbean Connection', 'kicker': 'Critic’s Pick', 'content_kicker': None, 'print_headline': 'Love Notes Forge a Caribbean Bond', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'A Tuba to Cuba (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Herrington, TG', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Clinch, Danny', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Jazz', 'rank': 5, 'major': 'N'}, {'name': 'organizations', 'value': 'Preservation Hall Jazz Band', 'rank': 6, 'major': 'N'}], 'pub_date': '2019-02-14T12:00:01+0000', 'byline': {'original': 'By Jeannette Catsoulis', 'person': [{'firstname': 'Jeannette', 'middlename': None, 'lastname': 'Catsoulis', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 267}, {'web_url': 'https://www.nytimes.com/2017/08/24/movies/tales-of-an-immoral-couple-review.html', 'snippet': 'Twenty-five years after they split, two former high school sweethearts reluctantly reunite for an awkward night.', 'source': 'The New York Times', 'headline': {'main': 'Review: ‘Tales of an Immoral Couple’: Love Means Having to Grow Up', 'kicker': None, 'content_kicker': None, 'print_headline': 'Tales of an Immoral Couple', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'Tales of an Immoral Couple (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Caro, Manolo', 'rank': 3, 'major': 'N'}], 'pub_date': '2017-08-24T16:22:43+0000', 'byline': {'original': 'By Monica Castillo', 'person': [{'firstname': 'Monica', 'middlename': None, 'lastname': 'Castillo', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 284}, {'web_url': 'https://www.nytimes.com/2020/01/09/movies/the-woman-who-loves-giraffes-review.html', 'snippet': 'This warm documentary uses one woman’s singular passion to fuel a tale of zoological discovery, blatant sexism and environmental alarm.', 'source': 'The New York Times', 'headline': {'main': '‘The Woman Who Loves Giraffes’ Review: Crackers for Animals', 'kicker': None, 'content_kicker': None, 'print_headline': 'A Special Spot  In Her Heart', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Giraffes', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'The Woman Who Loves Giraffes (Movie)', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Dagg, Anne Innis', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Reid, Alison (Filmmaker)', 'rank': 5, 'major': 'N'}], 'pub_date': '2020-01-09T12:00:04+0000', 'byline': {'original': 'By Jeannette Catsoulis', 'person': [{'firstname': 'Jeannette', 'middlename': None, 'lastname': 'Catsoulis', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 279}, {'web_url': 'https://www.nytimes.com/2016/02/12/movies/review-fitoor-enlists-dickens-to-tell-a-hindi-love-story.html', 'snippet': 'Based on “Great Expectations,” the film, directed by Abhishek Kapoor, is more Bollywood than Charles Dickens.', 'source': 'The New York Times', 'headline': {'main': 'Review: ‘Fitoor’ Enlists Dickens to ...
# Retrieval in process. loading: 95.0 %
# {'status': 'OK', 'copyright': 'Copyright (c) 2023 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://www.nytimes.com/2013/06/14/movies/the-stroller-strategy-a-french-comedy.html', 'snippet': 'A Paris illustrator tries to win back his ex-girlfriend through unorthodox means in “The Stroller Strategy,” directed by Clément Michel.', 'source': 'The New York Times', 'headline': {'main': 'Solution to His Love Problems?: Baby Formula', 'kicker': 'Movie Review', 'content_kicker': None, 'print_headline': 'The Stroller Strategy', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Michel, Clement', 'rank': 4, 'major': 'N'}], 'pub_date': '2013-06-14T02:20:57+0000', 'byline': {'original': 'By Nicolas Rapold', 'person': [{'firstname': 'Nicolas', 'middlename': None, 'lastname': 'Rapold', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 223}, {'web_url': 'https://www.nytimes.com/2021/07/14/movies/casanova-last-love-review-reappraising-a-philanderer.html', 'snippet': 'Benoît Jacquot’s erotic costume drama envisions the Italian playboy as a weathered sad sack living in exile.', 'source': 'The New York Times', 'headline': {'main': '‘Casanova, Last Love’ Review: Reappraising a Philanderer', 'kicker': None, 'content_kicker': None, 'print_headline': 'Casanova, Last Love', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Jacquot, Benoit', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'Casanova, Last Love (Movie)', 'rank': 3, 'major': 'N'}], 'pub_date': '2021-07-14T22:12:43+0000', 'byline': {'original': 'By Beatrice Loayza', 'person': [{'firstname': 'Beatrice', 'middlename': None, 'lastname': 'Loayza', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 312}, {'web_url': 'https://www.nytimes.com/2016/11/04/movies/loving-review-joel-edgerton-ruth-negga.html', 'snippet': 'Jeff Nichols’s “Loving” is a fictionalization of the story of Mildred and Richard Loving, an interracial couple whose civil rights case went to the Supreme Court.', 'source': 'The New York Times', 'headline': {'main': 'Review: In ‘Loving,’ They Loved. A Segregated Virginia Did Not Love Them Back.', 'kicker': None, 'content_kicker': None, 'print_headline': 'They Fought the Law. And Their Love Won.', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Nichols, Jeff (1978- )', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Negga, Ruth (1982- )', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Edgerton, Joel', 'rank': 4, 'major': 'N'}, {'name': 'creative_works', 'value': 'Loving (Movie)', 'rank': 5, 'major': 'N'}], 'pub_date': '2016-11-03T21:53:01+0000', 'byline': {'original': 'By Manohla Dargis', 'person': [{'firstname': 'Manohla', 'middlename': None, 'lastname': 'Dargis', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 1031}, {'web_url': 'https://www.nytimes.com/2013/04/05/movies/robert-redfords-company-you-keep-revisits-radical-60s.html', 'snippet': 'Robert Redford’s “Company You Keep,” which also features Julie Christie and Susan Sarandon, follows 1960s radicals in later life.', 'source': 'The New York Times', 'headline': {'main': 'Remembering the Side of the ’60s That Wasn’t All Peace and Love', 'kicker': 'Movie Review', 'content_kicker': None, 'print_headline': 'Remembering the Side of the ’60s That Wasn’t All Peace and Love', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'creative_works', 'value': 'The Company You Keep (Movie)', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value':  ...
# ... done

# %%
for i in range(0,5):
    print(reviews_list[i])
# Out:
# [{'web_url': 'https://www.nytimes.com/2018/01/18/movies/kangaroo-a-love-hate-story-review.html', 'snippet': 'The documentary looks at the mass killings of kangaroos for pet-food companies, leather processors and ranchers in Australia.', 'source': 'The New York Times', 'headline': {'main': 'Review: ‘Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacre', 'kicker': None, 'content_kicker': None, 'print_headline': 'Kangaroo: A Love-Hate Story', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'creative_works', 'value': 'Kangaroo: A Love-Hate Story (Movie)', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Kangaroos', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Animal Abuse, Rights and Welfare', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'McIntyre Clere, Kate', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'McIntyre, Mick', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 6, 'major': 'N'}, {'name': 'glocations', 'value': 'Australia', 'rank': 7, 'major': 'N'}], 'pub_date': '2018-01-18T12:00:23+0000', 'byline': {'original': 'By Ken Jaworowski', 'person': [{'firstname': 'Ken', 'middlename': None, 'lastname': 'Jaworowski', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 263}, {'web_url': 'https://www.nytimes.com/2013/09/20/movies/jewtopia-a-comedy-directed-by-bryan-fogel.html', 'snippet': 'In “Jewtopia,” a young man asks a childhood friend to help him “act Jewish” so he can romance the girl of his dreams.', 'source': 'The New York Times', 'headline': {'main': 'Love’s Eternal Masquerade', 'kicker': 'Movie Review', 'content_kicker': None, 'print_headline': 'Jewtopia', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Sergei, Ivan', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'Jewtopia (Movie)', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Fogel, Bryan', 'rank': 4, 'major': 'N'}], 'pub_date': '2013-09-19T23:33:15+0000', 'byline': {'original': 'By David DeWitt', 'person': [{'firstname': 'David', 'middlename': None, 'lastname': 'DeWitt', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 272}, {'web_url': 'https://www.nytimes.com/2019/05/21/movies/the-tomorrow-man-review.html', 'snippet': 'Blythe Danner and John Lithgow strain to elevate this twee late-life romance.', 'source': 'The New York Times', 'headline': {'main': '‘The Tomorrow Man’ Review: Love Among the Neuroses', 'kicker': None, 'content_kicker': None, 'print_headline': 'They Whirl, They Twirl, They Tango', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'The Tomorrow Man (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Danner, Blythe', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Lithgow, John', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Jones, Noble', 'rank': 5, 'major': 'N'}], 'pub_date': '2019-05-21T11:00:01+0000', 'byline': {'original': 'By Jeannette Catsoulis', 'person': [{'firstname': 'Jeannette', 'middlename': None, 'lastname': 'Catsoulis', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 280}, {'web_url': 'https://www.nytimes.com/2019/11/05/movies/marriage-story-review.html', 'snippet': 'Adam Driver and Scarlett Johansson self-consciously uncouple in Noah Baumbach’s tender, stinging tale of divorce.', 'source': 'The New York Times', 'headline': {'main': '‘Marriage Story’ Review: Dance Me to the End of Love', 'kicker': 'critic’s pick', 'content_kicker': None, 'print_headline': 'Friendly Split, Shattering Break', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subj ...
# [{'web_url': 'https://www.nytimes.com/2018/11/01/movies/theyll-love-me-when-im-dead-review-documentary.html', 'snippet': 'Morgan Neville’s movie tells the tumultuous behind-the-scenes story of the making and near-unmaking of “The Other Side of the Wind.”', 'source': 'The New York Times', 'headline': {'main': 'Review: ‘They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Film', 'kicker': None, 'content_kicker': None, 'print_headline': 'The Legend Behind The Scenes', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': "They'll Love Me When I'm Dead (Movie)", 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Neville, Morgan', 'rank': 3, 'major': 'N'}, {'name': 'creative_works', 'value': 'The Other Side of the Wind (Movie)', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Welles, Orson', 'rank': 5, 'major': 'N'}], 'pub_date': '2018-11-01T13:56:39+0000', 'byline': {'original': 'By Manohla Dargis', 'person': [{'firstname': 'Manohla', 'middlename': None, 'lastname': 'Dargis', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 794}, {'web_url': 'https://www.nytimes.com/2021/12/23/movies/a-journal-for-jordan-review.html', 'snippet': 'The actors Michael B. Jordan and Chanté Adams bring a compelling chemistry to the screen as opposites who fall for each other.', 'source': 'The New York Times', 'headline': {'main': '‘A Journal for Jordan’ Review: Reflections on Love Built and Lost', 'kicker': None, 'content_kicker': None, 'print_headline': 'Reflections on Love That’s Built and Lost', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'A Journal for Jordan (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Washington, Denzel', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Jordan, Michael B', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Adams, Chante', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Books and Literature', 'rank': 6, 'major': 'N'}, {'name': 'creative_works', 'value': 'A Journal for Jordan: A Story of Love and Honor (Book)', 'rank': 7, 'major': 'N'}, {'name': 'persons', 'value': 'Canedy, Dana', 'rank': 8, 'major': 'N'}, {'name': 'subject', 'value': 'Black People', 'rank': 9, 'major': 'N'}, {'name': 'subject', 'value': 'Blacks', 'rank': 10, 'major': 'N'}], 'pub_date': '2021-12-23T18:54:12+0000', 'byline': {'original': 'By Lisa Kennedy', 'person': [{'firstname': 'Lisa', 'middlename': None, 'lastname': 'Kennedy', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 505}, {'web_url': 'https://www.nytimes.com/2017/02/09/movies/review-a-united-kingdom-with-love-that-tested-racial-tolerance.html', 'snippet': 'This romance illustrates the struggle for African independence from colonialism, under the shadow of apartheid.', 'source': 'The New York Times', 'headline': {'main': 'Review: ‘A United Kingdom’ With Love That Tested Racial Tolerance', 'kicker': None, 'content_kicker': None, 'print_headline': 'Not Your Typical Fairy-Tale Romance', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'A United Kingdom (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Oyelowo, David', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Pike, Rosamund', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Asante, Amma', 'rank': 5, 'major': 'N'}], 'pub_date': '2017-02-09T10:00:16+0000', 'byline': {'original': 'By Glenn Kenny', 'person': [{'firstname': 'Glenn', 'middlename': None, 'lastname': 'Kenny', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organi ...
# [{'web_url': 'https://www.nytimes.com/2016/06/24/movies/from-this-day-forward-review.html', 'snippet': 'Sharon Shattuck’s documentary tells her family story of growing up with a transgender parent.', 'source': 'The New York Times', 'headline': {'main': 'Review: ‘From This Day Forward’ Attests to Love’s Adaptability', 'kicker': None, 'content_kicker': None, 'print_headline': 'Review: ‘From This Day Forward’ Attests to Love’s Adaptability', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Documentary Films and Programs', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Shattuck, Sharon', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Transgender and Transsexuals', 'rank': 4, 'major': 'N'}, {'name': 'subject', 'value': 'Movies', 'rank': 5, 'major': 'N'}], 'pub_date': '2016-06-23T21:11:31+0000', 'byline': {'original': 'By Andy Webster', 'person': [{'firstname': 'Andy', 'middlename': None, 'lastname': 'Webster', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 252}, {'web_url': 'https://www.nytimes.com/2016/07/15/movies/how-he-fell-in-love-review.html', 'snippet': 'This Marc Meyers film focuses on how the relationship between a young musician and a middle-age woman affects them and others in their orbit.', 'source': 'The New York Times', 'headline': {'main': 'Review: In ‘How He Fell in Love,’ an Extramarital Bond Unfolds', 'kicker': None, 'content_kicker': None, 'print_headline': None, 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Meyers, Marc (Director)', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'How He Fell in Love (Movie)', 'rank': 3, 'major': 'N'}], 'pub_date': '2016-07-14T21:15:47+0000', 'byline': {'original': 'By Helen T. Verongos', 'person': [{'firstname': 'Helen', 'middlename': 'T.', 'lastname': 'Verongos', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 273}, {'web_url': 'https://www.nytimes.com/2013/11/08/movies/how-i-live-now-a-dystopian-drama-starring-saoirse-ronan.html', 'snippet': 'In “How I Live Now,” based on the novel by Meg Rosoff, a surly American teenager finds herself caught in World War III in Britain.', 'source': 'The New York Times', 'headline': {'main': 'Young Love, Interrupted by a Nuclear Bomb', 'kicker': 'Movie Review', 'content_kicker': None, 'print_headline': 'How I Live Now', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Ronan, Saoirse', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'How I Live Now (Movie)', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Macdonald, Kevin', 'rank': 4, 'major': 'N'}], 'pub_date': '2013-11-08T00:59:34+0000', 'byline': {'original': 'By Jeannette Catsoulis', 'person': [{'firstname': 'Jeannette', 'middlename': None, 'lastname': 'Catsoulis', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 264}, {'web_url': 'https://www.nytimes.com/2015/11/13/movies/review-in-love-the-coopers-a-dysfunctional-family-sits-down-to-christmas-dinner.html', 'snippet': 'Diane Keaton and John Goodman play a long-married couple who have big news to deliver to the family once it gathers, in Jessie Nelson’s film.', 'source': 'The New York Times', 'headline': {'main': 'Review: In ‘Love the Coopers,’ a Dysfunctional Family Sits Down to Christmas Dinner', 'kicker': None, 'content_kicker': None, 'print_headline': 'Review: In ‘Love the Coopers,’ a Dysfunctional Family Sits Down to Christmas Dinner', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Nelson, Jessie (Film Director)', 'rank': 2, ...
# [{'web_url': 'https://www.nytimes.com/2021/10/14/movies/hard-luck-love-song-review.html', 'snippet': 'Drawn from the plotline of a Todd Snider song, the film follows a pool shark and an escort, taking twists that are both violent and silly.', 'source': 'The New York Times', 'headline': {'main': '‘Hard Luck Love Song’ Review: A Glossy Take on a Gritty Tune', 'kicker': None, 'content_kicker': None, 'print_headline': 'Hard Luck Love Song', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Dorman, Michael (1981- )', 'rank': 2, 'major': 'N'}, {'name': 'creative_works', 'value': 'Hard Luck Love Song (Movie)', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Bush, Sophia (1982- )', 'rank': 4, 'major': 'N'}], 'pub_date': '2021-10-14T12:27:03+0000', 'byline': {'original': 'By Glenn Kenny', 'person': [{'firstname': 'Glenn', 'middlename': None, 'lastname': 'Kenny', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 320}, {'web_url': 'https://www.nytimes.com/2022/04/18/movies/see-you-then-review.html', 'snippet': 'Former lovers reconnect, litigating the past and present, in this drama from Mari Walker.', 'source': 'The New York Times', 'headline': {'main': '‘See You Then’ Review: The More Things Stay the Same', 'kicker': None, 'content_kicker': None, 'print_headline': 'The Persistent Melancholy of Love', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'See You Then (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Walker, Mari', 'rank': 3, 'major': 'N'}], 'pub_date': '2022-04-18T11:00:03+0000', 'byline': {'original': 'By Kyle Turner', 'person': [{'firstname': 'Kyle', 'middlename': None, 'lastname': 'Turner', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 300}, {'web_url': 'https://www.nytimes.com/2019/04/19/movies/kalank-review.html', 'snippet': 'Abhishek Varman’s maximalist melodrama delivers spectacle (some of it mind-numbing) but fails to tell a gripping story.', 'source': 'The New York Times', 'headline': {'main': '‘Kalank’ Review: A Bollywood Love Story in the Shadow of Partition', 'kicker': None, 'content_kicker': None, 'print_headline': 'An Extravagant Spectacle', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'Kalank (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Varman, Abhishek', 'rank': 3, 'major': 'N'}], 'pub_date': '2019-04-19T15:38:08+0000', 'byline': {'original': 'By Rachel Saltz', 'person': [{'firstname': 'Rachel', 'middlename': None, 'lastname': 'Saltz', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 479}, {'web_url': 'https://www.nytimes.com/2015/08/28/movies/review-in-z-for-zachariah-an-end-of-days-love-triangle.html', 'snippet': 'Margot Robbie stars in Craig Zobel’s post-apocalyptic film about three survivors of the nuclear holocaust caught in a triangle.', 'source': 'The New York Times', 'headline': {'main': 'Review: In ‘Z for Zachariah,’ an End-of-Days Love Triangle', 'kicker': None, 'content_kicker': None, 'print_headline': 'When a Woman Finds 2 Friends for the End of the World', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Zobel, R Craig', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Robbie, Margot', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Ejiofor, Chiwetel', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Pine, Chris', 'rank': 5, 'major': 'N'}, {'name': 'persons', 'value': "O'Brien, Robert C", 'rank': 6, ' ...
# [{'web_url': 'https://www.nytimes.com/2019/08/29/movies/falling-inn-love-review.html', 'snippet': 'It’s hard to find a reliable, talented, reasonably priced, eco-friendly contractor these days.', 'source': 'The New York Times', 'headline': {'main': '‘Falling Inn Love’ Review: A Prize That Needs Some Work', 'kicker': 'Streaming Movie Review', 'content_kicker': None, 'print_headline': 'A Fine Romance to Watch While Sorting Socks', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'organizations', 'value': 'Netflix Inc', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Kumble, Roger', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Milian, Christina', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Demos, Adam', 'rank': 5, 'major': 'N'}, {'name': 'creative_works', 'value': 'Falling Inn Love (Movie)', 'rank': 6, 'major': 'N'}], 'pub_date': '2019-08-29T14:56:44+0000', 'byline': {'original': 'By Helen T. Verongos', 'person': [{'firstname': 'Helen', 'middlename': 'T.', 'lastname': 'Verongos', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 374}, {'web_url': 'https://www.nytimes.com/2015/11/27/movies/review-in-tamasha-finding-a-path-to-love-show-business-and-adulation.html', 'snippet': 'A Bollywood melodrama about a boy, a girl, storytelling and make-believe.', 'source': 'The New York Times', 'headline': {'main': 'Review: In ‘Tamasha,’ Finding a Path to Love, Show Business and Adulation', 'kicker': None, 'content_kicker': None, 'print_headline': 'Review: In ‘Tamasha,’ Finding a Path to Love, Show Business and Adulation', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'persons', 'value': 'Ali, Imtiaz', 'rank': 2, 'major': 'N'}], 'pub_date': '2015-11-26T21:37:30+0000', 'byline': {'original': 'By Andy Webster', 'person': [{'firstname': 'Andy', 'middlename': None, 'lastname': 'Webster', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 260}, {'web_url': 'https://www.nytimes.com/2019/05/15/movies/the-sun-is-also-a-star-review.html', 'snippet': 'Yara Shahidi and Charles Melton play teenagers falling in love on a hectic, sunny day in New York.', 'source': 'The New York Times', 'headline': {'main': '‘The Sun Is Also a Star’ Review: A Charming, if Generic, Adolescent Love Story', 'kicker': None, 'content_kicker': None, 'print_headline': 'A Beautiful Day for Young Hearts', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Movies', 'rank': 1, 'major': 'N'}, {'name': 'creative_works', 'value': 'The Sun Is also a Star (Movie)', 'rank': 2, 'major': 'N'}, {'name': 'persons', 'value': 'Russo-Young, Ry', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Shahidi, Yara (2000- )', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Yoon, Nicola (Author)', 'rank': 5, 'major': 'N'}, {'name': 'persons', 'value': 'Melton, Charles (1991- )', 'rank': 6, 'major': 'N'}], 'pub_date': '2019-05-15T16:01:27+0000', 'byline': {'original': 'By A.O. Scott', 'person': [{'firstname': 'A.', 'middlename': 'O.', 'lastname': 'Scott', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'word_count': 697}, {'web_url': 'https://www.nytimes.com/2015/05/01/movies/review-in-cathedrals-of-culture-buildings-to-love.html', 'snippet': 'A two-part program of short films by directors including Wim Wenders and Robert Redford tours structures that transcend mere architectural concerns.', 'source': 'The New York Times', 'headline': {'main': 'Review: In ‘Cathedrals of Culture,’ Buildings to Love', 'kicker': None, 'content_kicker': None, 'print_headline': 'Review: In ‘Cathedrals of Culture,’ Buildings to Love', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{' ...

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data

# I am not sure if here 5 means that we are looking at only the very first 5
# articles in the reviews_list, or the first 5 pages, but I think it is meant
# to be the latter here or there would be no point in doing it now rather than
# earlier.
for i in range(0,5):
    print(json.dumps(reviews_list[i],indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2018/01/18/movies/kangaroo-a-love-hate-story-review.html",
#         "snippet": "The documentary looks at the mass killings of kangaroos for pet-food companies, leather processors and ranchers in Australia.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018Kangaroo: A Love-Hate Story\u2019 Exposes a Wildlife Massacre",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Kangaroo: A Love-Hate Story",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "creative_works",
#                 "value": "Kangaroo: A Love-Hate Story (Movie)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Kangaroos",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Animal Abuse, Rights and Welfare",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "McIntyre Clere, Kate",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "McIntyre, Mick",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Australia",
#                 "rank": 7,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2018-01-18T12:00:23+0000",
#         "byline": {
#             "original": "By Ken Jaworowski",
#             "person": [
#                 {
#                     "firstname": "Ken",
#                     "middlename": null,
#                     "lastname": "Jaworowski",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 263
#     },
#     {
#         "web_url": "https://www.nytimes.com/2013/09/20/movies/jewtopia-a-comedy-directed-by-bryan-fogel.html",
#         "snippet": "In \u201cJewtopia,\u201d a young man asks a childhood friend to help him \u201cact Jewish\u201d so he can romance the girl of his dreams.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Love\u2019s Eternal Masquerade",
#             "kicker": "Movie Review",
#             "content_kicker": null,
#             "print_headline": "Jewtopia",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Sergei, Ivan",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Jewtopia (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Fogel, Bryan",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2013-09-19T23:33:15+0000",
#         "byline": {
#             "original": "By David DeWitt",
#             "person": [
#                 {
#                     "firstname": "David",
#                     "middlename": null,
#                     "lastname": "DeWitt",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 272
#     },
#     {
#         "web_url": "https://www.nytimes.com/2019/05/21/movies/the-tomorrow-man-review.html",
#         "snippet": "Blythe Danner and John Lithgow strain to elevate this twee late-life romance.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Tomorrow Man\u2019 Review: Love Among the Neuroses",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "They Whirl, They Twirl, They Tango",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Tomorrow Man (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Danner, Blythe",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lithgow, John",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Jones, Noble",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2019-05-21T11:00:01+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 280
#     },
#     {
#         "web_url": "https://www.nytimes.com/2019/11/05/movies/marriage-story-review.html",
#         "snippet": "Adam Driver and Scarlett Johansson self-consciously uncouple in Noah Baumbach\u2019s tender, stinging tale of divorce.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Marriage Story\u2019 Review: Dance Me to the End of Love",
#             "kicker": "critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Friendly Split, Shattering Break",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Baumbach, Noah",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Marriage Story (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Driver, Adam",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Johansson, Scarlett",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "ALDA, ALAN",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Dern, Laura",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Liotta, Ray",
#                 "rank": 8,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2019-11-05T19:01:02+0000",
#         "byline": {
#             "original": "By A.O. Scott",
#             "person": [
#                 {
#                     "firstname": "A.",
#                     "middlename": "O.",
#                     "lastname": "Scott",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 1244
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/11/17/movies/bones-and-all-review.html",
#         "snippet": "Luca Guadagnino\u2019s latest stars Timoth\u00e9e Chalamet and Taylor Russell as young cannibals on the run.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Bones and All\u2019 Review: You Eat What You Are",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "It\u2019s Eat, Prey, Love on a Journey of Self-Discovery",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Bones and All (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Guadagnino, Luca",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Chalamet, Timothee (1995- )",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Russell, Taylor (1994- )",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-11-17T12:00:06+0000",
#         "byline": {
#             "original": "By A.O. Scott",
#             "person": [
#                 {
#                     "firstname": "A.",
#                     "middlename": "O.",
#                     "lastname": "Scott",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 710
#     },
#     {
#         "web_url": "https://www.nytimes.com/2019/08/08/movies/love-anthosa-review.html",
#         "snippet": "Anton Yelchin, who played Chekov in the J.J. Abrams-produced \u201cStar Trek\u201d films, assembled an eclectic filmography before his death at 27 in 2016.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Love, Antosha\u2019 Review: A Heartbreaking Look at an Actor\u2019s Too-Short Life",
#             "kicker": "Critic\u2019s Pick",
#             "content_kicker": null,
#             "print_headline": "Love, Antosha",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Love, Antosha (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Price, Garret",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Yelchin, Anton",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2019-08-08T09:00:10+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 319
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2015/11/16/movies/review-prem-ratan-dhan-payo-a-bollywood-tale-of-a-prince-and-plebe-double.html",
#         "snippet": "Sooraj R. Barjatya\u2019s film stars Salman Khan as a decent and playful fellow who intervenes in the power battles of a royal family.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018Prem Ratan Dhan Payo,\u2019 a Bollywood Tale of a Prince-and-Plebe Double",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Love and War in a Palace of Mirrors",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Barjatya, Sooraj R (1964- )",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Khan, Salman",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapoor, Sonam",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2015-11-15T22:34:57+0000",
#         "byline": {
#             "original": "By Rachel Saltz",
#             "person": [
#                 {
#                     "firstname": "Rachel",
#                     "middlename": null,
#                     "lastname": "Saltz",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 363
#     },
#     {
#         "web_url": "https://www.nytimes.com/2013/10/18/movies/ja-rule-in-im-in-love-with-a-church-girl.html",
#         "snippet": "The rapper Ja Rule stars as a stylish concert publicist in \u201cI\u2019m in Love With a Church Girl,\u201d written by a pastor who plays a pastor in the film.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "A Promoter Finds a New Cause: God",
#             "kicker": "Movie Review",
#             "content_kicker": null,
#             "print_headline": "I\u2019m in Love With a Church Girl",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Ja Rule",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "I'm in Love with a Church Girl (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2013-10-17T23:05:39+0000",
#         "byline": {
#             "original": "By Miriam Bale",
#             "person": [
#                 {
#                     "firstname": "Miriam",
#                     "middlename": null,
#                     "lastname": "Bale",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 271
#     },
#     {
#         "web_url": "https://www.nytimes.com/2014/02/07/movies/zoe-kazan-plays-disparate-twins-in-the-pretty-one.html",
#         "snippet": "\u201cThe Pretty One\u201d stars Zoe Kazan as a pair of twins, one mousy and insecure, the other vivacious. When the popular twin dies in a car accident, her sister decides to assume her identity.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Now They\u2019ll Love Me, a Twin Sister Schemes",
#             "kicker": "Movie Review",
#             "content_kicker": null,
#             "print_headline": "Now They\u2019ll Love Me, a Twin Sister Schemes",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kazan, Zoe",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Pretty One (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "LeMarque, Jenee",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2014-02-07T00:05:06+0000",
#         "byline": {
#             "original": "By A.O. Scott",
#             "person": [
#                 {
#                     "firstname": "A.",
#                     "middlename": "O.",
#                     "lastname": "Scott",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 369
#     }
# ]
# [
#     {
#         "web_url": "https://www.nytimes.com/2018/11/01/movies/theyll-love-me-when-im-dead-review-documentary.html",
#         "snippet": "Morgan Neville\u2019s movie tells the tumultuous behind-the-scenes story of the making and near-unmaking of \u201cThe Other Side of the Wind.\u201d",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018They\u2019ll Love Me When I\u2019m Dead\u2019 Documents Orson Welles\u2019s Last Film",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Legend Behind The Scenes",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "They'll Love Me When I'm Dead (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Neville, Morgan",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Other Side of the Wind (Movie)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Welles, Orson",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2018-11-01T13:56:39+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 794
#     },
#     {
#         "web_url": "https://www.nytimes.com/2021/12/23/movies/a-journal-for-jordan-review.html",
#         "snippet": "The actors Michael B. Jordan and Chant\u00e9 Adams bring a compelling chemistry to the screen as opposites who fall for each other.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Journal for Jordan\u2019 Review: Reflections on Love Built and Lost",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Reflections on Love That\u2019s Built and Lost",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Journal for Jordan (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Washington, Denzel",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Jordan, Michael B",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Adams, Chante",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Books and Literature",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Journal for Jordan: A Story of Love and Honor (Book)",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Canedy, Dana",
#                 "rank": 8,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Black People",
#                 "rank": 9,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Blacks",
#                 "rank": 10,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2021-12-23T18:54:12+0000",
#         "byline": {
#             "original": "By Lisa Kennedy",
#             "person": [
#                 {
#                     "firstname": "Lisa",
#                     "middlename": null,
#                     "lastname": "Kennedy",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 505
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/02/09/movies/review-a-united-kingdom-with-love-that-tested-racial-tolerance.html",
#         "snippet": "This romance illustrates the struggle for African independence from colonialism, under the shadow of apartheid.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018A United Kingdom\u2019 With Love That Tested Racial Tolerance",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Not Your Typical Fairy-Tale Romance",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A United Kingdom (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Oyelowo, David",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Pike, Rosamund",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Asante, Amma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-02-09T10:00:16+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 606
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/02/02/movies/sophie-and-the-rising-sun-review.html",
#         "snippet": "The movie, set in 1941 and based on a novel by Augusta Trobaugh, finds a white woman and an Asian man falling in love, hindered by small-town prejudice.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018Sophie and the Rising Sun\u2019 Has Forbidden Love in a Foreboding Time",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Forbidden Love, in a Foreboding Time",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Sophie and the Rising Sun (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Martindale, Margo",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Nicholson, Julianne",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Greenwald, Maggie (1955- )",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-02-03T00:08:38+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 455
#     },
#     {
#         "web_url": "https://www.nytimes.com/2016/12/20/movies/passengers-review-jennifer-lawrence-chris-pratt.html",
#         "snippet": "Jennifer Lawrence stars in this interplanetary romance aboard a mechanically doomed spacecraft making a 120-year voyage.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: Two \u2018Passengers\u2019 Trapped on a Spaceship Find Love Amid Despair",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Fasten Your Seat Belts for a 120-Year Ride",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "creative_works",
#                 "value": "Passengers (Movie)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Lawrence, Jennifer",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Pratt, Chris",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Sheen, Michael",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tyldum, Morten",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2016-12-20T22:08:00+0000",
#         "byline": {
#             "original": "By Stephen Holden",
#             "person": [
#                 {
#                     "firstname": "Stephen",
#                     "middlename": null,
#                     "lastname": "Holden",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 792
#     },
#     {
#         "web_url": "https://www.nytimes.com/2021/06/03/movies/undine-review.html",
#         "snippet": "Paula Beer and Franz Rogowski, who made an impression in 2019\u2019s \u201cTransit,\u201d are reunited by the director Christian Petzold for this adaptation of a European myth.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Undine\u2019 Review: Love In and Out of the Water",
#             "kicker": "Critic\u2019s Pick",
#             "content_kicker": null,
#             "print_headline": "She\u2019s Like a Sprite Out of Water",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Petzold, Christian",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Rogowski, Franz",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Undine (Movie)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Beer, Paula (1995- )",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2021-06-03T11:00:08+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 535
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/09/01/movies/waiting-for-bojangles-review-endless-love.html",
#         "snippet": "Set in Paris in the 1960s, the film tells the story of two irrepressible lovers, and their young son, whose tale turns tragic.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Waiting for Bojangles\u2019 Review: Endless Love",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Waiting for Bojangles",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Bourdeaut, Olivier",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Waiting for Bojangles (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Roinsard, Regis",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-09-01T11:00:06+0000",
#         "byline": {
#             "original": "By Calum Marsh",
#             "person": [
#                 {
#                     "firstname": "Calum",
#                     "middlename": null,
#                     "lastname": "Marsh",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 267
#     },
#     {
#         "web_url": "https://www.nytimes.com/2014/08/15/movies/jealousy-directed-by-philippe-garrel.html",
#         "snippet": "In Philippe Garrel\u2019s \u201cJealousy,\u201d emotional ambivalence and wayward passion span years among a group of struggling artists.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Love and Unhappiness, in Soft Shades of Gray",
#             "kicker": "Movie Review",
#             "content_kicker": null,
#             "print_headline": "Love and Unhappiness, in Soft Shades of Gray",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Garrel, Philippe",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Jealousy (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2014-08-14T20:02:46+0000",
#         "byline": {
#             "original": "By A.O. Scott",
#             "person": [
#                 {
#                     "firstname": "A.",
#                     "middlename": "O.",
#                     "lastname": "Scott",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 619
#     },
#     {
#         "web_url": "https://www.nytimes.com/2017/06/15/movies/lost-in-paris-review.html",
#         "snippet": "The filmmakers Fiona Gordon and Dominique Abel star in their fourth movie, a tale infused with physical comedy about a woman in search of her aunt.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: Finding Love (and Slapstick) While \u2018Lost in Paris\u2019",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Lost in Paris",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "creative_works",
#                 "value": "Lost in Paris (Movie)",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Abel, Dominique",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Gordon, Fiona",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Riva, Emmanuelle",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2017-06-15T19:37:09+0000",
#         "byline": {
#             "original": "By Ben Kenigsberg",
#             "person": [
#                 {
#                     "firstname": "Ben",
#                     "middlename": null,
#                     "lastname": "Kenigsberg",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 254
#     },
#     {
#         "web_url": "https://www.nytimes.com/2015/03/20/movies/review-lost-and-love-shu-gi-stars-andy-lau-as-a-man-searching-for-his-lost-son.html",
#         "snippet": "Peng Sanyuan\u2019s drama builds a personal story and a road movie around the scourge of child trafficking in China.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018Lost and Love\u2019 (\u2018Shi Gu\u2019) Stars Andy Lau as a Man Searching for His Lost Son",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Review: \u2018Lost and Love\u2019 (\u2018Shu Gi\u2019) Stars Andy Lau as a Man Searching for His Lost Son",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Lost and Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2015-03-20T01:16:01+0000",
#         "byline": {
#             "original": "By Nicolas Rapold",
#             "person": [
#                 {
#                     "firstname": "Nicolas",
#                     "middlename": null,
#                     "lastname": "Rapold",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 261
#     }
# ]
# [
#     {
#         "web_url": "https://www.nytimes.com/2016/06/24/movies/from-this-day-forward-review.html",
#         "snippet": "Sharon Shattuck\u2019s documentary tells her family story of growing up with a transgender parent.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018From This Day Forward\u2019 Attests to Love\u2019s Adaptability",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Review: \u2018From This Day Forward\u2019 Attests to Love\u2019s Adaptability",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Shattuck, Sharon",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Transgender and Transsexuals",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2016-06-23T21:11:31+0000",
#         "byline": {
#             "original": "By Andy Webster",
#             "person": [
#                 {
#                     "firstname": "Andy",
#                     "middlename": null,
#                     "lastname": "Webster",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 252
#     },
#     {
#         "web_url": "https://www.nytimes.com/2016/07/15/movies/how-he-fell-in-love-review.html",
#         "snippet": "This Marc Meyers film focuses on how the relationship between a young musician and a middle-age woman affects them and others in their orbit.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: In \u2018How He Fell in Love,\u2019 an Extramarital Bond Unfolds",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": null,
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Meyers, Marc (Director)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "How He Fell in Love (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2016-07-14T21:15:47+0000",
#         "byline": {
#             "original": "By Helen T. Verongos",
#             "person": [
#                 {
#                     "firstname": "Helen",
#                     "middlename": "T.",
#                     "lastname": "Verongos",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 273
#     },
#     {
#         "web_url": "https://www.nytimes.com/2013/11/08/movies/how-i-live-now-a-dystopian-drama-starring-saoirse-ronan.html",
#         "snippet": "In \u201cHow I Live Now,\u201d based on the novel by Meg Rosoff, a surly American teenager finds herself caught in World War III in Britain.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Young Love, Interrupted by a Nuclear Bomb",
#             "kicker": "Movie Review",
#             "content_kicker": null,
#             "print_headline": "How I Live Now",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Ronan, Saoirse",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "How I Live Now (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Macdonald, Kevin",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2013-11-08T00:59:34+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 264
#     },
#     {
#         "web_url": "https://www.nytimes.com/2015/11/13/movies/review-in-love-the-coopers-a-dysfunctional-family-sits-down-to-christmas-dinner.html",
#         "snippet": "Diane Keaton and John Goodman play a long-married couple who have big news to deliver to the family once it gathers, in Jessie Nelson\u2019s film.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: In \u2018Love the Coopers,\u2019 a Dysfunctional Family Sits Down to Christmas Dinner",
#             "kicker": null,
#             "content_kicker": null,
# ...
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 697
#     },
#     {
#         "web_url": "https://www.nytimes.com/2015/05/01/movies/review-in-cathedrals-of-culture-buildings-to-love.html",
#         "snippet": "A two-part program of short films by directors including Wim Wenders and Robert Redford tours structures that transcend mere architectural concerns.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: In \u2018Cathedrals of Culture,\u2019 Buildings to Love",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Review: In \u2018Cathedrals of Culture,\u2019 Buildings to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Wenders, Wim",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Glawogger, Michael (1959-2014)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Madsen, Michael",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Redford, Robert",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Ainouz, Karim",
#                 "rank": 6,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 7,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "ARCHITECTURE",
#                 "rank": 8,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Cathedrals of Culture (Movie)",
#                 "rank": 9,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Olin, Margreth (1970- )",
#                 "rank": 10,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2015-04-30T23:50:03+0000",
#         "byline": {
#             "original": "By Nicolas Rapold",
#             "person": [
#                 {
#                     "firstname": "Nicolas",
#                     "middlename": null,
#                     "lastname": "Rapold",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 274
#     },
#     {
#         "web_url": "https://www.nytimes.com/2022/02/04/movies/book-of-love-review.html",
#         "snippet": "Unbeknown to the author of an uninspired romance novel, the book takes a sharp turn into erotic territory in its Spanish-language release.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Book of Love\u2019 Review: Lust (Eventually) in Translation",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Book of Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Claflin, Sam",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cal y Mayor, Analeine",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Book of Love (Movie)",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2022-02-04T05:01:04+0000",
#         "byline": {
#             "original": "By Natalia Winkelman",
#             "person": [
#                 {
#                     "firstname": "Natalia",
#                     "middlename": null,
#                     "lastname": "Winkelman",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 269
#     },
#     {
#         "web_url": "https://www.nytimes.com/2020/11/26/movies/my-psychedelic-love-story-review.html",
#         "snippet": "This Errol Morris documentary explores the relationship between the LSD guru and Joanna Harcourt-Smith, a woman who likened herself to Mata Hari.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018My Psychedelic Love Story\u2019 Review: On the Run With Timothy Leary",
#             "kicker": "Critic\u2019s Pick",
#             "content_kicker": null,
#             "print_headline": "Acid and Romance: On the Run With Timothy Leary",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Documentary Films and Programs",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "My Psychedelic Love Story (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Harcourt-Smith, Joanna (1946-2020)",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Morris, Errol",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "LSD (Lysergic Acid Diethylamide)",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Content Type: Personal Profile",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2020-11-26T12:00:05+0000",
#         "byline": {
#             "original": "By Glenn Kenny",
#             "person": [
#                 {
#                     "firstname": "Glenn",
#                     "middlename": null,
#                     "lastname": "Kenny",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 599
#     },
#     {
#         "web_url": "https://www.nytimes.com/2018/05/24/movies/how-to-talk-to-girls-at-parties-review.html",
#         "snippet": "John Cameron Mitchell\u2019s loony romantic comedy encourages young love to bloom in the soil of an alien visitation.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: An Alien Teaches a Teenage Punk \u2018How to Talk to Girls at Parties\u2019",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Otherworldly Love in a Punk-Rock World",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "How to Talk to Girls at Parties (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Mitchell, John Cameron",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Fanning, Elle",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Sharp, Alexander",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2018-05-24T11:00:01+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 458
#     },
#     {
#         "web_url": "https://www.nytimes.com/2015/10/30/movies/review-flowers-leaves-three-women-pining-for-the-same-lost-love.html",
#         "snippet": "This melodrama directed by Jon Gara\u00f1o and Jose Mari Goenaga follows how lives are altered after one woman receives anonymous weekly bouquets.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018Flowers\u2019 Leaves Three Women Pining for the Same Lost Love",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Review: \u2018Flowers\u2019 Leaves Three Women Pining for the Same Lost Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Garano, Jon (1974- )",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Goenaga, Jose Mari",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Flowers (Movie)",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2015-10-29T23:02:59+0000",
#         "byline": {
#             "original": "By Andy Webster",
#             "person": [
#                 {
#                     "firstname": "Andy",
#                     "middlename": null,
#                     "lastname": "Webster",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 250
#     },
#     {
#         "web_url": "https://www.nytimes.com/2020/02/28/movies/all-the-bright-places-review.html",
#         "snippet": "Elle Fanning and Justice Smith breathe life into a film about mental illness and the healing power of love.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018All the Bright Places\u2019 Review: Love Amid Trauma",
#             "kicker": "Streaming Movie Review",
#             "content_kicker": null,
#             "print_headline": "A Refreshing Exploration of Mental Illness",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "All the Bright Places (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Haley, Brett",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Fanning, Elle",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Smith, Justice (1995- )",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "organizations",
#                 "value": "Netflix Inc",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2020-02-28T08:01:07+0000",
#         "byline": {
#             "original": "By Candice Frederick",
#             "person": [
#                 {
#                     "firstname": "Candice",
#                     "middlename": null,
#                     "lastname": "Frederick",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 233
#     },
#     {
#         "web_url": "https://www.nytimes.com/2016/02/12/movies/review-touched-with-fire-a-love-story-between-two-bipolar-poets.html",
#         "snippet": "Katie Holmes and Luke Kirby play bright, high-strung artists struggling with depression in this film by Paul Dalio.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018Touched With Fire,\u2019 a Love Story Between Two Bipolar Poets",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "Two Offbeat Poets Trying to Find Their Rhyme and Rhythm",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Dalio, Paul (1979- )",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Holmes, Katie",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kirby, Luke",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "subject",
#                 "value": "Bipolar Disorder",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Touched with Fire (Movie)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2016-02-11T22:47:15+0000",
#         "byline": {
#             "original": "By Stephen Holden",
#             "person": [
#                 {
#                     "firstname": "Stephen",
#                     "middlename": null,
#                     "lastname": "Holden",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 678
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()

# Create an empty dataframe
reviews_dataframe = pd.DataFrame()

# Loop through pages in the dataframe
for page in reviews_list:
    reviews_dataframe = pd.concat([reviews_dataframe, pd.json_normalize(page)])

# Reset the index of the DataFrame
reviews_dataframe = reviews_dataframe.reset_index(drop=True)

# Display the final DataFrame
reviews_dataframe
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2018/01/18/movies/kang...
# 1    https://www.nytimes.com/2013/09/20/movies/jewt...
# 2    https://www.nytimes.com/2019/05/21/movies/the-...
# 3    https://www.nytimes.com/2019/11/05/movies/marr...
# 4    https://www.nytimes.com/2022/11/17/movies/bone...
# ..                                                 ...
# 195  https://www.nytimes.com/2016/12/27/movies/ocea...
# 196  https://www.nytimes.com/2022/05/26/movies/dinn...
# 197  https://www.nytimes.com/2015/04/10/movies/revi...
# 198  https://www.nytimes.com/2022/11/17/movies/the-...
# 199  https://www.nytimes.com/2013/03/22/movies/dorf...
#
#                                                snippet              source  \
# 0    The documentary looks at the mass killings of ...  The New York Times
# 1    In “Jewtopia,” a young man asks a childhood fr...  The New York Times
# 2    Blythe Danner and John Lithgow strain to eleva...  The New York Times
# 3    Adam Driver and Scarlett Johansson self-consci...  The New York Times
# 4    Luca Guadagnino’s latest stars Timothée Chalam...  The New York Times
# ..                                                 ...                 ...
# 195  In a 1993 gem from this revered Japanese anima...  The New York Times
# 196  A rage-fueled rock singer on the run from the ...  The New York Times
# 197  In this film, an orphaned girl’s friendship wi...  The New York Times
# 198  Elegance Bratton’s autobiographical first feat...  The New York Times
# 199  “Dorfman in Love,” directed by Bradley Leong, ...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'creative_works', 'value': 'Kangaroo...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'creative_works', 'value': 'Ocean Wa...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                      pub_date  word_count  \
# 0    2018-01-18T12:00:23+0000         263
# 1    2013-09-19T23:33:15+0000         272
# 2    2019-05-21T11:00:01+0000         280
# 3    2019-11-05T19:01:02+0000        1244
# 4    2022-11-17T12:00:06+0000         710
# ..                        ...         ...
# 195  2016-12-27T21:08:58+0000         263
# 196  2022-05-26T11:00:04+0000         254
# 197  2015-04-09T23:37:10+0000         491
# 198  2022-11-17T12:00:07+0000         836
# 199  2013-03-22T00:54:43+0000         250
#
#                                          headline.main headline.kicker  \
# 0    Review: ‘Kangaroo: A Love-Hate Story’ Exposes ...            None
# 1                            Love’s Eternal Masquerade    Movie Review
# 2    ‘The Tomorrow Man’ Review: Love Among the Neur...            None
# 3    ‘Marriage Story’ Review: Dance Me to the End o...   critic’s pick
# 4         ‘Bones and All’ Review: You Eat What You Are            None
# ..                                                 ...             ...
# 195  Review: ‘Ocean Waves,’ a Tale of Young Love, G...            None
# 196  ‘Dinner in America’ Review: A Punk-Rock Love S...            None
# 197  Review: In ‘The Harvest,’ Love Is Wielded With...            None
# 198   ‘The Inspection’ Review: Boot Camp, a Love Story   critic’s pick
# 199                       To Live and Decorate in L.A.    Movie Review
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                          Kangaroo: A Love-Hate Story          None
# 1                                             Jewtopia          None
# 2                   They Whirl, They Twirl, They Tango          None
# 3                     Friendly Split, Shattering Break          None
# 4    It’s Eat, Prey, Love on a Journey of Self-Disc...          None
# ..                                                 ...           ...
# 195            Teenage  Romance,  Flashbacks and Style          None
# 196                                  Dinner in America          None
# 197                         Love, Wielded With a Chill          None
# 198                  A Few Good Men, Some With Secrets          None
# 199                                    Dorfman in Love          None
#
#     headline.seo headline.sub         byline.original  \
# 0           None         None       By Ken Jaworowski
# 1           None         None         By David DeWitt
# 2           None         None  By Jeannette Catsoulis
# 3           None         None           By A.O. Scott
# 4           None         None           By A.O. Scott
# ..           ...          ...                     ...
# 195         None         None          By Glenn Kenny
# 196         None         None   By Concepción de León
# 197         None         None  By Jeannette Catsoulis
# 198         None         None           By A.O. Scott
# 199         None         None         By Andy Webster
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 1    [{'firstname': 'David', 'middlename': None, 'l...                None
# 2    [{'firstname': 'Jeannette', 'middlename': None...                None
# 3    [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 4    [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 196  [{'firstname': 'Concepción', 'middlename': Non...                None
# 197  [{'firstname': 'Jeannette', 'middlename': None...                None
# 198  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 199  [{'firstname': 'Andy', 'middlename': None, 'la...                None
#
# [200 rows x 16 columns]

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early

extract = lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")]
reviews_dataframe['title'] = reviews_dataframe['headline.main'].apply(extract)
reviews_dataframe

# I am not entirely confident that this function is doing quite what it is supposed to be doing.
# What does it mean that the "end string should incluce ' Review'"?
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2018/01/18/movies/kang...
# 1    https://www.nytimes.com/2013/09/20/movies/jewt...
# 2    https://www.nytimes.com/2019/05/21/movies/the-...
# 3    https://www.nytimes.com/2019/11/05/movies/marr...
# 4    https://www.nytimes.com/2022/11/17/movies/bone...
# ..                                                 ...
# 195  https://www.nytimes.com/2016/12/27/movies/ocea...
# 196  https://www.nytimes.com/2022/05/26/movies/dinn...
# 197  https://www.nytimes.com/2015/04/10/movies/revi...
# 198  https://www.nytimes.com/2022/11/17/movies/the-...
# 199  https://www.nytimes.com/2013/03/22/movies/dorf...
#
#                                                snippet              source  \
# 0    The documentary looks at the mass killings of ...  The New York Times
# 1    In “Jewtopia,” a young man asks a childhood fr...  The New York Times
# 2    Blythe Danner and John Lithgow strain to eleva...  The New York Times
# 3    Adam Driver and Scarlett Johansson self-consci...  The New York Times
# 4    Luca Guadagnino’s latest stars Timothée Chalam...  The New York Times
# ..                                                 ...                 ...
# 195  In a 1993 gem from this revered Japanese anima...  The New York Times
# 196  A rage-fueled rock singer on the run from the ...  The New York Times
# 197  In this film, an orphaned girl’s friendship wi...  The New York Times
# 198  Elegance Bratton’s autobiographical first feat...  The New York Times
# 199  “Dorfman in Love,” directed by Bradley Leong, ...  The New York Times
#
#                                               keywords  \
# 0    [{'name': 'creative_works', 'value': 'Kangaroo...
# 1    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3    [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4    [{'name': 'subject', 'value': 'Movies', 'rank'...
# ..                                                 ...
# 195  [{'name': 'creative_works', 'value': 'Ocean Wa...
# 196  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 197  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 198  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 199  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                      pub_date  word_count  \
# 0    2018-01-18T12:00:23+0000         263
# 1    2013-09-19T23:33:15+0000         272
# 2    2019-05-21T11:00:01+0000         280
# 3    2019-11-05T19:01:02+0000        1244
# 4    2022-11-17T12:00:06+0000         710
# ..                        ...         ...
# 195  2016-12-27T21:08:58+0000         263
# 196  2022-05-26T11:00:04+0000         254
# 197  2015-04-09T23:37:10+0000         491
# 198  2022-11-17T12:00:07+0000         836
# 199  2013-03-22T00:54:43+0000         250
#
#                                          headline.main headline.kicker  \
# 0    Review: ‘Kangaroo: A Love-Hate Story’ Exposes ...            None
# 1                            Love’s Eternal Masquerade    Movie Review
# 2    ‘The Tomorrow Man’ Review: Love Among the Neur...            None
# 3    ‘Marriage Story’ Review: Dance Me to the End o...   critic’s pick
# 4         ‘Bones and All’ Review: You Eat What You Are            None
# ..                                                 ...             ...
# 195  Review: ‘Ocean Waves,’ a Tale of Young Love, G...            None
# 196  ‘Dinner in America’ Review: A Punk-Rock Love S...            None
# 197  Review: In ‘The Harvest,’ Love Is Wielded With...            None
# 198   ‘The Inspection’ Review: Boot Camp, a Love Story   critic’s pick
# 199                       To Live and Decorate in L.A.    Movie Review
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                          Kangaroo: A Love-Hate Story          None
# 1                                             Jewtopia          None
# 2                   They Whirl, They Twirl, They Tango          None
# 3                     Friendly Split, Shattering Break          None
# 4    It’s Eat, Prey, Love on a Journey of Self-Disc...          None
# ..                                                 ...           ...
# 195            Teenage  Romance,  Flashbacks and Style          None
# 196                                  Dinner in America          None
# 197                         Love, Wielded With a Chill          None
# 198                  A Few Good Men, Some With Secrets          None
# 199                                    Dorfman in Love          None
#
#     headline.seo headline.sub         byline.original  \
# 0           None         None       By Ken Jaworowski
# 1           None         None         By David DeWitt
# 2           None         None  By Jeannette Catsoulis
# 3           None         None           By A.O. Scott
# 4           None         None           By A.O. Scott
# ..           ...          ...                     ...
# 195         None         None          By Glenn Kenny
# 196         None         None   By Concepción de León
# 197         None         None  By Jeannette Catsoulis
# 198         None         None           By A.O. Scott
# 199         None         None         By Andy Webster
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 1    [{'firstname': 'David', 'middlename': None, 'l...                None
# 2    [{'firstname': 'Jeannette', 'middlename': None...                None
# 3    [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 4    [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 196  [{'firstname': 'Concepción', 'middlename': Non...                None
# 197  [{'firstname': 'Jeannette', 'middlename': None...                None
# 198  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 199  [{'firstname': 'Andy', 'middlename': None, 'la...                None
#
#                                                  title
# 0    Kangaroo: A Love-Hate Story’ Exposes a Wildlif...
# 1                             Love’s Eternal Masquerad
# 2                                     The Tomorrow Man
# 3                                       Marriage Story
# 4                                        Bones and All
# ..                                                 ...
# 195    Ocean Waves,’ a Tale of Young Love, Ghibli Styl
# 196                                  Dinner in America
# 197          The Harvest,’ Love Is Wielded With a Chil
# 198                                     The Inspection
# 199                        To Live and Decorate in L.A
#
# [200 rows x 17 columns]

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_dataframe['keywords'] = reviews_dataframe['keywords'].apply(extract_keywords)
reviews_dataframe

# note: If this code has been used to convert already, it will fail if trying
# to run it again. If this happens, return to the snippet where we are 
# converting to a pandas data frame.
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2018/01/18/movies/kang...
# 1    https://www.nytimes.com/2013/09/20/movies/jewt...
# 2    https://www.nytimes.com/2019/05/21/movies/the-...
# 3    https://www.nytimes.com/2019/11/05/movies/marr...
# 4    https://www.nytimes.com/2022/11/17/movies/bone...
# ..                                                 ...
# 195  https://www.nytimes.com/2016/12/27/movies/ocea...
# 196  https://www.nytimes.com/2022/05/26/movies/dinn...
# 197  https://www.nytimes.com/2015/04/10/movies/revi...
# 198  https://www.nytimes.com/2022/11/17/movies/the-...
# 199  https://www.nytimes.com/2013/03/22/movies/dorf...
#
#                                                snippet              source  \
# 0    The documentary looks at the mass killings of ...  The New York Times
# 1    In “Jewtopia,” a young man asks a childhood fr...  The New York Times
# 2    Blythe Danner and John Lithgow strain to eleva...  The New York Times
# 3    Adam Driver and Scarlett Johansson self-consci...  The New York Times
# 4    Luca Guadagnino’s latest stars Timothée Chalam...  The New York Times
# ..                                                 ...                 ...
# 195  In a 1993 gem from this revered Japanese anima...  The New York Times
# 196  A rage-fueled rock singer on the run from the ...  The New York Times
# 197  In this film, an orphaned girl’s friendship wi...  The New York Times
# 198  Elegance Bratton’s autobiographical first feat...  The New York Times
# 199  “Dorfman in Love,” directed by Bradley Leong, ...  The New York Times
#
#                                               keywords  \
# 0    creative_works: Kangaroo: A Love-Hate Story (M...
# 1    subject: Movies;persons: Sergei, Ivan;creative...
# 2    subject: Movies;creative_works: The Tomorrow M...
# 3    subject: Movies;persons: Baumbach, Noah;creati...
# 4    subject: Movies;creative_works: Bones and All ...
# ..                                                 ...
# 195  creative_works: Ocean Waves (Movie);subject: A...
# 196  subject: Movies;persons: Rehmeier, Adam;creati...
# 197  subject: Movies;persons: McNaughton, John;pers...
# 198  subject: Movies;creative_works: The Inspection...
# 199  subject: Movies;creative_works: Dorfman in Lov...
#
#                      pub_date  word_count  \
# 0    2018-01-18T12:00:23+0000         263
# 1    2013-09-19T23:33:15+0000         272
# 2    2019-05-21T11:00:01+0000         280
# 3    2019-11-05T19:01:02+0000        1244
# 4    2022-11-17T12:00:06+0000         710
# ..                        ...         ...
# 195  2016-12-27T21:08:58+0000         263
# 196  2022-05-26T11:00:04+0000         254
# 197  2015-04-09T23:37:10+0000         491
# 198  2022-11-17T12:00:07+0000         836
# 199  2013-03-22T00:54:43+0000         250
#
#                                          headline.main headline.kicker  \
# 0    Review: ‘Kangaroo: A Love-Hate Story’ Exposes ...            None
# 1                            Love’s Eternal Masquerade    Movie Review
# 2    ‘The Tomorrow Man’ Review: Love Among the Neur...            None
# 3    ‘Marriage Story’ Review: Dance Me to the End o...   critic’s pick
# 4         ‘Bones and All’ Review: You Eat What You Are            None
# ..                                                 ...             ...
# 195  Review: ‘Ocean Waves,’ a Tale of Young Love, G...            None
# 196  ‘Dinner in America’ Review: A Punk-Rock Love S...            None
# 197  Review: In ‘The Harvest,’ Love Is Wielded With...            None
# 198   ‘The Inspection’ Review: Boot Camp, a Love Story   critic’s pick
# 199                       To Live and Decorate in L.A.    Movie Review
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                          Kangaroo: A Love-Hate Story          None
# 1                                             Jewtopia          None
# 2                   They Whirl, They Twirl, They Tango          None
# 3                     Friendly Split, Shattering Break          None
# 4    It’s Eat, Prey, Love on a Journey of Self-Disc...          None
# ..                                                 ...           ...
# 195            Teenage  Romance,  Flashbacks and Style          None
# 196                                  Dinner in America          None
# 197                         Love, Wielded With a Chill          None
# 198                  A Few Good Men, Some With Secrets          None
# 199                                    Dorfman in Love          None
#
#     headline.seo headline.sub         byline.original  \
# 0           None         None       By Ken Jaworowski
# 1           None         None         By David DeWitt
# 2           None         None  By Jeannette Catsoulis
# 3           None         None           By A.O. Scott
# 4           None         None           By A.O. Scott
# ..           ...          ...                     ...
# 195         None         None          By Glenn Kenny
# 196         None         None   By Concepción de León
# 197         None         None  By Jeannette Catsoulis
# 198         None         None           By A.O. Scott
# 199         None         None         By Andy Webster
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'Ken', 'middlename': None, 'las...                None
# 1    [{'firstname': 'David', 'middlename': None, 'l...                None
# 2    [{'firstname': 'Jeannette', 'middlename': None...                None
# 3    [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 4    [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# ..                                                 ...                 ...
# 195  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 196  [{'firstname': 'Concepción', 'middlename': Non...                None
# 197  [{'firstname': 'Jeannette', 'middlename': None...                None
# 198  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 199  [{'firstname': 'Andy', 'middlename': None, 'la...                None
#
#                                                  title
# 0    Kangaroo: A Love-Hate Story’ Exposes a Wildlif...
# 1                             Love’s Eternal Masquerad
# 2                                     The Tomorrow Man
# 3                                       Marriage Story
# 4                                        Bones and All
# ..                                                 ...
# 195    Ocean Waves,’ a Tale of Young Love, Ghibli Styl
# 196                                  Dinner in America
# 197          The Harvest,’ Love Is Wielded With a Chil
# 198                                     The Inspection
# 199                        To Live and Decorate in L.A
#
# [200 rows x 17 columns]

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
title_list = reviews_dataframe['title'].to_list()
title_list
# Out:
# ['Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr',
#  'Love’s Eternal Masquerad',
#  'The Tomorrow Man',
#  'Marriage Story',
#  'Bones and All',
#  'Love, Antosha',
#  'You Can Live Forever',
#  'Prem Ratan Dhan Payo,’ a Bollywood Tale of a Prince-and-Plebe Doubl',
#  'A Promoter Finds a New Cause: Go',
#  'Now They’ll Love Me, a Twin Sister Scheme',
#  'They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil',
#  'A Journal for Jordan',
#  'A United Kingdom’ With Love That Tested Racial Toleranc',
#  'Sophie and the Rising Sun’ Has Forbidden Love in a Foreboding Tim',
#  'Passengers’ Trapped on a Spaceship Find Love Amid Despai',
#  'Undine',
#  'Waiting for Bojangles',
#  'Love and Unhappiness, in Soft Shades of Gra',
#  'Lost in Paris',
#  'Lost and Love’ (‘Shi Gu’) Stars Andy Lau as a Man Searching for His Lost So',
#  'From This Day Forward’ Attests to Love’s Adaptabilit',
#  'How He Fell in Love,’ an Extramarital Bond Unfold',
#  'Young Love, Interrupted by a Nuclear Bom',
#  'Love the Coopers,’ a Dysfunctional Family Sits Down to Christmas Dinne',
#  'Ma Ma,’ Penélope Cruz as a Cancer Patient Finding Lov',
#  'The Shape of Water’ Is Altogether Wonderfu',
#  'Love After Love,’ an Unflinching Look at Extended Grie',
#  'Love & Mercy’ Gets Inside Brian Wilson’s Hea',
#  'Women Who Kill,’ and May Be in Love With On',
#  'He’s in Love, but No Closer to Figuring It Ou',
#  'Hard Luck Love Song',
#  'See You Then',
#  'Kalank',
#  'Z for Zachariah,’ an End-of-Days Love Triangl',
#  'Your Name Engraved Herein',
#  'Youth,’ the People’s Dance Troupe, in Love and Wa',
#  'Tu Me Manques',
#  'Together',
#  'Alcarràs',
#  'Queen & Slim',
#  'Falling Inn Love',
#  'Tamasha,’ Finding a Path to Love, Show Business and Adulatio',
#  'The Sun Is Also a Star',
#  'Cathedrals of Culture,’ Buildings to Lov',
#  'Book of Love',
#  'My Psychedelic Love Story',
#  'How to Talk to Girls at Parties',
#  'Flowers’ Leaves Three Women Pining for the Same Lost Lov',
#  'All the Bright Places',
#  'Touched With Fire,’ a Love Story Between Two Bipolar Poet',
#  'Cyrano, My Love',
#  'Quincy’ Captures a Lifelong Love Affair With Musi',
#  'Wife of a Spy',
#  'The Mountain Between Us',
#  'Hope Gap',
#  'How to Train Your Dragon: The Hidden World',
#  'Monday',
#  'My Policeman',
#  'Paris 05:59 Théo & Hugo’ Finds Two Men Out to Get Luck',
#  'Ariana Grande: Excuse Me, I Love You',
#  'Love Among the Gas Pump',
#  'A Paragon of Honor, With a Little Time Off for Lov',
#  'Thelma,’ a Woman in Love Can Burn Down the Worl',
#  'Almost Holy’ Demonstrates a Pastor’s Tough Love for Street Kids in Ukrain',
#  'Love & Taxes',
#  'Young Love, the Unrequited Typ',
#  'Where Love Coexists With Deat',
#  'Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem',
#  'Berlin, I Love You',
#  'Godard Mon Amour',
#  'Five Feet Apart',
#  'Kampai! For the Love of Sake’ Celebrates Japan’s Best-Known Libatio',
#  'Two of Us',
#  'Worms, a Botanist and Pigs. Sounds Like a Love Story',
#  'Stay Prayed Up',
#  'Pushing the Usual Button',
#  'Asia',
#  'On the Beach at Night Alone’ Zooms in on a Love Affai',
#  'The In Between',
#  'Anaïs in Love',
#  'I Love My Dad',
#  'Maggie’s Plan,’ Greta Gerwig Aspires to Motherhood on Her Term',
#  'Ordinary Love',
#  'A Dancer Tries Out Many Move',
#  'The Pink Cloud',
#  'Doctor and Patient: A Gothic Love Stor',
#  'Running Against the Wind',
#  'Love and Neuroses in Mamaronec',
#  'Frank & Lola,’ Retreading Old Groun',
#  'Loro',
#  'Asako I & II',
#  'Brothers Retrace Their Holocaust Childhood',
#  'The Attachment Diaries',
#  'A Literary Triumvirate of Love and Lus',
#  'Babyteeth',
#  'The Other Half',
#  'The Brothers Grimsby’: From Sacha, With Lov',
#  'Alleluia’ Follows Partners in Crime, but Not Necessarily in Lov',
#  'Forever My Girl,’ a Romance Resumes After a Long Brea',
#  'You Go to My Head',
#  'Ammonite',
#  'Annette',
#  'Alone Together',
#  'City of Gold',
#  'Love After Love',
#  'The Lobster,’ Colin Farrell Plays a Divorced Man in a Loner-Hating Societ',
#  'How Do I Love Thee? Let Me Count the Wedding',
#  'Finding Love in a Cruel Tim',
#  'Sorry Angel',
#  'Redefining Bollywood Love Storie',
#  'About Fate',
#  'Love & Gelato',
#  'First Love',
#  'Love at First Fight,’ a Romance in the Wil',
#  'The Happiest Day in the Life of Olli Maki,’ Love and Life on the Rope',
#  'Dates Blind and Less So in a Starry Metropoli',
#  'Ride or Die',
#  'Happier Than Ever',
#  'Life and Loves of a Brooklyn Bank Robbe',
#  'Rogers Park,’ Life and Love in a Chicago Neighborhoo',
#  'Love Wedding Repeat',
#  'Love Thy Nature,’ It Takes a Plane',
#  'Is It Love, or Stockholm Syndrome',
#  'Transfixed,’ a Real-Life Love Story, With Complication',
#  'Man in the Kitchen Is Hungry for Lov',
#  'Best Friends, but Wanting Mor',
#  'Sand Dollars,’ Unrequited Love in the Dominican Republi',
#  'Black Mother',
#  'I Love America',
#  'My Love, Don’t Cross That River',
#  'God’s Own Country',
#  'La Mami',
#  'Untogether',
#  'Court the Soul, Pummel the Sexualit',
#  'Deep Water',
#  'Love, Guaranteed',
#  'Leto',
#  'Pretenders',
#  'Love,’ Gaspar Noé’s Romance Told Through Se',
#  'Space Camp — the Style, Not the Plac',
#  'Dina,’ a Differently Abled Love Stor',
#  'Change of Heart for Vietnam War Buddie',
#  'Sea, Sky, Spray and a Love Triangl',
#  'Work, Love and Therapy, in So Many Byte',
#  'Pimp',
#  'Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade',
#  'Love, and Warring Parent',
#  'The Princess of France',
#  'Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen',
#  'Shéhérazade',
#  'Love Hard',
#  'Pamela, a Love Story',
#  'Museum Town',
#  'Future People',
#  'Aulcie',
#  'Submergence,’ a Love Story Sunk by Geopolitic',
#  'Marguerite & Julien,’ a Tale of Siblings in Lov',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'The Party',
#  'To All the Boys: Always and Forever',
#  '69: The Saga of Danny Hernandez',
#  'The Lost Weekend: A Love Story',
#  'Art of Love',
#  'Asher',
#  'Spilling a Love Potion on a Fairy Princes',
#  'Wild Mountain Thyme',
#  'Diane',
#  'The Big Sick,’ Comedy Is Hard, Love Harde',
#  'Luz',
#  'Love in a Time of Quarantin',
#  'Eva,’ Robot Designer Loves Cute Ki',
#  'Pursuing Sex With a Bad Bo',
#  'Lingui, the Sacred Bonds',
#  'Anything to Save Their Pension',
#  'A Ballad for Those Lost in Love and in Prid',
#  'Preparations to Be Together',
#  'For the Love of Spock,’ a Son’s Tribute to Leonard Nimo',
#  'Atlantis',
#  'Little Sister,’ an Aspiring Nun With a Love of Goth Visits Her Troubled Famil',
#  'Thor: Love and Thunder',
#  'A Tuba to Cuba',
#  'Tales of an Immoral Couple’: Love Means Having to Grow U',
#  'The Woman Who Loves Giraffes',
#  'Fitoor’ Enlists Dickens to Tell a Hindi Love Stor',
#  'Burning,’ Love Ignites a Divided Worl',
#  'Sing Street’ Is an ’80s Love Affair, Hair Gel Require',
#  'In From the Side',
#  'Twirling in Oklahoma, a Dervish for Lov',
#  'Women Who Love Their Weapon',
#  'Hot Air',
#  'Solution to His Love Problems?: Baby Formul',
#  'Casanova, Last Love',
#  'Loving,’ They Loved. A Segregated Virginia Did Not Love Them Back',
#  'Remembering the Side of the ’60s That Wasn’t All Peace and Lov',
#  'Dreams of Flight, National Pride and Love à la Bollywoo',
#  'Ocean Waves,’ a Tale of Young Love, Ghibli Styl',
#  'Dinner in America',
#  'The Harvest,’ Love Is Wielded With a Chil',
#  'The Inspection',
#  'To Live and Decorate in L.A']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
title = reviews_dataframe["title"][2]

title = title.replace(" ", "%20")
print(url+title+tmdb_key_string)
selected_film = requests.get(url+title+tmdb_key_string).json()
print(title)
#print(selected_film)
id = str(selected_film['results'][0]["id"])
print(id)
movie_id_url = f"https://api.themoviedb.org/3/movie/{id}?api_key={tmdb_api_key}"
id_find = requests.get(movie_id_url).json()
print([d['name'] for d in id_find["genres"]])
id_find["spoken_languages"]
english_names = [d['english_name'] for d in id_find["spoken_languages"]]
english_names
id_find["production_countries"]
production_countries = [d['name'] for d in id_find["production_countries"]]
production_countries
id_find["release_date"]
# Out:
# https://api.themoviedb.org/3/search/movie?query=The%20Tomorrow%20Man&api_key=5cbad47995205d1b58d64711e0dc111d
# The%20Tomorrow%20Man
# 565391
# ['Drama', 'Romance']
# '2019-05-22'

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1
found_counter = 0
not_found_counter = 0

# Loop through the titles
# I'm a bit confused about this part. Why are we looping through the title
# list? Wouldn't it make more sense to loop through movie titles and not
# review titles?
for title in title_list:

    # Check if we need to sleep before making a request
    if request_counter % 50 == 0:
        print(f"-------Sleeping at {request_counter} requests----------")
        time.sleep(1)

    # in case nothing is found, try replacing spaces with url code:
    #title = title.replace(" ", "%20")
    
    # Add 1 to the request counter
    request_counter += 1
    
    # Perform a "GET" request for The Movie Database
    film_results = requests.get(url+title+tmdb_key_string).json()

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    try:
        # Get movie id
        id = film_results["results"][0]["id"]

        # Make a request for a the full movie details
        movie_url = f"https://api.themoviedb.org/3/movie/{id}?api_key={tmdb_api_key}"
        

        # Execute "GET" request with url
        id_find = requests.get(movie_url).json()
        
        # Extract the genre names into a list
        genre_names = [d['name'] for d in id_find["genres"]]

        # Extract the spoken_languages' English name into a list
        spoken_languages = [d['english_name'] for d in id_find["spoken_languages"]]

        # Extract the production_countries' name into a list
        production_countries = [d['name'] for d in id_find["production_countries"]]

        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        movie_dictionary = {
        'title' : title,
        'original_title' : id_find["original_title"],
        'budget' : id_find["budget"],
        'id' : id,
        'genre': genre_names,
        'language' : id_find["original_language"],
        'homepage' : id_find["homepage"],
        'overview' : id_find["overview"],
        'popularity' : id_find["popularity"],
        'runtime' : id_find["runtime"],
        'revenue' : id_find["revenue"],
        'release_date' : id_find["release_date"],
        'vote_average' : id_find["vote_average"],
        'vote_count' : id_find["vote_count"],
        'spoken_languages': spoken_languages,
        'production_countries': production_countries
        }
        tmdb_movies_list.append(movie_dictionary)
        # Print out the title that was found
        print(f"Found {title}")
        found_counter += 1
    except:
        print(f"{title} not found.")
        not_found_counter += 1
print(f"{found_counter} movies were found")
print(f"{not_found_counter} movies were not found")
# Out:
# Kangaroo: A Love-Hate Story’ Exposes a Wildlife Massacr not found.
# Love’s Eternal Masquerad not found.
# Found The Tomorrow Man
# Found Marriage Story
# Found Bones and All
# Found Love, Antosha
# Found You Can Live Forever
# Prem Ratan Dhan Payo,’ a Bollywood Tale of a Prince-and-Plebe Doubl not found.
# A Promoter Finds a New Cause: Go not found.
# Now They’ll Love Me, a Twin Sister Scheme not found.
# They’ll Love Me When I’m Dead’ Documents Orson Welles’s Last Fil not found.
# Found A Journal for Jordan
# A United Kingdom’ With Love That Tested Racial Toleranc not found.
# Sophie and the Rising Sun’ Has Forbidden Love in a Foreboding Tim not found.
# Passengers’ Trapped on a Spaceship Find Love Amid Despai not found.
# Found Undine
# Found Waiting for Bojangles
# Love and Unhappiness, in Soft Shades of Gra not found.
# Found Lost in Paris
# Lost and Love’ (‘Shi Gu’) Stars Andy Lau as a Man Searching for His Lost So not found.
# From This Day Forward’ Attests to Love’s Adaptabilit not found.
# How He Fell in Love,’ an Extramarital Bond Unfold not found.
# Young Love, Interrupted by a Nuclear Bom not found.
# Love the Coopers,’ a Dysfunctional Family Sits Down to Christmas Dinne not found.
# Ma Ma,’ Penélope Cruz as a Cancer Patient Finding Lov not found.
# The Shape of Water’ Is Altogether Wonderfu not found.
# Love After Love,’ an Unflinching Look at Extended Grie not found.
# Found Love & Mercy’ Gets Inside Brian Wilson’s Hea
# Women Who Kill,’ and May Be in Love With On not found.
# He’s in Love, but No Closer to Figuring It Ou not found.
# Found Hard Luck Love Song
# Found See You Then
# Found Kalank
# Z for Zachariah,’ an End-of-Days Love Triangl not found.
# Found Your Name Engraved Herein
# Youth,’ the People’s Dance Troupe, in Love and Wa not found.
# Found Tu Me Manques
# Found Together
# Found Alcarràs
# Found Queen & Slim
# Found Falling Inn Love
# Tamasha,’ Finding a Path to Love, Show Business and Adulatio not found.
# Found The Sun Is Also a Star
# Cathedrals of Culture,’ Buildings to Lov not found.
# Found Book of Love
# Found My Psychedelic Love Story
# Found How to Talk to Girls at Parties
# Flowers’ Leaves Three Women Pining for the Same Lost Lov not found.
# Found All the Bright Places
# -------Sleeping at 50 requests----------
# Touched With Fire,’ a Love Story Between Two Bipolar Poet not found.
# Found Cyrano, My Love
# Quincy’ Captures a Lifelong Love Affair With Musi not found.
# Found Wife of a Spy
# Found The Mountain Between Us
# Found Hope Gap
# Found How to Train Your Dragon: The Hidden World
# Found Monday
# Found My Policeman
# Found Paris 05:59 Théo & Hugo’ Finds Two Men Out to Get Luck
# Found Ariana Grande: Excuse Me, I Love You
# Love Among the Gas Pump not found.
# A Paragon of Honor, With a Little Time Off for Lov not found.
# Thelma,’ a Woman in Love Can Burn Down the Worl not found.
# Almost Holy’ Demonstrates a Pastor’s Tough Love for Street Kids in Ukrain not found.
# Found Love & Taxes
# Young Love, the Unrequited Typ not found.
# Where Love Coexists With Deat not found.
# Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinem not found.
# Found Berlin, I Love You
# Found Godard Mon Amour
# Found Five Feet Apart
# Kampai! For the Love of Sake’ Celebrates Japan’s Best-Known Libatio not found.
# Found Two of Us
# Worms, a Botanist and Pigs. Sounds Like a Love Story not found.
# Found Stay Prayed Up
# Pushing the Usual Button not found.
# Found Asia
# On the Beach at Night Alone’ Zooms in on a Love Affai not found.
# Found The In Between
# Found Anaïs in Love
# Found I Love My Dad
# Maggie’s Plan,’ Greta Gerwig Aspires to Motherhood on Her Term not found.
# Found Ordinary Love
# A Dancer Tries Out Many Move not found.
# Found The Pink Cloud
# Doctor and Patient: A Gothic Love Stor not found.
# Found Running Against the Wind
# Love and Neuroses in Mamaronec not found.
# Found Frank & Lola,’ Retreading Old Groun
# Found Loro
# Found Asako I & II
# Brothers Retrace Their Holocaust Childhood not found.
# Found The Attachment Diaries
# A Literary Triumvirate of Love and Lus not found.
# Found Babyteeth
# Found The Other Half
# The Brothers Grimsby’: From Sacha, With Lov not found.
# Alleluia’ Follows Partners in Crime, but Not Necessarily in Lov not found.
# Forever My Girl,’ a Romance Resumes After a Long Brea not found.
# -------Sleeping at 100 requests----------
# Found You Go to My Head
# Found Ammonite
# Found Annette
# Found Alone Together
# Found City of Gold
# Found Love After Love
# The Lobster,’ Colin Farrell Plays a Divorced Man in a Loner-Hating Societ not found.
# How Do I Love Thee? Let Me Count the Wedding not found.
# Finding Love in a Cruel Tim not found.
# Found Sorry Angel
# Redefining Bollywood Love Storie not found.
# Found About Fate
# Found Love & Gelato
# Found First Love
# Love at First Fight,’ a Romance in the Wil not found.
# The Happiest Day in the Life of Olli Maki,’ Love and Life on the Rope not found.
# Dates Blind and Less So in a Starry Metropoli not found.
# Found Ride or Die
# Found Happier Than Ever
# Life and Loves of a Brooklyn Bank Robbe not found.
# Rogers Park,’ Life and Love in a Chicago Neighborhoo not found.
# Found Love Wedding Repeat
# Love Thy Nature,’ It Takes a Plane not found.
# Is It Love, or Stockholm Syndrome not found.
# Transfixed,’ a Real-Life Love Story, With Complication not found.
# Man in the Kitchen Is Hungry for Lov not found.
# Best Friends, but Wanting Mor not found.
# Sand Dollars,’ Unrequited Love in the Dominican Republi not found.
# Found Black Mother
# Found I Love America
# Found My Love, Don’t Cross That River
# Found God’s Own Country
# Found La Mami
# Found Untogether
# Court the Soul, Pummel the Sexualit not found.
# Found Deep Water
# Found Love, Guaranteed
# Found Leto
# Found Pretenders
# Love,’ Gaspar Noé’s Romance Told Through Se not found.
# Space Camp — the Style, Not the Plac not found.
# Dina,’ a Differently Abled Love Stor not found.
# Change of Heart for Vietnam War Buddie not found.
# Sea, Sky, Spray and a Love Triangl not found.
# Work, Love and Therapy, in So Many Byte not found.
# Found Pimp
# Hello Again,’ a Movie Musical Ode to Love and Lust Over Decade not found.
# Love, and Warring Parent not found.
# Found The Princess of France
# Woodpeckers,’ a Tale of Love and Agonizing Penal Confinemen not found.
# -------Sleeping at 150 requests----------
# Found Shéhérazade
# Found Love Hard
# Found Pamela, a Love Story
# Found Museum Town
# Found Future People
# Aulcie not found.
# Submergence,’ a Love Story Sunk by Geopolitic not found.
# Found Marguerite & Julien,’ a Tale of Siblings in Lov
# What’s Love Got to Do With It?’ Probably a Lo not found.
# Found The Party
# Found To All the Boys: Always and Forever
# Found 69: The Saga of Danny Hernandez
# Found The Lost Weekend: A Love Story
# Found Art of Love
# Found Asher
# Spilling a Love Potion on a Fairy Princes not found.
# Found Wild Mountain Thyme
# Found Diane
# The Big Sick,’ Comedy Is Hard, Love Harde not found.
# Found Luz
# Love in a Time of Quarantin not found.
# Eva,’ Robot Designer Loves Cute Ki not found.
# Pursuing Sex With a Bad Bo not found.
# Found Lingui, the Sacred Bonds
# Anything to Save Their Pension not found.
# A Ballad for Those Lost in Love and in Prid not found.
# Found Preparations to Be Together
# For the Love of Spock,’ a Son’s Tribute to Leonard Nimo not found.
# Found Atlantis
# Little Sister,’ an Aspiring Nun With a Love of Goth Visits Her Troubled Famil not found.
# Found Thor: Love and Thunder
# Found A Tuba to Cuba
# Tales of an Immoral Couple’: Love Means Having to Grow U not found.
# Found The Woman Who Loves Giraffes
# Fitoor’ Enlists Dickens to Tell a Hindi Love Stor not found.
# Burning,’ Love Ignites a Divided Worl not found.
# Sing Street’ Is an ’80s Love Affair, Hair Gel Require not found.
# Found In From the Side
# Twirling in Oklahoma, a Dervish for Lov not found.
# Women Who Love Their Weapon not found.
# Found Hot Air
# Solution to His Love Problems?: Baby Formul not found.
# Found Casanova, Last Love
# Loving,’ They Loved. A Segregated Virginia Did Not Love Them Back not found.
# Remembering the Side of the ’60s That Wasn’t All Peace and Lov not found.
# Dreams of Flight, National Pride and Love à la Bollywoo not found.
# Ocean Waves,’ a Tale of Young Love, Ghibli Styl not found.
# Found Dinner in America
# The Harvest,’ Love Is Wielded With a Chil not found.
# Found The Inspection
# -------Sleeping at 200 requests----------
# To Live and Decorate in L.A not found.
# 103 movies were found
# 97 movies were not found

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
#for i in range(0,5):
    #print(json.dumps(tmdb_movies_list[i],indent=4))

print(json.dumps(tmdb_movies_list,indent=4))
# Out:
# [
#     {
#         "title": "The Tomorrow Man",
#         "original_title": "The Tomorrow Man",
#         "budget": 0,
#         "id": 565391,
#         "genre": [
#             "Drama",
#             "Romance"
#         ],
#         "language": "en",
#         "homepage": "https://bleeckerstreetmedia.com/thetomorrowman",
#         "overview": "Ed Hemsler spends his life preparing for a disaster that may never come. Ronnie Meisner spends her life shopping for things she may never use. In a small town somewhere in America, these two people will try to find love while trying not to get lost in each other\u2019s stuff.",
#         "popularity": 5.507,
#         "runtime": 94,
#         "revenue": 0,
#         "release_date": "2019-05-22",
#         "vote_average": 5.63,
#         "vote_count": 50,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Marriage Story",
#         "original_title": "Marriage Story",
#         "budget": 18000000,
#         "id": 492188,
#         "genre": [
#             "Drama"
#         ],
#         "language": "en",
#         "homepage": "https://www.marriagestorymovie.com/",
#         "overview": "A stage director and an actress struggle through a grueling, coast-to-coast divorce that pushes them to their personal extremes.",
#         "popularity": 25.424,
#         "runtime": 137,
#         "revenue": 2300000,
#         "release_date": "2019-09-28",
#         "vote_average": 7.749,
#         "vote_count": 6545,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United Kingdom"
#         ]
#     },
#     {
#         "title": "Bones and All",
#         "original_title": "Bones and All",
#         "budget": 18000000,
#         "id": 791177,
#         "genre": [
#             "Drama",
#             "Horror",
#             "Romance"
#         ],
#         "language": "it",
#         "homepage": "https://www.bonesandallfilm.net/",
#         "overview": "Abandoned by her father, a young woman embarks on a thousand-mile odyssey through the backroads of America where she meets a disenfranchised drifter. But despite their best efforts, all roads lead back to their terrifying pasts and to a final stand that will determine whether their love can survive their otherness.",
#         "popularity": 22.87,
#         "runtime": 131,
#         "revenue": 15100000,
#         "release_date": "2022-11-18",
#         "vote_average": 7.128,
#         "vote_count": 1070,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "Italy",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Love, Antosha",
#         "original_title": "Love, Antosha",
#         "budget": 0,
#         "id": 565276,
#         "genre": [
#             "Documentary"
#         ],
#         "language": "en",
#         "homepage": "https://antonyelchindoc.com/",
#         "overview": "From a prolific career in film and television, Anton Yelchin left an indelible legacy as an actor. Through his journals and other writings, his photography, the original music he wrote, and interviews with his family, friends, and colleagues, this film looks not just at Anton's impressive career, but at a broader portrait of the man.",
#         "popularity": 10.22,
#         "runtime": 92,
#         "revenue": 0,
#         "release_date": "2019-08-02",
#         "vote_average": 7.4,
#         "vote_count": 48,
#         "spoken_languages": [
#             "English",
#             "Russian"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "You Can Live Forever",
#         "original_title": "You Can Live Forever",
#         "budget": 0,
#         "id": 887580,
#         "genre": [
#             "Drama",
#             "Romance"
#         ],
#         "language": "en",
#         "homepage": "https://gooddeedentertainment.com/you-can-live-forever/",
#         "overview": "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.",
#         "popularity": 7.338,
#         "runtime": 96,
#         "revenue": 0,
#         "release_date": "2022-06-11",
#         "vote_average": 7.263,
#         "vote_count": 38,
#         "spoken_languages": [
#             "French",
#             "English"
#         ],
#         "production_countries": [
#             "Canada"
#         ]
#     },
#     {
#         "title": "A Journal for Jordan",
#         "original_title": "A Journal for Jordan",
#         "budget": 25000000,
#         "id": 501841,
#         "genre": [
#             "Drama",
#             "Romance"
#         ],
#         "language": "en",
#         "homepage": "https://www.sonypictures.com/movies/ajournalforjordan",
#         "overview": "Based on the true story of First Sergeant Charles Monroe King, a soldier deployed to Iraq begins to keep a journal of love and advice for his infant son. Back at home, senior New York Times editor Dana Canedy revisits the story of her unlikely, life-altering relationship with King and his enduring devotion to her and their child.",
#         "popularity": 10.752,
#         "runtime": 131,
#         "revenue": 6700000,
#         "release_date": "2021-12-22",
#         "vote_average": 7.2,
#         "vote_count": 92,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "Canada",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Undine",
#         "original_title": "Undine",
#         "budget": 0,
#         "id": 615761,
#         "genre": [
#             "Fantasy",
#             "Drama",
#             "Romance"
#         ],
#         "language": "de",
#         "homepage": "https://www.the-match-factory.com/catalogue/films/undine.html",
#         "overview": "Undine is a historian and tour guide at the Berlin City Museum specializing in urban development, while Christoph is an industrial diver. Linked by a love of the water, the two form an intense bond, which can only do so much to help Undine overcome the considerable baggage of her former affair.",
#         "popularity": 15.048,
#         "runtime": 90,
#         "revenue": 0,
#         "release_date": "2020-07-01",
#         "vote_average": 6.513,
#         "vote_count": 194,
#         "spoken_languages": [
#             "English",
#             "German",
#             "Spanish"
#         ],
#         "production_countries": [
#             "France",
#             "Germany"
#         ]
#     },
#     {
#         "title": "Waiting for Bojangles",
#         "original_title": "En attendant Bojangles",
#         "budget": 0,
#         "id": 851303,
#         "genre": [
#             "Drama",
#             "Comedy",
#             "Romance"
#         ],
#         "language": "fr",
#         "homepage": "",
#         "overview": "A boy and his eccentric parents leave their home in Paris for a country house in Spain. As the mother descends deeper into her own mind, it's up to the boy and his father to keep her safe and happy.",
#         "popularity": 13.273,
#         "runtime": 124,
#         "revenue": 0,
#         "release_date": "2021-10-13",
#         "vote_average": 7.422,
#         "vote_count": 275,
#         "spoken_languages": [
#             "French",
#             "English"
#         ],
#         "production_countries": [
#             "France",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Lost in Paris",
#         "original_title": "Paris pieds nus",
#         "budget": 0,
#         "id": 413778,
#         "genre": [
#             "Comedy"
#         ],
#         "language": "fr",
#         "homepage": "",
#         "overview": "Fiona visits Paris for the first time to assist her myopic Aunt Martha. Catastrophes ensue, mainly involving Dom, a homeless man who has yet to have an emotion or thought he was afraid of expressing.",
#         "popularity": 5.866,
#         "runtime": 83,
#         "revenue": 0,
#         "release_date": "2017-01-14",
#         "vote_average": 6.05,
#         "vote_count": 109,
#         "spoken_languages": [
#             "French"
#         ],
#         "production_countries": [
#             "Belgium",
#             "France"
#         ]
#     },
#     {
#         "title": "Love & Mercy\u2019 Gets Inside Brian Wilson\u2019s Hea",
#         "original_title": "\u0e25\u0e2d\u0e07 \u0e25\u0e35\u0e1f \u0e40\u0e25\u0e34\u0e1f\u0e27\u0e4c",
#         "budget": 0,
#         "id": 1026961,
#         "genre": [
#             "Romance",
#             "Comedy"
#         ],
#         "language": "th",
#         "homepage": "https://longlivelovethailanddrama.splashthat.com",
#         "overview": "A story about a party-animal Sati, a man whose attitude has left a broken family at home. Meta, his wife, is preparing to leave him. At age 15, his daughter, Namo is already jaded from a lifetime of broken promises.",
#         "popularity": 25.972,
#         "runtime": 135,
#         "revenue": 2122023,
#         "release_date": "2023-06-29",
#         "vote_average": 8.133,
#         "vote_count": 15,
#         "spoken_languages": [
#             "Thai"
#         ],
#         "production_countries": [
#             "Thailand"
#         ]
#     },
#     {
#         "title": "Hard Luck Love Song",
#         "original_title": "Hard Luck Love Song",
#         "budget": 0,
#         "id": 536208,
#         "genre": [
#             "Romance",
#             "Music",
#             "Drama",
#             "Thriller"
#         ],
#         "language": "en",
#         "homepage": "http://HardLuckLoveSong.com",
#         "overview": "Jesse, a charismatic but down on his luck troubadour, finds himself at an existential crossroads as bad choices catch up with him during an unexpected reunion with Carla, an old flame.",
#         "popularity": 3.988,
#         "runtime": 104,
#         "revenue": 0,
#         "release_date": "2021-10-15",
#         "vote_average": 5.0,
#         "vote_count": 8,
#         "spoken_languages": [
#             "English",
#             "Spanish"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "See You Then",
#         "original_title": "See You Then",
#         "budget": 0,
#         "id": 794903,
#         "genre": [
#             "Drama"
#         ],
#         "language": "en",
#         "homepage": "https://vanishingangle.com/see-you-then",
#         "overview": "A decade after abruptly breaking up with Naomi, Kris invites her to a dinner to catch-up on their complicated lives, relationships, and Kris' transition.",
#         "popularity": 1.906,
#         "runtime": 74,
#         "revenue": 0,
#         "release_date": "2022-04-01",
#         "vote_average": 2.5,
#         "vote_count": 2,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Kalank",
#         "original_title": "\u0915\u0932\u0902\u0915",
#         "budget": 0,
#         "id": 556271,
#         "genre": [
#             "Drama",
#             "Romance"
#         ],
#         "language": "hi",
#         "homepage": "",
#         "overview": "Set in 1945, in Pre-Independent India, the elite, opulent and solemn world of the Chaudhry family, and the wild, mysterious and musical underbelly of the town, Hira Mandi, clash when Roop Chaudhry encounters Zafar, a daredevil from Hira Mandi, unleashing deep-buried truths, secrets of betrayal and affairs that threaten to bring both worlds crashing down.",
#         "popularity": 6.878,
#         "runtime": 166,
#         "revenue": 0,
#         "release_date": "2019-04-17",
#         "vote_average": 5.466,
#         "vote_count": 44,
#         "spoken_languages": [
#             "Hindi"
#         ],
#         "production_countries": [
#             "India"
#         ]
#     },
#     {
#         "title": "Your Name Engraved Herein",
#         "original_title": "\u523b\u5728\u4f60\u5fc3\u5e95\u7684\u540d\u5b57",
#         "budget": 0,
#         "id": 719410,
#         "genre": [
#             "Romance",
#             "Drama"
#         ],
#         "language": "zh",
#         "homepage": "",
#         "overview": "In 1987, as martial law ends in Taiwan, Jia-han and Birdy fall in love amid family pressure, homophobia and social stigma.",
#         "popularity": 20.357,
#         "runtime": 114,
#         "revenue": 0,
#         "release_date": "2020-09-30",
#         "vote_average": 7.885,
#         "vote_count": 227,
#         "spoken_languages": [
#             "Mandarin",
#             "English"
#         ],
#         "production_countries": [
#             "Taiwan",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Tu Me Manques",
#         "original_title": "Tu me manques",
#         "budget": 0,
#         "id": 612437,
#         "genre": [
#             "Drama",
#             "Romance"
#         ],
#         "language": "es",
#         "homepage": "",
#         "overview": "Following his son Gabriel\u2019s death, Jorge travels from conservative Bolivia to New York City to confront Gabriel\u2019s boyfriend Sebastian. While the two battle over Jorge\u2019s inability to accept his son, Sebastian channels his grief into a bold new play in honor of his lost love, in which Gabriel\u2019s inner turmoil is transformed into an eye-popping gay fantasia.",
#         "popularity": 4.146,
#         "runtime": 105,
#         "revenue": 0,
#         "release_date": "2019-07-27",
#         "vote_average": 6.9,
#         "vote_count": 21,
#         "spoken_languages": [
#             "English",
#             "Spanish"
#         ],
#         "production_countries": [
#             "Bolivia",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Together",
#         "original_title": "Trolls Band Together",
#         "budget": 95000000,
#         "id": 901362,
#         "genre": [
#             "Animation",
#             "Family",
#             "Music",
#             "Fantasy",
#             "Comedy"
#         ],
#         "language": "en",
#         "homepage": "https://www.dreamworks.com/movies/trolls-band-together",
#         "overview": "When Branch's brother, Floyd, is kidnapped for his musical talents by a pair of nefarious pop-star villains, Branch and Poppy embark on a harrowing and emotional journey to reunite the other brothers and rescue Floyd from a fate even worse than pop-culture obscurity.",
#         "popularity": 1710.225,
#         "runtime": 92,
#         "revenue": 161200000,
#         "release_date": "2023-10-12",
#         "vote_average": 7.181,
#         "vote_count": 279,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Alcarr\u00e0s",
#         "original_title": "Alcarr\u00e0s",
#         "budget": 0,
#         "id": 804251,
#         "genre": [
#             "Drama"
#         ],
#         "language": "ca",
#         "homepage": "https://www.alcarras-film.com/",
#         "overview": "In a small village in Catalonia, the peach farmers of the Sol\u00e9 family spend every summer together picking fruit from their orchard. But when plans arise to install solar panels and cut down trees, the members of this tight-knit group suddenly face eviction \u2013 and the loss of far more than their home.",
#         "popularity": 8.75,
#         "runtime": 120,
#         "revenue": 0,
#         "release_date": "2022-04-29",
#         "vote_average": 6.888,
#         "vote_count": 156,
#         "spoken_languages": [
#             "Catalan"
#         ],
#         "production_countries": [
#             "Spain"
#         ]
#     },
#     {
#         "title": "Queen & Slim",
#         "original_title": "\u0397 \u039c\u03b1\u03cd\u03c1\u03b7 \u0395\u03bc\u03bc\u03b1\u03bd\u03bf\u03c5\u03ad\u03bb\u03b1",
#         "budget": 0,
#         "id": 40108,
#         "genre": [
#             "Crime",
#             "Drama"
#         ],
#         "language": "el",
#         "homepage": "",
#         "overview": "After years of abuse at the hands of her husband, a woman, Emmanouella, is pushed to the breaking point. She hires a hitman to do in her husband, but just when she thinks her troubles are at an end, the assassin blackmails her. As her husband's business partner struggles to prove her guilt, and as the hitman continues to threaten her new found security, Emmanouella struggles to keep her name clear and to keep her naive stepdaughter from becoming tangled in the web of danger she has created.",
#         "popularity": 63.718,
#         "runtime": 91,
#         "revenue": 0,
#         "release_date": "1980-03-12",
#         "vote_average": 6.058,
#         "vote_count": 69,
#         "spoken_languages": [
#             "Greek",
#             "Italian"
#         ],
#         "production_countries": [
#             "Cyprus",
#             "Greece"
#         ]
#     },
#     {
#         "title": "Falling Inn Love",
#         "original_title": "Falling Inn Love",
#         "budget": 0,
#         "id": 623195,
#         "genre": [
#             "Romance",
#             "Comedy"
#         ],
#         "language": "en",
#         "homepage": "https://www.netflix.com/title/80999781",
#         "overview": "When a San Francisco exec wins a New Zealand inn, she ditches city life to remodel and flip the rustic property with help from a handsome contractor.",
#         "popularity": 14.701,
#         "runtime": 98,
#         "revenue": 0,
#         "release_date": "2019-08-29",
#         "vote_average": 6.522,
#         "vote_count": 1097,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "The Sun Is Also a Star",
#         "original_title": "The Sun Is Also a Star",
#         "budget": 9000000,
#         "id": 508791,
#         "genre": [
#             "Romance",
#             "Drama"
#         ],
#         "language": "en",
#         "homepage": "https://www.thesunisalsoastarmovie.com",
#         "overview": "Two young New Yorkers begin to fall in love over the course of a single day, as a series of potentially life-altering meetings loom over their heads - hers concerning her family\u2019s deportation to Jamaica, and his concerning an education at Dartmouth.",
#         "popularity": 18.156,
#         "runtime": 100,
#         "revenue": 6800000,
#         "release_date": "2019-05-16",
#         "vote_average": 7.0,
#         "vote_count": 558,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Book of Love",
#         "original_title": "Book of Love",
#         "budget": 0,
#         "id": 892835,
#         "genre": [
#             "Comedy",
#             "Romance"
#         ],
#         "language": "en",
#         "homepage": "",
#         "overview": "Henry, an English writer who has written a new book that has become a failure in the U.K, gets notified that the dull book has been highly trending over in Mexico. Little does he know that Maria, a Spanish translator, turned the book into an erotic novel. Henry and Maria then swerve around Mexico to do a book tour and go through a wind of events.",
#         "popularity": 9.07,
#         "runtime": 106,
#         "revenue": 398876,
#         "release_date": "2022-01-06",
#         "vote_average": 5.6,
#         "vote_count": 105,
#         "spoken_languages": [
#             "English",
#             "Spanish"
#         ],
#         "production_countries": [
#             "Mexico",
#             "United Kingdom",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "My Psychedelic Love Story",
#         "original_title": "My Psychedelic Love Story",
#         "budget": 0,
#         "id": 750595,
#         "genre": [
#             "Documentary"
#         ],
#         "language": "en",
#         "homepage": "https://www.sho.com/titles/3497302/my-psychedelic-love-story",
#         "overview": "An examination of the notorious high priest of LSD Timothy Leary through the eyes of his famed lover Joanna Harcourt-Smith.",
#         "popularity": 1.319,
#         "runtime": 107,
#         "revenue": 0,
#         "release_date": "2020-10-22",
#         "vote_average": 6.0,
#         "vote_count": 5,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "How to Talk to Girls at Parties",
#         "original_title": "How to Talk to Girls at Parties",
#         "budget": 0,
#         "id": 341689,
#         "genre": [
#             "Comedy",
#             "Music",
#             "Romance",
#             "Science Fiction"
#         ],
#         "language": "en",
#         "homepage": "https://a24films.com/films/how-to-talk-to-girls-at-parties",
#         "overview": "In 1970s London, a teenage outsider named Enn falls in love with a rebellious alien girl named Zan, who has come to Earth for a party. Together, they navigate the complexities of intergalactic culture and the trials of first love.",
#         "popularity": 9.536,
#         "runtime": 103,
#         "revenue": 0,
#         "release_date": "2017-10-06",
#         "vote_average": 6.047,
#         "vote_count": 352,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United Kingdom",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "All the Bright Places",
#         "original_title": "All the Bright Places",
#         "budget": 0,
#         "id": 342470,
#         "genre": [
#             "Romance",
#             "Drama"
#         ],
#         "language": "en",
#         "homepage": "https://www.netflix.com/title/80208802",
#         "overview": "Two teens facing personal struggles form a powerful bond as they embark on a cathartic journey chronicling the wonders of Indiana.",
#         "popularity": 26.029,
#         "runtime": 108,
#         "revenue": 0,
#         "release_date": "2020-02-28",
#         "vote_average": 7.7,
#         "vote_count": 2720,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Cyrano, My Love",
#         "original_title": "Edmond",
#         "budget": 0,
#         "id": 544510,
#         "genre": [
#             "Comedy",
#             "History"
#         ],
#         "language": "fr",
#         "homepage": "http://roadsideattractions.com/filmography/cyranomylove",
#         "overview": "Paris, France, December 1897. The young playwright Edmond Rostand feels like a failure. Inspiration has abandoned him. Married and father of two children, desperate and penniless, he persuades the great actor Constant Coquelin to perform the main role in his new play. But there is a problem: Coquelin wants to premiere it at Christmas and Edmond has not written a single word.",
#         "popularity": 8.618,
#         "runtime": 113,
#         "revenue": 0,
#         "release_date": "2018-11-10",
#         "vote_average": 7.5,
#         "vote_count": 464,
#         "spoken_languages": [
#             "French",
#             "Russian"
#         ],
#         "production_countries": [
#             "Belgium",
#             "France"
#         ]
#     },
#     {
#         "title": "Wife of a Spy",
#         "original_title": "\u30b9\u30d1\u30a4\u306e\u59bb",
#         "budget": 0,
#         "id": 688301,
#         "genre": [
#             "Drama",
#             "War",
#             "Thriller"
#         ],
#         "language": "ja",
#         "homepage": "https://intl.nikkatsu.com/sales/358.html",
#         "overview": "It\u2019s 1940, and the population of Japan is divided over its entry into World War II. Satoko, the wife of a fabric merchant, is devoted to her husband but is beginning to suspect he\u2019s up to something. Soon she allows herself to be drawn into a game in which she enigmatically conceals her intentions.",
#         "popularity": 13.631,
#         "runtime": 114,
#         "revenue": 0,
#         "release_date": "2020-10-16",
#         "vote_average": 6.5,
#         "vote_count": 75,
#         "spoken_languages": [
#             "English",
#             "Japanese"
#         ],
#         "production_countries": [
#             "Japan"
#         ]
#     },
#     {
#         "title": "The Mountain Between Us",
#         "original_title": "The Mountain Between Us",
#         "budget": 35000000,
#         "id": 290512,
#         "genre": [
#             "Drama",
#             "Adventure",
#             "Romance"
#         ],
#         "language": "en",
#         "homepage": "http://MountainBetweenUs.com",
#         "overview": "Stranded on a mountain after a tragic plane crash, two strangers must work together to endure the extreme elements of the remote, snow-covered terrain. When they realize help is not coming, they embark on a perilous journey across hundreds of miles of wilderness, pushing each other to survive and discovering their inner strength.",
#         "popularity": 26.194,
#         "runtime": 109,
#         "revenue": 62832209,
#         "release_date": "2017-10-05",
#         "vote_average": 6.6,
#         "vote_count": 2201,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Hope Gap",
#         "original_title": "Hope Gap",
#         "budget": 0,
#         "id": 537140,
#         "genre": [
#             "Drama"
#         ],
#         "language": "en",
#         "homepage": "https://www.originpictures.co.uk/hope-gap",
#         "overview": "A couple's visit with their son takes a dramatic turn when the father tells him he plans on leaving his mother.",
#         "popularity": 8.987,
#         "runtime": 100,
#         "revenue": 1136167,
#         "release_date": "2019-10-03",
#         "vote_average": 6.346,
#         "vote_count": 114,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United Kingdom",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "How to Train Your Dragon: The Hidden World",
#         "original_title": "How to Train Your Dragon: The Hidden World",
#         "budget": 129000000,
#         "id": 166428,
#         "genre": [
#             "Animation",
#             "Family",
#             "Adventure"
#         ],
#         "language": "en",
#         "homepage": "https://www.howtotrainyourdragon.com/",
#         "overview": "As Hiccup fulfills his dream of creating a peaceful dragon utopia, Toothless\u2019 discovery of an untamed, elusive mate draws the Night Fury away. When danger mounts at home and Hiccup\u2019s reign as village chief is tested, both dragon and rider must make impossible decisions to save their kind.",
#         "popularity": 61.277,
#         "runtime": 104,
#         "revenue": 524580592,
#         "release_date": "2019-01-03",
#         "vote_average": 7.8,
#         "vote_count": 5899,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Monday",
#         "original_title": "Monday",
#         "budget": 0,
#         "id": 550524,
#         "genre": [
#             "Drama",
#             "Romance"
#         ],
#         "language": "en",
#         "homepage": "https://www.monday.movie",
#         "overview": "A spark on a Friday can lead to a sizzling weekend fling, but what happens when you get to the inevitable Monday?",
#         "popularity": 10.83,
#         "runtime": 116,
#         "revenue": 0,
#         "release_date": "2020-09-11",
#         "vote_average": 6.666,
#         "vote_count": 151,
#         "spoken_languages": [
#             "English",
#             "Greek"
#         ],
#         "production_countries": [
#             "Greece",
#             "United Kingdom",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "My Policeman",
#         "original_title": "My Policeman",
#         "budget": 0,
#         "id": 744114,
#         "genre": [
#             "Drama",
#             "Romance"
#         ],
#         "language": "en",
#         "homepage": "https://www.amazon.com/dp/B09Y8SHDPD",
#         "overview": "In the late 1990s, the arrival of elderly invalid Patrick into Marion and Tom\u2019s home triggers the exploration of seismic events from 40 years previous: the passionate relationship between Tom and Patrick at a time when homosexuality was illegal.",
#         "popularity": 13.643,
#         "runtime": 113,
#         "revenue": 0,
#         "release_date": "2022-10-20",
#         "vote_average": 7.761,
#         "vote_count": 593,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United Kingdom",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Paris 05:59 Th\u00e9o & Hugo\u2019 Finds Two Men Out to Get Luck",
#         "original_title": "Th\u00e9o et Hugo dans le m\u00eame bateau",
#         "budget": 0,
#         "id": 382892,
#         "genre": [
#             "Drama"
#         ],
#         "language": "fr",
#         "homepage": "",
#         "overview": "Th\u00e9o and Hugo meet in a club and form an immediate bond. Once the desire and elation of this first moment has passed, the two young men, now sober, wander through the empty streets of nocturnal Paris, having to confront the love they sense blossoming between them.",
#         "popularity": 9.676,
#         "runtime": 97,
#         "revenue": 0,
#         "release_date": "2016-04-27",
#         "vote_average": 6.825,
#         "vote_count": 97,
#         "spoken_languages": [
#             "French"
#         ],
#         "production_countries": [
#             "France"
#         ]
#     },
#     {
#         "title": "Ariana Grande: Excuse Me, I Love You",
#         "original_title": "ariana grande: excuse me, i love you",
#         "budget": 0,
#         "id": 774372,
#         "genre": [
#             "Music",
#             "Documentary"
#         ],
#         "language": "en",
#         "homepage": "https://www.netflix.com/title/81238721",
#         "overview": "Ariana Grande takes the stage in London for her Sweetener World Tour and shares a behind-the-scenes look at her life in rehearsal and on the road.",
#         "popularity": 11.98,
#         "runtime": 97,
#         "revenue": 0,
#         "release_date": "2020-12-21",
#         "vote_average": 8.1,
#         "vote_count": 334,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Love & Taxes",
#         "original_title": "\u0e25\u0e2d\u0e07 \u0e25\u0e35\u0e1f \u0e40\u0e25\u0e34\u0e1f\u0e27\u0e4c",
#         "budget": 0,
#         "id": 1026961,
#         "genre": [
#             "Romance",
#             "Comedy"
#         ],
#         "language": "th",
#         "homepage": "https://longlivelovethailanddrama.splashthat.com",
#         "overview": "A story about a party-animal Sati, a man whose attitude has left a broken family at home. Meta, his wife, is preparing to leave him. At age 15, his daughter, Namo is already jaded from a lifetime of broken promises.",
#         "popularity": 25.972,
#         "runtime": 135,
#         "revenue": 2122023,
#         "release_date": "2023-06-29",
#         "vote_average": 8.133,
#         "vote_count": 15,
#         "spoken_languages": [
#             "Thai"
#         ],
#         "production_countries": [
#             "Thailand"
#         ]
#     },
#     {
#         "title": "Berlin, I Love You",
#         "original_title": "Berlin, I Love You",
#         "budget": 0,
#         "id": 401686,
#         "genre": [
#             "Drama"
#         ],
#         "language": "en",
#         "homepage": "",
#         "overview": "An anthology feature of 10 stories of romance set in the German capital.",
#         "popularity": 7.791,
#         "runtime": 120,
#         "revenue": 163908,
#         "release_date": "2019-02-08",
#         "vote_average": 4.7,
#         "vote_count": 73,
#         "spoken_languages": [
#             "English",
#             "German"
#         ],
#         "production_countries": [
#             "Germany",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Godard Mon Amour",
#         "original_title": "Le Redoutable",
#         "budget": 12840746,
#         "id": 416186,
#         "genre": [
#             "Drama",
#             "Romance",
#             "Comedy"
#         ],
#         "language": "fr",
#         "homepage": "",
#         "overview": "In 1967, during the making of \u201cLa Chinoise,\u201d film director Jean-Luc Godard falls in love with 19-year-old actress Anne Wiazemsky and marries her.",
#         "popularity": 11.216,
#         "runtime": 108,
#         "revenue": 82264,
#         "release_date": "2017-06-24",
#         "vote_average": 6.661,
#         "vote_count": 330,
#         "spoken_languages": [
#             "Czech",
#             "French",
#             "English",
#             "Italian"
#         ],
#         "production_countries": [
#             "Myanmar",
#             "France"
#         ]
#     },
#     {
#         "title": "Five Feet Apart",
#         "original_title": "Five Feet Apart",
#         "budget": 7000000,
#         "id": 527641,
#         "genre": [
#             "Romance",
#             "Drama"
#         ],
#         "language": "en",
#         "homepage": "",
#         "overview": "Seventeen-year-old Stella spends most of her time in the hospital as a cystic fibrosis patient. Her life is full of routines, boundaries and self-control \u2014 all of which get put to the test when she meets Will, an impossibly charming teen who has the same illness. There's an instant flirtation, though restrictions dictate that they must maintain a safe distance between them. As their connection intensifies, so does the temptation to throw the rules out the window and embrace that attraction.",
#         "popularity": 40.528,
#         "runtime": 116,
#         "revenue": 92600000,
#         "release_date": "2019-03-14",
#         "vote_average": 8.282,
#         "vote_count": 5304,
#         "spoken_languages": [
#             "English",
#             "Spanish",
#             "French"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Two of Us",
#         "original_title": "L'Amour et les For\u00eats",
#         "budget": 0,
#         "id": 989672,
#         "genre": [
#             "Thriller",
#             "Drama",
#             "Romance"
#         ],
#         "language": "fr",
#         "homepage": "",
#         "overview": "When Blanche meets Gr\u00e9goire, she thinks she has found the one. The ties that bind them grow quickly, and a passionate affair ensues. Together, they relocate. For Blanche, far from her family, from her twin sister, Rose, a new life begins. But little by little, she finds herself caught in the grip of a deeply possessive and dangerous man.",
#         "popularity": 15.491,
#         "runtime": 105,
#         "revenue": 0,
#         "release_date": "2023-05-24",
#         "vote_average": 7.039,
#         "vote_count": 141,
#         "spoken_languages": [
#             "French"
#         ],
#         "production_countries": [
#             "France"
#         ]
#     },
#     {
#         "title": "Stay Prayed Up",
#         "original_title": "Stay Prayed Up",
#         "budget": 0,
#         "id": 869628,
#         "genre": [
#             "Documentary"
#         ],
#         "language": "en",
#         "homepage": "",
#         "overview": "Lena Mae \u201cMother\u201d Perry, the backbone of her community, cooks for crowds, tends to the needy, and boy, can she sing! After 50 years leading the dynamic, down-home gospel group The Branchettes, the octogenarian powerhouse, armed with her unwavering faith, shows no signs of slowing down. Taking us inside her loving community while following the recording of the group\u2019s first album, this film is bursting with warmth, joy, and soul-stirring gospel music.",
#         "popularity": 0.6,
#         "runtime": 73,
#         "revenue": 0,
#         "release_date": "2021-09-01",
#         "vote_average": 0.0,
#         "vote_count": 0,
#         "spoken_languages": [],
#         "production_countries": []
#     },
#     {
#         "title": "Asia",
#         "original_title": "2019 GFRIEND ASIA TOUR 'GO GO GFRIEND!'",
#         "budget": 0,
#         "id": 684527,
#         "genre": [
#             "Music"
#         ],
#         "language": "ko",
#         "homepage": "",
#         "overview": "Go Go GFriend! is GFriend's 2nd Asia tour. The tour was held at South Korea, Malaysia, Singapore, Thailand, Hong Kong, Indonesia, Philippines, Taiwan, and Japan.",
#         "popularity": 3.234,
#         "runtime": 170,
#         "revenue": 0,
#         "release_date": "2019-05-19",
#         "vote_average": 7.344,
#         "vote_count": 32,
#         "spoken_languages": [
#             "Korean"
#         ],
#         "production_countries": []
#     },
#     {
#         "title": "The In Between",
#         "original_title": "The In Between",
#         "budget": 0,
#         "id": 818750,
#         "genre": [
#             "Romance",
#             "Science Fiction",
#             "Drama"
#         ],
#         "language": "en",
#         "homepage": "https://www.netflix.com/title/81447264",
#         "overview": "After surviving a car accident that took the life of her boyfriend, a teenage girl believes he's attempting to reconnect with her from the after world.",
#         "popularity": 29.827,
#         "runtime": 116,
#         "revenue": 0,
#         "release_date": "2022-02-11",
#         "vote_average": 7.389,
#         "vote_count": 637,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Ana\u00efs in Love",
#         "original_title": "Les Amours d\u2019Ana\u00efs",
#         "budget": 0,
#         "id": 781453,
#         "genre": [
#             "Drama",
#             "Romance",
#             "Comedy"
#         ],
#         "language": "fr",
#         "homepage": "",
#         "overview": "A young woman struggling to stay on top of everything in her life meets a married publisher and begins an affair with him.",
#         "popularity": 9.235,
#         "runtime": 98,
#         "revenue": 0,
#         "release_date": "2021-09-15",
#         "vote_average": 6.234,
#         "vote_count": 128,
#         "spoken_languages": [
#             "French"
#         ],
#         "production_countries": [
#             "France"
#         ]
#     },
#     {
#         "title": "I Love My Dad",
#         "original_title": "I Love My Dad",
#         "budget": 0,
#         "id": 876825,
#         "genre": [
#             "Comedy"
#         ],
#         "language": "en",
#         "homepage": "http://www.magpictures.com/ilovemydad/",
#         "overview": "A hopelessly estranged father catfishes his son in an attempt to reconnect.",
#         "popularity": 9.975,
#         "runtime": 90,
#         "revenue": 0,
#         "release_date": "2022-08-05",
#         "vote_average": 5.763,
#         "vote_count": 40,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Ordinary Love",
#         "original_title": "Ordinary Love",
#         "budget": 0,
#         "id": 588787,
#         "genre": [
#             "Drama",
#             "Romance"
#         ],
#         "language": "en",
#         "homepage": "https://bleeckerstreetmedia.com/ordinary-love-film",
#         "overview": "An extraordinary look at the lives of a middle-aged couple in the midst of the wife's breast cancer diagnosis.",
#         "popularity": 13.049,
#         "runtime": 92,
#         "revenue": 0,
#         "release_date": "2019-12-06",
#         "vote_average": 6.861,
#         "vote_count": 126,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "Ireland",
#             "United Kingdom"
#         ]
#     },
#     {
#         "title": "The Pink Cloud",
#         "original_title": "A Nuvem Rosa",
#         "budget": 0,
#         "id": 776490,
#         "genre": [
#             "Drama",
#             "Science Fiction"
#         ],
#         "language": "pt",
#         "homepage": "",
#         "overview": "Giovana and Yago are strangers who share a spark after meeting at a party. When a deadly cloud mysteriously takes over their city, they are forced to seek shelter with only each other for company. As months pass and the planet settles into an extended quarantine, their world shrinks, and they are forced to come to terms with an accelerated timeline for their relationship. With all their other interactions governed by screens, and with the strain of isolation setting in, Giovana and Yago struggle to reinvent themselves and reconcile the differences that threaten to tear them apart.",
#         "popularity": 2.638,
#         "runtime": 105,
#         "revenue": 0,
#         "release_date": "2021-04-01",
#         "vote_average": 6.02,
#         "vote_count": 25,
#         "spoken_languages": [
#             "Portuguese"
#         ],
#         "production_countries": [
#             "Brazil"
#         ]
#     },
#     {
#         "title": "Running Against the Wind",
#         "original_title": "\u12e8\u1290\u134b\u1231 \u134d\u120d\u121a\u12eb",
#         "budget": 0,
#         "id": 631831,
#         "genre": [
#             "Drama"
#         ],
#         "language": "am",
#         "homepage": "",
#         "overview": "The film follows the fate of two boys, one of whom hopes to become an Olympic runner and the other a photographer.",
#         "popularity": 2.247,
#         "runtime": 112,
#         "revenue": 0,
#         "release_date": "2023-07-20",
#         "vote_average": 6.5,
#         "vote_count": 0,
#         "spoken_languages": [
#             "Amharic"
#         ],
#         "production_countries": [
#             "Ethiopia",
#             "Germany"
#         ]
#     },
#     {
#         "title": "Frank & Lola,\u2019 Retreading Old Groun",
#         "original_title": "Cuando Frank conoci\u00f3 a Carlitos",
#         "budget": 0,
#         "id": 1158529,
#         "genre": [
#             "Drama",
#             "Comedy",
#             "Music"
#         ],
#         "language": "es",
#         "homepage": "",
#         "overview": "According to an anecdote that has been going around the Internet for several years, in 1934 Gardel was performing on NBC in New York when he was introduced to a young admirer who was eager to meet him. As it turns out, he was none other than 19-year-old Frank Sinatra. Nobody is certain about whether that meeting happened or not but rumor has it that during the night, Gardel and Sinatra were locked in a dressing room together.",
#         "popularity": 2.348,
#         "runtime": 72,
#         "revenue": 0,
#         "release_date": "2023-08-18",
#         "vote_average": 8.071,
#         "vote_count": 7,
#         "spoken_languages": [
#             "English",
#             "Italian",
#             "Spanish"
#         ],
#         "production_countries": [
#             "Argentina",
#             "Mexico"
#         ]
#     },
#     {
#         "title": "Loro",
#         "original_title": "Loro",
#         "budget": 0,
#         "id": 541660,
#         "genre": [
#             "Drama"
#         ],
#         "language": "it",
#         "homepage": "",
#         "overview": "Internationally released Director's Cut of \"Loro 1\" and \"Loro 2\", which were released separately as two movies in Italy. The film talks about the group of businessmen and politicians \u2013 the Loro (Them) from the title \u2013 who live and act near to media tycoon and politician Silvio Berlusconi in the years between 2006 and 2009.",
#         "popularity": 9.499,
#         "runtime": 157,
#         "revenue": 0,
#         "release_date": "2018-09-13",
#         "vote_average": 6.683,
#         "vote_count": 259,
#         "spoken_languages": [
#             "Italian"
#         ],
#         "production_countries": [
#             "France",
#             "Italy"
#         ]
#     },
#     {
#         "title": "Asako I & II",
#         "original_title": "\u5bdd\u3066\u3082\u899a\u3081\u3066\u3082",
#         "budget": 0,
#         "id": 487850,
#         "genre": [
#             "Drama",
#             "Romance"
#         ],
#         "language": "ja",
#         "homepage": "http://www.netemosametemo.jp/",
#         "overview": "College student Asako falls in love at first sight with Baku after meeting at a photography exhibit. Romance sparks between the two but doesn't last long when Baku suddenly disappears from her life. Two years later, she spots a man that bears a striking resemblance to him. Even though it is only his physical similarities to Baku that attracted her to him, she doesn't say so and starts dating the soft-spoken young man called Ryohei.",
#         "popularity": 12.612,
#         "runtime": 119,
#         "revenue": 0,
#         "release_date": "2018-09-01",
#         "vote_average": 6.9,
#         "vote_count": 149,
#         "spoken_languages": [
#             "Japanese",
#             "English"
#         ],
#         "production_countries": [
#             "Japan"
#         ]
#     },
#     {
#         "title": "The Attachment Diaries",
#         "original_title": "El apego",
#         "budget": 0,
#         "id": 743040,
#         "genre": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "language": "es",
#         "homepage": "",
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "popularity": 1.26,
#         "runtime": 102,
#         "revenue": 0,
#         "release_date": "2021-10-07",
#         "vote_average": 4.0,
#         "vote_count": 2,
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "production_countries": [
#             "Argentina"
#         ]
#     },
#     {
#         "title": "Babyteeth",
#         "original_title": "Babyteeth",
#         "budget": 0,
#         "id": 522098,
#         "genre": [
#             "Drama",
#             "Comedy",
#             "Romance"
#         ],
#         "language": "en",
#         "homepage": "http://babyteeth.movie",
#         "overview": "A terminally ill teen upsets her parents when she falls in love with a small-time drug dealer.",
#         "popularity": 15.312,
#         "runtime": 118,
#         "revenue": 989310,
#         "release_date": "2020-06-15",
#         "vote_average": 6.865,
#         "vote_count": 304,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "Australia"
#         ]
#     },
#     {
#         "title": "The Other Half",
#         "original_title": "The Other Half",
#         "budget": 0,
#         "id": 381015,
#         "genre": [
#             "Drama",
#             "Romance"
#         ],
#         "language": "en",
#         "homepage": "http://theotherhalfmovie.com/",
#         "overview": "A grief-stricken man and a bipolar woman fall in love and attempt to forge a simple life together.",
#         "popularity": 3.568,
#         "runtime": 103,
#         "revenue": 0,
#         "release_date": "2016-12-02",
#         "vote_average": 6.2,
#         "vote_count": 21,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "Canada"
#         ]
#     },
#     {
#         "title": "You Go to My Head",
#         "original_title": "You Go To My Head",
#         "budget": 0,
#         "id": 508892,
#         "genre": [
#             "Drama",
#             "Mystery",
#             "Romance",
#             "Thriller"
#         ],
#         "language": "fr",
#         "homepage": "http://yougotomyhead.com/",
#         "overview": "Following a mysterious car accident in the desert, Dafne suffers from post-traumatic amnesia. Jake, the first person she sees when she regains consciousness, tells her he's her husband.",
#         "popularity": 1.46,
#         "runtime": 116,
#         "revenue": 0,
#         "release_date": "2017-10-26",
#         "vote_average": 6.7,
#         "vote_count": 9,
#         "spoken_languages": [
#             "English",
#             "French"
#         ],
#         "production_countries": [
#             "Belgium",
#             "France",
#             "Germany"
#         ]
#     },
#     {
#         "title": "Ammonite",
# ...
#         "budget": 0,
#         "id": 765057,
#         "genre": [
#             "Music",
#             "Documentary"
#         ],
#         "language": "en",
#         "homepage": "https://www.hulu.com/movie/69-the-saga-of-danny-hernandez-345025ec-5022-4cca-a5f7-d3870fce96b3",
#         "overview": "Part investigative documentary, part real-life gangster movie, this film unpacks the life of polarizing rap sensation and internet troll Tekashi69, aka 69, while chronicling his meteoric rise and fall from fame.",
#         "popularity": 2.321,
#         "runtime": 101,
#         "revenue": 0,
#         "release_date": "2021-04-29",
#         "vote_average": 6.9,
#         "vote_count": 10,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "The Lost Weekend: A Love Story",
#         "original_title": "The Lost Weekend: A Love Story",
#         "budget": 0,
#         "id": 965042,
#         "genre": [
#             "Documentary"
#         ],
#         "language": "en",
#         "homepage": "https://thelostweekendmovie.com/",
#         "overview": "May Pang lovingly recounts her life in rock & roll and the whirlwind 18 months spent as friend, lover, and confidante to one of the towering figures of popular culture, John Lennon, in this funny, touching, and vibrant portrait of first love.",
#         "popularity": 2.071,
#         "runtime": 95,
#         "revenue": 0,
#         "release_date": "2023-04-13",
#         "vote_average": 6.0,
#         "vote_count": 2,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Art of Love",
#         "original_title": "L'Art d'aimer",
#         "budget": 0,
#         "id": 92424,
#         "genre": [
#             "Romance",
#             "Comedy"
#         ],
#         "language": "fr",
#         "homepage": "",
#         "overview": "The Art of Love is composed of several chapters, which follows several Parisian couples.",
#         "popularity": 4.527,
#         "runtime": 85,
#         "revenue": 0,
#         "release_date": "2011-11-23",
#         "vote_average": 5.855,
#         "vote_count": 55,
#         "spoken_languages": [
#             "French"
#         ],
#         "production_countries": [
#             "France"
#         ]
#     },
#     {
#         "title": "Asher",
#         "original_title": "Asher",
#         "budget": 0,
#         "id": 529982,
#         "genre": [
#             "Thriller",
#             "Action",
#             "Drama"
#         ],
#         "language": "en",
#         "homepage": "",
#         "overview": "Asher is a former Mossad agent turned gun for hire, living an austere life in an ever-changing Brooklyn. Approaching the end of his career, he breaks the oath he took as a young man when he meets Sophie on a hit gone wrong. In order to have love in his life before it's too late, he must kill the man he was, for a chance at becoming the man he wants to be.",
#         "popularity": 10.283,
#         "runtime": 117,
#         "revenue": 0,
#         "release_date": "2018-12-07",
#         "vote_average": 5.788,
#         "vote_count": 132,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Wild Mountain Thyme",
#         "original_title": "Wild Mountain Thyme",
#         "budget": 0,
#         "id": 628333,
#         "genre": [
#             "Romance",
#             "Drama"
#         ],
#         "language": "en",
#         "homepage": "",
#         "overview": "Headstrong farmer Rosemary Muldoon has her heart set on winning her neighbour Anthony Reilly's love. The problem is, Anthony seems to have inherited a family curse, and remains oblivious to his beautiful admirer. Stung by his father's plans to sell the family farm to his American nephew, Anthony is jolted into pursuing his dreams.",
#         "popularity": 10.971,
#         "runtime": 102,
#         "revenue": 0,
#         "release_date": "2020-12-11",
#         "vote_average": 5.141,
#         "vote_count": 142,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "Ireland",
#             "United Kingdom"
#         ]
#     },
#     {
#         "title": "Diane",
#         "original_title": "Diane",
#         "budget": 0,
#         "id": 510034,
#         "genre": [
#             "Drama"
#         ],
#         "language": "en",
#         "homepage": "",
#         "overview": "Diane is a devoted friend and caretaker, particularly to her drug-addicted son. But as those around her begin to drift away in the last quarter of her life, she is left to reckon with past choices and long-dormant memories.",
#         "popularity": 3.588,
#         "runtime": 96,
#         "revenue": 0,
#         "release_date": "2019-03-28",
#         "vote_average": 6.206,
#         "vote_count": 34,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Luz",
#         "original_title": "Luz",
#         "budget": 0,
#         "id": 1193055,
#         "genre": [],
#         "language": "es",
#         "homepage": "",
#         "overview": "",
#         "popularity": 1.778,
#         "runtime": 0,
#         "revenue": 0,
#         "release_date": "2023-10-31",
#         "vote_average": 0.0,
#         "vote_count": 0,
#         "spoken_languages": [],
#         "production_countries": []
#     },
#     {
#         "title": "Lingui, the Sacred Bonds",
#         "original_title": "Lingui : les liens sacr\u00e9s",
#         "budget": 0,
#         "id": 820693,
#         "genre": [
#             "Drama"
#         ],
#         "language": "fr",
#         "homepage": "",
#         "overview": "On the outskirts of the capital of Chad, determined single mother Amina works tirelessly to provide for herself and her 15-year old daughter Maria. When Amina discovers Maria is pregnant and does not want a child, the two women begin to seek out an abortion, condemned by both religion and law. In the process, mother and daughter forge a connection stronger than any they\u2019ve ever known.",
#         "popularity": 5.164,
#         "runtime": 88,
#         "revenue": 0,
#         "release_date": "2021-12-08",
#         "vote_average": 6.661,
#         "vote_count": 28,
#         "spoken_languages": [
#             "Arabic",
#             "French"
#         ],
#         "production_countries": [
#             "Germany",
#             "Belgium",
#             "Chad",
#             "France"
#         ]
#     },
#     {
#         "title": "Preparations to Be Together",
#         "original_title": "Felk\u00e9sz\u00fcl\u00e9s meghat\u00e1rozatlan ideig tart\u00f3 egy\u00fcttl\u00e9tre",
#         "budget": 1000000,
#         "id": 727002,
#         "genre": [
#             "Drama"
#         ],
#         "language": "hu",
#         "homepage": "",
#         "overview": "M\u00e1rta, a 40-year-old neurosurgeon, falls in love. She leaves her shining American career behind and returns to Budapest to start a new life with the man she loves. But she waits for him at the Liberty Bridge in vain - he does not appear at their rendezvous. M\u00e1rta starts to search for him desperately, but when she finally finds him, the love of her life claims that they have never met before.",
#         "popularity": 4.452,
#         "runtime": 95,
#         "revenue": 117368,
#         "release_date": "2020-09-24",
#         "vote_average": 6.6,
#         "vote_count": 25,
#         "spoken_languages": [
#             "English",
#             "Hungarian"
#         ],
#         "production_countries": [
#             "Hungary"
#         ]
#     },
#     {
#         "title": "Atlantis",
#         "original_title": "Atlantis",
#         "budget": 0,
#         "id": 15466,
#         "genre": [
#             "Music",
#             "Documentary"
#         ],
#         "language": "fr",
#         "homepage": "",
#         "overview": "Atmospheric soundtrack follows this compilation of nature footage that focuses on the ocean and various life forms that live, mate and die in it.",
#         "popularity": 6.512,
#         "runtime": 74,
#         "revenue": 138,
#         "release_date": "1991-08-21",
#         "vote_average": 6.2,
#         "vote_count": 41,
#         "spoken_languages": [
#             "French"
#         ],
#         "production_countries": [
#             "France",
#             "Italy"
#         ]
#     },
#     {
#         "title": "Thor: Love and Thunder",
#         "original_title": "Thor: Love and Thunder",
#         "budget": 250000000,
#         "id": 616037,
#         "genre": [
#             "Fantasy",
#             "Action",
#             "Comedy"
#         ],
#         "language": "en",
#         "homepage": "https://www.marvel.com/movies/thor-love-and-thunder",
#         "overview": "After his retirement is interrupted by Gorr the God Butcher, a galactic killer who seeks the extinction of the gods, Thor Odinson enlists the help of King Valkyrie, Korg, and ex-girlfriend Jane Foster, who now wields Mjolnir as the Mighty Thor. Together they embark upon a harrowing cosmic adventure to uncover the mystery of the God Butcher\u2019s vengeance and stop him before it\u2019s too late.",
#         "popularity": 133.692,
#         "runtime": 119,
#         "revenue": 760928081,
#         "release_date": "2022-07-06",
#         "vote_average": 6.502,
#         "vote_count": 6693,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "A Tuba to Cuba",
#         "original_title": "A Tuba To Cuba",
#         "budget": 0,
#         "id": 502190,
#         "genre": [
#             "Documentary",
#             "Music",
#             "History"
#         ],
#         "language": "en",
#         "homepage": "https://www.atubatocuba.com/",
#         "overview": "A son seeking to fulfill his late father\u2019s dream takes his band from the storied city of New Orleans to the shores of Cuba, where \u2014 through the universal language of music \u2014 dark and ancient connections between their peoples reveal the roots of jazz.",
#         "popularity": 1.086,
#         "runtime": 82,
#         "revenue": 0,
#         "release_date": "2019-02-15",
#         "vote_average": 6.6,
#         "vote_count": 8,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "Cuba",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "The Woman Who Loves Giraffes",
#         "original_title": "The Woman Who Loves Giraffes",
#         "budget": 0,
#         "id": 544825,
#         "genre": [
#             "Documentary"
#         ],
#         "language": "en",
#         "homepage": "",
#         "overview": "Dr. Anne Innis Dagg re-traces the steps of her groundbreaking 1956 journey to South Africa to study giraffes in the wild. Now, at 85 years old, Anne sees a startling contrast between the world of giraffes she once knew and the one it has become. Weaving through the past and present, her harrowing journey gives us an intimate look into the factors that destroyed her career and the forces that brought her back.",
#         "popularity": 1.651,
#         "runtime": 81,
#         "revenue": 0,
#         "release_date": "2018-10-03",
#         "vote_average": 7.0,
#         "vote_count": 12,
#         "spoken_languages": [],
#         "production_countries": [
#             "Canada",
#             "South Africa",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "In From the Side",
#         "original_title": "In from the Side",
#         "budget": 0,
#         "id": 622082,
#         "genre": [
#             "Drama",
#             "Romance"
#         ],
#         "language": "en",
#         "homepage": "http://www.infromthesidemovie.com",
#         "overview": "Mark, a new and inexperienced rugby club member, finds himself drawn to Warren, a seasoned first team player. When a series of happenstances at an away fixture lead to a drunken encounter, Mark and Warren unwittingly embark on a romantic affair they struggle to hide from their partners and teammates.",
#         "popularity": 12.489,
#         "runtime": 134,
#         "revenue": 0,
#         "release_date": "2022-09-16",
#         "vote_average": 7.068,
#         "vote_count": 44,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United Kingdom"
#         ]
#     },
#     {
#         "title": "Hot Air",
#         "original_title": "Hot Air",
#         "budget": 0,
#         "id": 479315,
#         "genre": [
#             "Drama"
#         ],
#         "language": "en",
#         "homepage": "",
#         "overview": "A right-wing talk show host's life takes a sudden turn when his 16-year-old niece comes crashing into his life.",
#         "popularity": 3.088,
#         "runtime": 99,
#         "revenue": 0,
#         "release_date": "2018-04-10",
#         "vote_average": 5.219,
#         "vote_count": 16,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Casanova, Last Love",
#         "original_title": "Dernier amour",
#         "budget": 0,
#         "id": 504605,
#         "genre": [
#             "Drama",
#             "Romance"
#         ],
#         "language": "fr",
#         "homepage": "https://lesfilmsdufleuve.be/en/movies/dernier-amour",
#         "overview": "Year 1763. Forced into exile, the famous libertine Giacomo Casanova leaves Paris and travels to London, where he meets Marianne de Charpillon, a young prostitute to whom he is so attracted that he forgets about the other women.",
#         "popularity": 9.66,
#         "runtime": 99,
#         "revenue": 0,
#         "release_date": "2019-03-20",
#         "vote_average": 4.9,
#         "vote_count": 33,
#         "spoken_languages": [
#             "English",
#             "French",
#             "German",
#             "Italian"
#         ],
#         "production_countries": [
#             "Belgium",
#             "France",
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Dinner in America",
#         "original_title": "Dinner in America",
#         "budget": 0,
#         "id": 653664,
#         "genre": [
#             "Comedy",
#             "Drama",
#             "Music",
#             "Romance"
#         ],
#         "language": "en",
#         "homepage": "",
#         "overview": "An on-the-lam punk rocker and a young woman obsessed with his band go on an unexpected and epic journey together through the decaying suburbs of the American Midwest.",
#         "popularity": 12.923,
#         "runtime": 106,
#         "revenue": 0,
#         "release_date": "2020-05-27",
#         "vote_average": 6.8,
#         "vote_count": 68,
#         "spoken_languages": [
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "The Inspection",
#         "original_title": "The Inspection",
#         "budget": 0,
#         "id": 837938,
#         "genre": [
#             "Drama"
#         ],
#         "language": "en",
#         "homepage": "https://a24films.com/films/inspection",
#         "overview": "Ellis French is a young, gay Black man, rejected by his mother and with few options for his future, decides to join the Marines, doing whatever it takes to succeed in a system that would cast him aside. But even as he battles deep-seated prejudice and the grueling routines of basic training, he finds unexpected camaraderie, strength, and support in this new community, giving him a hard-earned sense of belonging that will shape his identity and forever change his life.",
#         "popularity": 9.399,
#         "runtime": 95,
#         "revenue": 0,
#         "release_date": "2022-11-18",
#         "vote_average": 6.356,
#         "vote_count": 45,
#         "spoken_languages": [
#             "Arabic",
#             "Spanish",
#             "English"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     }
# ]

# %%
tmdb_movies_list
# Out:
# [{'title': 'The Tomorrow Man',
#   'original_title': 'The Tomorrow Man',
#   'budget': 0,
#   'id': 565391,
#   'genre': ['Drama', 'Romance'],
#   'language': 'en',
#   'homepage': 'https://bleeckerstreetmedia.com/thetomorrowman',
#   'overview': 'Ed Hemsler spends his life preparing for a disaster that may never come. Ronnie Meisner spends her life shopping for things she may never use. In a small town somewhere in America, these two people will try to find love while trying not to get lost in each other’s stuff.',
#   'popularity': 5.507,
#   'runtime': 94,
#   'revenue': 0,
#   'release_date': '2019-05-22',
#   'vote_average': 5.63,
#   'vote_count': 50,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Marriage Story',
#   'original_title': 'Marriage Story',
#   'budget': 18000000,
#   'id': 492188,
#   'genre': ['Drama'],
#   'language': 'en',
#   'homepage': 'https://www.marriagestorymovie.com/',
#   'overview': 'A stage director and an actress struggle through a grueling, coast-to-coast divorce that pushes them to their personal extremes.',
#   'popularity': 25.424,
#   'runtime': 137,
#   'revenue': 2300000,
#   'release_date': '2019-09-28',
#   'vote_average': 7.749,
#   'vote_count': 6545,
#   'spoken_languages': ['English'],
#   'production_countries': ['United Kingdom']},
#  {'title': 'Bones and All',
#   'original_title': 'Bones and All',
#   'budget': 18000000,
#   'id': 791177,
#   'genre': ['Drama', 'Horror', 'Romance'],
#   'language': 'it',
#   'homepage': 'https://www.bonesandallfilm.net/',
#   'overview': 'Abandoned by her father, a young woman embarks on a thousand-mile odyssey through the backroads of America where she meets a disenfranchised drifter. But despite their best efforts, all roads lead back to their terrifying pasts and to a final stand that will determine whether their love can survive their otherness.',
#   'popularity': 22.87,
#   'runtime': 131,
#   'revenue': 15100000,
#   'release_date': '2022-11-18',
#   'vote_average': 7.128,
#   'vote_count': 1070,
#   'spoken_languages': ['English'],
#   'production_countries': ['Italy', 'United States of America']},
#  {'title': 'Love, Antosha',
#   'original_title': 'Love, Antosha',
#   'budget': 0,
#   'id': 565276,
#   'genre': ['Documentary'],
#   'language': 'en',
#   'homepage': 'https://antonyelchindoc.com/',
#   'overview': "From a prolific career in film and television, Anton Yelchin left an indelible legacy as an actor. Through his journals and other writings, his photography, the original music he wrote, and interviews with his family, friends, and colleagues, this film looks not just at Anton's impressive career, but at a broader portrait of the man.",
#   'popularity': 10.22,
#   'runtime': 92,
#   'revenue': 0,
#   'release_date': '2019-08-02',
#   'vote_average': 7.4,
#   'vote_count': 48,
#   'spoken_languages': ['English', 'Russian'],
#   'production_countries': ['United States of America']},
#  {'title': 'You Can Live Forever',
#   'original_title': 'You Can Live Forever',
#   'budget': 0,
#   'id': 887580,
#   'genre': ['Drama', 'Romance'],
#   'language': 'en',
#   'homepage': 'https://gooddeedentertainment.com/you-can-live-forever/',
#   'overview': "When Jaime, a gay teenager, is sent to live in a community of Jehovah's Witnesses in small-town Quebec, she falls madly in love with a devout Witness girl. The two embark on an intense affair with consequences that will reshape the rest of their lives.",
#   'popularity': 7.338,
#   'runtime': 96,
#   'revenue': 0,
#   'release_date': '2022-06-11',
#   'vote_average': 7.263,
#   'vote_count': 38,
#   'spoken_languages': ['French', 'English'],
#   'production_countries': ['Canada']},
#  {'title': 'A Journal for Jordan',
#   'original_title': 'A Journal for Jordan',
#   'budget': 25000000,
#   'id': 501841,
#   'genre': ['Drama', 'Romance'],
#   'language': 'en',
#   'homepage': 'https://www.sonypictures.com/movies/ajournalforjordan',
#   'overview': 'Based on the true story of First Sergeant Charles Monroe King, a soldier deployed to Iraq begins to keep a journal of love and advice for his infant son. Back at home, senior New York Times editor Dana Canedy revisits the story of her unlikely, life-altering relationship with King and his enduring devotion to her and their child.',
#   'popularity': 10.752,
#   'runtime': 131,
#   'revenue': 6700000,
#   'release_date': '2021-12-22',
#   'vote_average': 7.2,
#   'vote_count': 92,
#   'spoken_languages': ['English'],
#   'production_countries': ['Canada', 'United States of America']},
#  {'title': 'Undine',
#   'original_title': 'Undine',
#   'budget': 0,
#   'id': 615761,
#   'genre': ['Fantasy', 'Drama', 'Romance'],
#   'language': 'de',
#   'homepage': 'https://www.the-match-factory.com/catalogue/films/undine.html',
#   'overview': 'Undine is a historian and tour guide at the Berlin City Museum specializing in urban development, while Christoph is an industrial diver. Linked by a love of the water, the two form an intense bond, which can only do so much to help Undine overcome the considerable baggage of her former affair.',
#   'popularity': 15.048,
#   'runtime': 90,
#   'revenue': 0,
#   'release_date': '2020-07-01',
#   'vote_average': 6.513,
#   'vote_count': 194,
#   'spoken_languages': ['English', 'German', 'Spanish'],
#   'production_countries': ['France', 'Germany']},
#  {'title': 'Waiting for Bojangles',
#   'original_title': 'En attendant Bojangles',
#   'budget': 0,
#   'id': 851303,
#   'genre': ['Drama', 'Comedy', 'Romance'],
#   'language': 'fr',
#   'homepage': '',
#   'overview': "A boy and his eccentric parents leave their home in Paris for a country house in Spain. As the mother descends deeper into her own mind, it's up to the boy and his father to keep her safe and happy.",
#   'popularity': 13.273,
#   'runtime': 124,
#   'revenue': 0,
#   'release_date': '2021-10-13',
#   'vote_average': 7.422,
#   'vote_count': 275,
#   'spoken_languages': ['French', 'English'],
#   'production_countries': ['France', 'United States of America']},
#  {'title': 'Lost in Paris',
#   'original_title': 'Paris pieds nus',
#   'budget': 0,
#   'id': 413778,
#   'genre': ['Comedy'],
#   'language': 'fr',
#   'homepage': '',
#   'overview': 'Fiona visits Paris for the first time to assist her myopic Aunt Martha. Catastrophes ensue, mainly involving Dom, a homeless man who has yet to have an emotion or thought he was afraid of expressing.',
#   'popularity': 5.866,
#   'runtime': 83,
#   'revenue': 0,
#   'release_date': '2017-01-14',
#   'vote_average': 6.05,
#   'vote_count': 109,
#   'spoken_languages': ['French'],
#   'production_countries': ['Belgium', 'France']},
#  {'title': 'Love & Mercy’ Gets Inside Brian Wilson’s Hea',
#   'original_title': 'ลอง ลีฟ เลิฟว์',
#   'budget': 0,
#   'id': 1026961,
#   'genre': ['Romance', 'Comedy'],
#   'language': 'th',
#   'homepage': 'https://longlivelovethailanddrama.splashthat.com',
#   'overview': 'A story about a party-animal Sati, a man whose attitude has left a broken family at home. Meta, his wife, is preparing to leave him. At age 15, his daughter, Namo is already jaded from a lifetime of broken promises.',
#   'popularity': 25.972,
#   'runtime': 135,
#   'revenue': 2122023,
#   'release_date': '2023-06-29',
#   'vote_average': 8.133,
#   'vote_count': 15,
#   'spoken_languages': ['Thai'],
#   'production_countries': ['Thailand']},
#  {'title': 'Hard Luck Love Song',
#   'original_title': 'Hard Luck Love Song',
#   'budget': 0,
#   'id': 536208,
#   'genre': ['Romance', 'Music', 'Drama', 'Thriller'],
#   'language': 'en',
#   'homepage': 'http://HardLuckLoveSong.com',
#   'overview': 'Jesse, a charismatic but down on his luck troubadour, finds himself at an existential crossroads as bad choices catch up with him during an unexpected reunion with Carla, an old flame.',
#   'popularity': 3.988,
#   'runtime': 104,
#   'revenue': 0,
#   'release_date': '2021-10-15',
#   'vote_average': 5.0,
#   'vote_count': 8,
#   'spoken_languages': ['English', 'Spanish'],
#   'production_countries': ['United States of America']},
#  {'title': 'See You Then',
#   'original_title': 'See You Then',
#   'budget': 0,
#   'id': 794903,
#   'genre': ['Drama'],
#   'language': 'en',
#   'homepage': 'https://vanishingangle.com/see-you-then',
#   'overview': "A decade after abruptly breaking up with Naomi, Kris invites her to a dinner to catch-up on their complicated lives, relationships, and Kris' transition.",
#   'popularity': 1.906,
#   'runtime': 74,
#   'revenue': 0,
#   'release_date': '2022-04-01',
#   'vote_average': 2.5,
#   'vote_count': 2,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Kalank',
#   'original_title': 'कलंक',
#   'budget': 0,
#   'id': 556271,
#   'genre': ['Drama', 'Romance'],
#   'language': 'hi',
#   'homepage': '',
#   'overview': 'Set in 1945, in Pre-Independent India, the elite, opulent and solemn world of the Chaudhry family, and the wild, mysterious and musical underbelly of the town, Hira Mandi, clash when Roop Chaudhry encounters Zafar, a daredevil from Hira Mandi, unleashing deep-buried truths, secrets of betrayal and affairs that threaten to bring both worlds crashing down.',
#   'popularity': 6.878,
#   'runtime': 166,
#   'revenue': 0,
#   'release_date': '2019-04-17',
#   'vote_average': 5.466,
#   'vote_count': 44,
#   'spoken_languages': ['Hindi'],
#   'production_countries': ['India']},
#  {'title': 'Your Name Engraved Herein',
#   'original_title': '刻在你心底的名字',
#   'budget': 0,
#   'id': 719410,
#   'genre': ['Romance', 'Drama'],
#   'language': 'zh',
#   'homepage': '',
#   'overview': 'In 1987, as martial law ends in Taiwan, Jia-han and Birdy fall in love amid family pressure, homophobia and social stigma.',
#   'popularity': 20.357,
#   'runtime': 114,
#   'revenue': 0,
#   'release_date': '2020-09-30',
#   'vote_average': 7.885,
#   'vote_count': 227,
#   'spoken_languages': ['Mandarin', 'English'],
#   'production_countries': ['Taiwan', 'United States of America']},
#  {'title': 'Tu Me Manques',
#   'original_title': 'Tu me manques',
#   'budget': 0,
#   'id': 612437,
#   'genre': ['Drama', 'Romance'],
#   'language': 'es',
#   'homepage': '',
#   'overview': 'Following his son Gabriel’s death, Jorge travels from conservative Bolivia to New York City to confront Gabriel’s boyfriend Sebastian. While the two battle over Jorge’s inability to accept his son, Sebastian channels his grief into a bold new play in honor of his lost love, in which Gabriel’s inner turmoil is transformed into an eye-popping gay fantasia.',
#   'popularity': 4.146,
#   'runtime': 105,
#   'revenue': 0,
#   'release_date': '2019-07-27',
#   'vote_average': 6.9,
#   'vote_count': 21,
#   'spoken_languages': ['English', 'Spanish'],
#   'production_countries': ['Bolivia', 'United States of America']},
#  {'title': 'Together',
#   'original_title': 'Trolls Band Together',
#   'budget': 95000000,
#   'id': 901362,
#   'genre': ['Animation', 'Family', 'Music', 'Fantasy', 'Comedy'],
#   'language': 'en',
#   'homepage': 'https://www.dreamworks.com/movies/trolls-band-together',
#   'overview': "When Branch's brother, Floyd, is kidnapped for his musical talents by a pair of nefarious pop-star villains, Branch and Poppy embark on a harrowing and emotional journey to reunite the other brothers and rescue Floyd from a fate even worse than pop-culture obscurity.",
#   'popularity': 1710.225,
#   'runtime': 92,
#   'revenue': 161200000,
#   'release_date': '2023-10-12',
#   'vote_average': 7.181,
#   'vote_count': 279,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Alcarràs',
#   'original_title': 'Alcarràs',
#   'budget': 0,
#   'id': 804251,
#   'genre': ['Drama'],
#   'language': 'ca',
#   'homepage': 'https://www.alcarras-film.com/',
#   'overview': 'In a small village in Catalonia, the peach farmers of the Solé family spend every summer together picking fruit from their orchard. But when plans arise to install solar panels and cut down trees, the members of this tight-knit group suddenly face eviction – and the loss of far more than their home.',
#   'popularity': 8.75,
#   'runtime': 120,
#   'revenue': 0,
#   'release_date': '2022-04-29',
#   'vote_average': 6.888,
#   'vote_count': 156,
#   'spoken_languages': ['Catalan'],
#   'production_countries': ['Spain']},
#  {'title': 'Queen & Slim',
#   'original_title': 'Η Μαύρη Εμμανουέλα',
#   'budget': 0,
#   'id': 40108,
#   'genre': ['Crime', 'Drama'],
#   'language': 'el',
#   'homepage': '',
#   'overview': "After years of abuse at the hands of her husband, a woman, Emmanouella, is pushed to the breaking point. She hires a hitman to do in her husband, but just when she thinks her troubles are at an end, the assassin blackmails her. As her husband's business partner struggles to prove her guilt, and as the hitman continues to threaten her new found security, Emmanouella struggles to keep her name clear and to keep her naive stepdaughter from becoming tangled in the web of danger she has created.",
#   'popularity': 63.718,
#   'runtime': 91,
#   'revenue': 0,
#   'release_date': '1980-03-12',
#   'vote_average': 6.058,
#   'vote_count': 69,
#   'spoken_languages': ['Greek', 'Italian'],
#   'production_countries': ['Cyprus', 'Greece']},
#  {'title': 'Falling Inn Love',
#   'original_title': 'Falling Inn Love',
#   'budget': 0,
#   'id': 623195,
#   'genre': ['Romance', 'Comedy'],
#   'language': 'en',
#   'homepage': 'https://www.netflix.com/title/80999781',
#   'overview': 'When a San Francisco exec wins a New Zealand inn, she ditches city life to remodel and flip the rustic property with help from a handsome contractor.',
#   'popularity': 14.701,
#   'runtime': 98,
#   'revenue': 0,
#   'release_date': '2019-08-29',
#   'vote_average': 6.522,
#   'vote_count': 1097,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'The Sun Is Also a Star',
#   'original_title': 'The Sun Is Also a Star',
#   'budget': 9000000,
#   'id': 508791,
#   'genre': ['Romance', 'Drama'],
#   'language': 'en',
#   'homepage': 'https://www.thesunisalsoastarmovie.com',
#   'overview': 'Two young New Yorkers begin to fall in love over the course of a single day, as a series of potentially life-altering meetings loom over their heads - hers concerning her family’s deportation to Jamaica, and his concerning an education at Dartmouth.',
#   'popularity': 18.156,
#   'runtime': 100,
#   'revenue': 6800000,
#   'release_date': '2019-05-16',
#   'vote_average': 7.0,
#   'vote_count': 558,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Book of Love',
#   'original_title': 'Book of Love',
#   'budget': 0,
#   'id': 892835,
#   'genre': ['Comedy', 'Romance'],
#   'language': 'en',
#   'homepage': '',
#   'overview': 'Henry, an English writer who has written a new book that has become a failure in the U.K, gets notified that the dull book has been highly trending over in Mexico. Little does he know that Maria, a Spanish translator, turned the book into an erotic novel. Henry and Maria then swerve around Mexico to do a book tour and go through a wind of events.',
#   'popularity': 9.07,
#   'runtime': 106,
#   'revenue': 398876,
#   'release_date': '2022-01-06',
#   'vote_average': 5.6,
#   'vote_count': 105,
#   'spoken_languages': ['English', 'Spanish'],
#   'production_countries': ['Mexico',
#    'United Kingdom',
#    'United States of America']},
#  {'title': 'My Psychedelic Love Story',
#   'original_title': 'My Psychedelic Love Story',
#   'budget': 0,
#   'id': 750595,
#   'genre': ['Documentary'],
#   'language': 'en',
#   'homepage': 'https://www.sho.com/titles/3497302/my-psychedelic-love-story',
#   'overview': 'An examination of the notorious high priest of LSD Timothy Leary through the eyes of his famed lover Joanna Harcourt-Smith.',
#   'popularity': 1.319,
#   'runtime': 107,
#   'revenue': 0,
#   'release_date': '2020-10-22',
#   'vote_average': 6.0,
#   'vote_count': 5,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'How to Talk to Girls at Parties',
#   'original_title': 'How to Talk to Girls at Parties',
#   'budget': 0,
#   'id': 341689,
#   'genre': ['Comedy', 'Music', 'Romance', 'Science Fiction'],
#   'language': 'en',
#   'homepage': 'https://a24films.com/films/how-to-talk-to-girls-at-parties',
#   'overview': 'In 1970s London, a teenage outsider named Enn falls in love with a rebellious alien girl named Zan, who has come to Earth for a party. Together, they navigate the complexities of intergalactic culture and the trials of first love.',
#   'popularity': 9.536,
#   'runtime': 103,
#   'revenue': 0,
#   'release_date': '2017-10-06',
#   'vote_average': 6.047,
#   'vote_count': 352,
#   'spoken_languages': ['English'],
#   'production_countries': ['United Kingdom', 'United States of America']},
#  {'title': 'All the Bright Places',
#   'original_title': 'All the Bright Places',
#   'budget': 0,
#   'id': 342470,
#   'genre': ['Romance', 'Drama'],
#   'language': 'en',
#   'homepage': 'https://www.netflix.com/title/80208802',
#   'overview': 'Two teens facing personal struggles form a powerful bond as they embark on a cathartic journey chronicling the wonders of Indiana.',
#   'popularity': 26.029,
#   'runtime': 108,
#   'revenue': 0,
#   'release_date': '2020-02-28',
#   'vote_average': 7.7,
#   'vote_count': 2720,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Cyrano, My Love',
#   'original_title': 'Edmond',
#   'budget': 0,
#   'id': 544510,
#   'genre': ['Comedy', 'History'],
#   'language': 'fr',
#   'homepage': 'http://roadsideattractions.com/filmography/cyranomylove',
#   'overview': 'Paris, France, December 1897. The young playwright Edmond Rostand feels like a failure. Inspiration has abandoned him. Married and father of two children, desperate and penniless, he persuades the great actor Constant Coquelin to perform the main role in his new play. But there is a problem: Coquelin wants to premiere it at Christmas and Edmond has not written a single word.',
#   'popularity': 8.618,
#   'runtime': 113,
#   'revenue': 0,
#   'release_date': '2018-11-10',
#   'vote_average': 7.5,
#   'vote_count': 464,
#   'spoken_languages': ['French', 'Russian'],
#   'production_countries': ['Belgium', 'France']},
#  {'title': 'Wife of a Spy',
#   'original_title': 'スパイの妻',
#   'budget': 0,
#   'id': 688301,
#   'genre': ['Drama', 'War', 'Thriller'],
#   'language': 'ja',
#   'homepage': 'https://intl.nikkatsu.com/sales/358.html',
#   'overview': 'It’s 1940, and the population of Japan is divided over its entry into World War II. Satoko, the wife of a fabric merchant, is devoted to her husband but is beginning to suspect he’s up to something. Soon she allows herself to be drawn into a game in which she enigmatically conceals her intentions.',
#   'popularity': 13.631,
#   'runtime': 114,
#   'revenue': 0,
#   'release_date': '2020-10-16',
#   'vote_average': 6.5,
#   'vote_count': 75,
#   'spoken_languages': ['English', 'Japanese'],
#   'production_countries': ['Japan']},
#  {'title': 'The Mountain Between Us',
#   'original_title': 'The Mountain Between Us',
#   'budget': 35000000,
#   'id': 290512,
#   'genre': ['Drama', 'Adventure', 'Romance'],
#   'language': 'en',
#   'homepage': 'http://MountainBetweenUs.com',
#   'overview': 'Stranded on a mountain after a tragic plane crash, two strangers must work together to endure the extreme elements of the remote, snow-covered terrain. When they realize help is not coming, they embark on a perilous journey across hundreds of miles of wilderness, pushing each other to survive and discovering their inner strength.',
#   'popularity': 26.194,
#   'runtime': 109,
#   'revenue': 62832209,
#   'release_date': '2017-10-05',
#   'vote_average': 6.6,
#   'vote_count': 2201,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Hope Gap',
#   'original_title': 'Hope Gap',
#   'budget': 0,
#   'id': 537140,
#   'genre': ['Drama'],
#   'language': 'en',
#   'homepage': 'https://www.originpictures.co.uk/hope-gap',
#   'overview': "A couple's visit with their son takes a dramatic turn when the father tells him he plans on leaving his mother.",
#   'popularity': 8.987,
#   'runtime': 100,
#   'revenue': 1136167,
#   'release_date': '2019-10-03',
#   'vote_average': 6.346,
#   'vote_count': 114,
#   'spoken_languages': ['English'],
#   'production_countries': ['United Kingdom', 'United States of America']},
#  {'title': 'How to Train Your Dragon: The Hidden World',
#   'original_title': 'How to Train Your Dragon: The Hidden World',
#   'budget': 129000000,
#   'id': 166428,
#   'genre': ['Animation', 'Family', 'Adventure'],
#   'language': 'en',
#   'homepage': 'https://www.howtotrainyourdragon.com/',
#   'overview': 'As Hiccup fulfills his dream of creating a peaceful dragon utopia, Toothless’ discovery of an untamed, elusive mate draws the Night Fury away. When danger mounts at home and Hiccup’s reign as village chief is tested, both dragon and rider must make impossible decisions to save their kind.',
#   'popularity': 61.277,
#   'runtime': 104,
#   'revenue': 524580592,
#   'release_date': '2019-01-03',
#   'vote_average': 7.8,
#   'vote_count': 5899,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Monday',
#   'original_title': 'Monday',
#   'budget': 0,
#   'id': 550524,
#   'genre': ['Drama', 'Romance'],
#   'language': 'en',
#   'homepage': 'https://www.monday.movie',
#   'overview': 'A spark on a Friday can lead to a sizzling weekend fling, but what happens when you get to the inevitable Monday?',
#   'popularity': 10.83,
#   'runtime': 116,
#   'revenue': 0,
#   'release_date': '2020-09-11',
#   'vote_average': 6.666,
#   'vote_count': 151,
#   'spoken_languages': ['English', 'Greek'],
#   'production_countries': ['Greece',
#    'United Kingdom',
#    'United States of America']},
#  {'title': 'My Policeman',
#   'original_title': 'My Policeman',
#   'budget': 0,
#   'id': 744114,
#   'genre': ['Drama', 'Romance'],
#   'language': 'en',
#   'homepage': 'https://www.amazon.com/dp/B09Y8SHDPD',
#   'overview': 'In the late 1990s, the arrival of elderly invalid Patrick into Marion and Tom’s home triggers the exploration of seismic events from 40 years previous: the passionate relationship between Tom and Patrick at a time when homosexuality was illegal.',
#   'popularity': 13.643,
#   'runtime': 113,
#   'revenue': 0,
#   'release_date': '2022-10-20',
#   'vote_average': 7.761,
#   'vote_count': 593,
#   'spoken_languages': ['English'],
#   'production_countries': ['United Kingdom', 'United States of America']},
#  {'title': 'Paris 05:59 Théo & Hugo’ Finds Two Men Out to Get Luck',
#   'original_title': 'Théo et Hugo dans le même bateau',
#   'budget': 0,
#   'id': 382892,
#   'genre': ['Drama'],
#   'language': 'fr',
#   'homepage': '',
#   'overview': 'Théo and Hugo meet in a club and form an immediate bond. Once the desire and elation of this first moment has passed, the two young men, now sober, wander through the empty streets of nocturnal Paris, having to confront the love they sense blossoming between them.',
#   'popularity': 9.676,
#   'runtime': 97,
#   'revenue': 0,
#   'release_date': '2016-04-27',
#   'vote_average': 6.825,
#   'vote_count': 97,
#   'spoken_languages': ['French'],
#   'production_countries': ['France']},
#  {'title': 'Ariana Grande: Excuse Me, I Love You',
#   'original_title': 'ariana grande: excuse me, i love you',
#   'budget': 0,
#   'id': 774372,
#   'genre': ['Music', 'Documentary'],
#   'language': 'en',
#   'homepage': 'https://www.netflix.com/title/81238721',
#   'overview': 'Ariana Grande takes the stage in London for her Sweetener World Tour and shares a behind-the-scenes look at her life in rehearsal and on the road.',
#   'popularity': 11.98,
#   'runtime': 97,
#   'revenue': 0,
#   'release_date': '2020-12-21',
#   'vote_average': 8.1,
#   'vote_count': 334,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Love & Taxes',
#   'original_title': 'ลอง ลีฟ เลิฟว์',
#   'budget': 0,
#   'id': 1026961,
#   'genre': ['Romance', 'Comedy'],
#   'language': 'th',
#   'homepage': 'https://longlivelovethailanddrama.splashthat.com',
#   'overview': 'A story about a party-animal Sati, a man whose attitude has left a broken family at home. Meta, his wife, is preparing to leave him. At age 15, his daughter, Namo is already jaded from a lifetime of broken promises.',
#   'popularity': 25.972,
#   'runtime': 135,
#   'revenue': 2122023,
#   'release_date': '2023-06-29',
#   'vote_average': 8.133,
#   'vote_count': 15,
#   'spoken_languages': ['Thai'],
#   'production_countries': ['Thailand']},
#  {'title': 'Berlin, I Love You',
#   'original_title': 'Berlin, I Love You',
#   'budget': 0,
#   'id': 401686,
#   'genre': ['Drama'],
#   'language': 'en',
#   'homepage': '',
#   'overview': 'An anthology feature of 10 stories of romance set in the German capital.',
#   'popularity': 7.791,
#   'runtime': 120,
#   'revenue': 163908,
#   'release_date': '2019-02-08',
#   'vote_average': 4.7,
#   'vote_count': 73,
#   'spoken_languages': ['English', 'German'],
#   'production_countries': ['Germany', 'United States of America']},
#  {'title': 'Godard Mon Amour',
#   'original_title': 'Le Redoutable',
#   'budget': 12840746,
#   'id': 416186,
#   'genre': ['Drama', 'Romance', 'Comedy'],
#   'language': 'fr',
#   'homepage': '',
#   'overview': 'In 1967, during the making of “La Chinoise,” film director Jean-Luc Godard falls in love with 19-year-old actress Anne Wiazemsky and marries her.',
#   'popularity': 11.216,
#   'runtime': 108,
#   'revenue': 82264,
#   'release_date': '2017-06-24',
#   'vote_average': 6.661,
#   'vote_count': 330,
#   'spoken_languages': ['Czech', 'French', 'English', 'Italian'],
#   'production_countries': ['Myanmar', 'France']},
#  {'title': 'Five Feet Apart',
#   'original_title': 'Five Feet Apart',
#   'budget': 7000000,
#   'id': 527641,
#   'genre': ['Romance', 'Drama'],
#   'language': 'en',
#   'homepage': '',
#   'overview': "Seventeen-year-old Stella spends most of her time in the hospital as a cystic fibrosis patient. Her life is full of routines, boundaries and self-control — all of which get put to the test when she meets Will, an impossibly charming teen who has the same illness. There's an instant flirtation, though restrictions dictate that they must maintain a safe distance between them. As their connection intensifies, so does the temptation to throw the rules out the window and embrace that attraction.",
#   'popularity': 40.528,
#   'runtime': 116,
#   'revenue': 92600000,
#   'release_date': '2019-03-14',
#   'vote_average': 8.282,
#   'vote_count': 5304,
#   'spoken_languages': ['English', 'Spanish', 'French'],
#   'production_countries': ['United States of America']},
#  {'title': 'Two of Us',
#   'original_title': "L'Amour et les Forêts",
#   'budget': 0,
#   'id': 989672,
#   'genre': ['Thriller', 'Drama', 'Romance'],
#   'language': 'fr',
#   'homepage': '',
#   'overview': 'When Blanche meets Grégoire, she thinks she has found the one. The ties that bind them grow quickly, and a passionate affair ensues. Together, they relocate. For Blanche, far from her family, from her twin sister, Rose, a new life begins. But little by little, she finds herself caught in the grip of a deeply possessive and dangerous man.',
#   'popularity': 15.491,
#   'runtime': 105,
#   'revenue': 0,
#   'release_date': '2023-05-24',
#   'vote_average': 7.039,
#   'vote_count': 141,
#   'spoken_languages': ['French'],
#   'production_countries': ['France']},
#  {'title': 'Stay Prayed Up',
#   'original_title': 'Stay Prayed Up',
#   'budget': 0,
#   'id': 869628,
#   'genre': ['Documentary'],
#   'language': 'en',
#   'homepage': '',
#   'overview': 'Lena Mae “Mother” Perry, the backbone of her community, cooks for crowds, tends to the needy, and boy, can she sing! After 50 years leading the dynamic, down-home gospel group The Branchettes, the octogenarian powerhouse, armed with her unwavering faith, shows no signs of slowing down. Taking us inside her loving community while following the recording of the group’s first album, this film is bursting with warmth, joy, and soul-stirring gospel music.',
#   'popularity': 0.6,
#   'runtime': 73,
#   'revenue': 0,
#   'release_date': '2021-09-01',
#   'vote_average': 0.0,
#   'vote_count': 0,
#   'spoken_languages': [],
#   'production_countries': []},
#  {'title': 'Asia',
#   'original_title': "2019 GFRIEND ASIA TOUR 'GO GO GFRIEND!'",
#   'budget': 0,
#   'id': 684527,
#   'genre': ['Music'],
#   'language': 'ko',
#   'homepage': '',
#   'overview': "Go Go GFriend! is GFriend's 2nd Asia tour. The tour was held at South Korea, Malaysia, Singapore, Thailand, Hong Kong, Indonesia, Philippines, Taiwan, and Japan.",
#   'popularity': 3.234,
#   'runtime': 170,
#   'revenue': 0,
#   'release_date': '2019-05-19',
#   'vote_average': 7.344,
#   'vote_count': 32,
#   'spoken_languages': ['Korean'],
#   'production_countries': []},
#  {'title': 'The In Between',
#   'original_title': 'The In Between',
#   'budget': 0,
#   'id': 818750,
#   'genre': ['Romance', 'Science Fiction', 'Drama'],
#   'language': 'en',
#   'homepage': 'https://www.netflix.com/title/81447264',
#   'overview': "After surviving a car accident that took the life of her boyfriend, a teenage girl believes he's attempting to reconnect with her from the after world.",
#   'popularity': 29.827,
#   'runtime': 116,
#   'revenue': 0,
#   'release_date': '2022-02-11',
#   'vote_average': 7.389,
#   'vote_count': 637,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Anaïs in Love',
#   'original_title': 'Les Amours d’Anaïs',
#   'budget': 0,
#   'id': 781453,
#   'genre': ['Drama', 'Romance', 'Comedy'],
#   'language': 'fr',
#   'homepage': '',
#   'overview': 'A young woman struggling to stay on top of everything in her life meets a married publisher and begins an affair with him.',
#   'popularity': 9.235,
#   'runtime': 98,
#   'revenue': 0,
#   'release_date': '2021-09-15',
#   'vote_average': 6.234,
#   'vote_count': 128,
#   'spoken_languages': ['French'],
#   'production_countries': ['France']},
#  {'title': 'I Love My Dad',
#   'original_title': 'I Love My Dad',
#   'budget': 0,
#   'id': 876825,
#   'genre': ['Comedy'],
#   'language': 'en',
#   'homepage': 'http://www.magpictures.com/ilovemydad/',
#   'overview': 'A hopelessly estranged father catfishes his son in an attempt to reconnect.',
#   'popularity': 9.975,
#   'runtime': 90,
#   'revenue': 0,
#   'release_date': '2022-08-05',
#   'vote_average': 5.763,
#   'vote_count': 40,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Ordinary Love',
#   'original_title': 'Ordinary Love',
#   'budget': 0,
#   'id': 588787,
#   'genre': ['Drama', 'Romance'],
#   'language': 'en',
#   'homepage': 'https://bleeckerstreetmedia.com/ordinary-love-film',
#   'overview': "An extraordinary look at the lives of a middle-aged couple in the midst of the wife's breast cancer diagnosis.",
#   'popularity': 13.049,
#   'runtime': 92,
#   'revenue': 0,
#   'release_date': '2019-12-06',
#   'vote_average': 6.861,
#   'vote_count': 126,
#   'spoken_languages': ['English'],
#   'production_countries': ['Ireland', 'United Kingdom']},
#  {'title': 'The Pink Cloud',
#   'original_title': 'A Nuvem Rosa',
#   'budget': 0,
#   'id': 776490,
#   'genre': ['Drama', 'Science Fiction'],
#   'language': 'pt',
#   'homepage': '',
#   'overview': 'Giovana and Yago are strangers who share a spark after meeting at a party. When a deadly cloud mysteriously takes over their city, they are forced to seek shelter with only each other for company. As months pass and the planet settles into an extended quarantine, their world shrinks, and they are forced to come to terms with an accelerated timeline for their relationship. With all their other interactions governed by screens, and with the strain of isolation setting in, Giovana and Yago struggle to reinvent themselves and reconcile the differences that threaten to tear them apart.',
#   'popularity': 2.638,
#   'runtime': 105,
#   'revenue': 0,
#   'release_date': '2021-04-01',
#   'vote_average': 6.02,
#   'vote_count': 25,
#   'spoken_languages': ['Portuguese'],
#   'production_countries': ['Brazil']},
#  {'title': 'Running Against the Wind',
#   'original_title': 'የነፋሱ ፍልሚያ',
#   'budget': 0,
#   'id': 631831,
#   'genre': ['Drama'],
#   'language': 'am',
#   'homepage': '',
#   'overview': 'The film follows the fate of two boys, one of whom hopes to become an Olympic runner and the other a photographer.',
#   'popularity': 2.247,
#   'runtime': 112,
#   'revenue': 0,
#   'release_date': '2023-07-20',
#   'vote_average': 6.5,
#   'vote_count': 0,
#   'spoken_languages': ['Amharic'],
#   'production_countries': ['Ethiopia', 'Germany']},
#  {'title': 'Frank & Lola,’ Retreading Old Groun',
#   'original_title': 'Cuando Frank conoció a Carlitos',
#   'budget': 0,
#   'id': 1158529,
#   'genre': ['Drama', 'Comedy', 'Music'],
#   'language': 'es',
#   'homepage': '',
#   'overview': 'According to an anecdote that has been going around the Internet for several years, in 1934 Gardel was performing on NBC in New York when he was introduced to a young admirer who was eager to meet him. As it turns out, he was none other than 19-year-old Frank Sinatra. Nobody is certain about whether that meeting happened or not but rumor has it that during the night, Gardel and Sinatra were locked in a dressing room together.',
#   'popularity': 2.348,
#   'runtime': 72,
#   'revenue': 0,
#   'release_date': '2023-08-18',
#   'vote_average': 8.071,
#   'vote_count': 7,
#   'spoken_languages': ['English', 'Italian', 'Spanish'],
#   'production_countries': ['Argentina', 'Mexico']},
#  {'title': 'Loro',
#   'original_title': 'Loro',
#   'budget': 0,
#   'id': 541660,
#   'genre': ['Drama'],
#   'language': 'it',
#   'homepage': '',
#   'overview': 'Internationally released Director\'s Cut of "Loro 1" and "Loro 2", which were released separately as two movies in Italy. The film talks about the group of businessmen and politicians – the Loro (Them) from the title – who live and act near to media tycoon and politician Silvio Berlusconi in the years between 2006 and 2009.',
#   'popularity': 9.499,
#   'runtime': 157,
#   'revenue': 0,
#   'release_date': '2018-09-13',
#   'vote_average': 6.683,
#   'vote_count': 259,
#   'spoken_languages': ['Italian'],
#   'production_countries': ['France', 'Italy']},
#  {'title': 'Asako I & II',
#   'original_title': '寝ても覚めても',
#   'budget': 0,
#   'id': 487850,
#   'genre': ['Drama', 'Romance'],
#   'language': 'ja',
#   'homepage': 'http://www.netemosametemo.jp/',
#   'overview': "College student Asako falls in love at first sight with Baku after meeting at a photography exhibit. Romance sparks between the two but doesn't last long when Baku suddenly disappears from her life. Two years later, she spots a man that bears a striking resemblance to him. Even though it is only his physical similarities to Baku that attracted her to him, she doesn't say so and starts dating the soft-spoken young man called Ryohei.",
#   'popularity': 12.612,
#   'runtime': 119,
#   'revenue': 0,
#   'release_date': '2018-09-01',
#   'vote_average': 6.9,
#   'vote_count': 149,
#   'spoken_languages': ['Japanese', 'English'],
#   'production_countries': ['Japan']},
#  {'title': 'The Attachment Diaries',
#   'original_title': 'El apego',
#   'budget': 0,
#   'id': 743040,
#   'genre': ['Drama', 'Mystery', 'Thriller', 'Horror'],
#   'language': 'es',
#   'homepage': '',
#   'overview': 'Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.',
#   'popularity': 1.26,
#   'runtime': 102,
#   'revenue': 0,
#   'release_date': '2021-10-07',
#   'vote_average': 4.0,
#   'vote_count': 2,
#   'spoken_languages': ['Spanish'],
#   'production_countries': ['Argentina']},
#  {'title': 'Babyteeth',
#   'original_title': 'Babyteeth',
#   'budget': 0,
#   'id': 522098,
#   'genre': ['Drama', 'Comedy', 'Romance'],
#   'language': 'en',
#   'homepage': 'http://babyteeth.movie',
#   'overview': 'A terminally ill teen upsets her parents when she falls in love with a small-time drug dealer.',
#   'popularity': 15.312,
#   'runtime': 118,
#   'revenue': 989310,
#   'release_date': '2020-06-15',
#   'vote_average': 6.865,
#   'vote_count': 304,
#   'spoken_languages': ['English'],
#   'production_countries': ['Australia']},
#  {'title': 'The Other Half',
#   'original_title': 'The Other Half',
#   'budget': 0,
#   'id': 381015,
#   'genre': ['Drama', 'Romance'],
#   'language': 'en',
#   'homepage': 'http://theotherhalfmovie.com/',
#   'overview': 'A grief-stricken man and a bipolar woman fall in love and attempt to forge a simple life together.',
#   'popularity': 3.568,
#   'runtime': 103,
#   'revenue': 0,
#   'release_date': '2016-12-02',
#   'vote_average': 6.2,
#   'vote_count': 21,
#   'spoken_languages': ['English'],
#   'production_countries': ['Canada']},
#  {'title': 'You Go to My Head',
#   'original_title': 'You Go To My Head',
#   'budget': 0,
#   'id': 508892,
#   'genre': ['Drama', 'Mystery', 'Romance', 'Thriller'],
#   'language': 'fr',
#   'homepage': 'http://yougotomyhead.com/',
#   'overview': "Following a mysterious car accident in the desert, Dafne suffers from post-traumatic amnesia. Jake, the first person she sees when she regains consciousness, tells her he's her husband.",
#   'popularity': 1.46,
#   'runtime': 116,
#   'revenue': 0,
#   'release_date': '2017-10-26',
#   'vote_average': 6.7,
#   'vote_count': 9,
#   'spoken_languages': ['English', 'French'],
#   'production_countries': ['Belgium', 'France', 'Germany']},
#  {'title': 'Ammonite',
#   'original_title': 'Ammonite',
#   'budget': 0,
#   'id': 568467,
#   'genre': ['Romance', 'Drama'],
#   'language': 'en',
#   'homepage': 'https://www.ammonite-movie.com',
#   'overview': 'In 1840s England, palaeontologist Mary Anning and a young woman sent by her husband to convalesce by the sea develop an intense relationship. Despite the chasm between their social spheres and personalities, Mary and Charlotte discover they can each offer what the other has been searching for: the realisation that they are not alone. It is the beginning of a passionate and all-consuming love affair that will defy all social bounds and alter the course of both lives irrevocably.',
#   'popularity': 17.064,
#   'runtime': 118,
#   'revenue': 1396905,
#   'release_date': '2020-11-13',
#   'vote_average': 7.056,
#   'vote_count': 500,
#   'spoken_languages': ['English'],
#   'production_countries': ['United Kingdom']},
#  {'title': 'Annette',
#   'original_title': 'Annette',
#   'budget': 15500000,
#   'id': 424277,
#   'genre': ['Drama', 'Romance'],
#   'language': 'fr',
#   'homepage': 'https://www.amazon.com/dp/B093KHDSHR',
#   'overview': 'The story of Henry, a stand-up comedian with a fierce sense of humour and Ann, a singer of international renown. In the spotlight, they are the perfect couple, healthy, happy, and glamourous. The birth of their first child, Annette, a mysterious girl with an exceptional destiny, will change their lives.',
#   'popularity': 18.021,
#   'runtime': 140,
#   'revenue': 3700000,
#   'release_date': '2021-07-07',
#   'vote_average': 6.777,
#   'vote_count': 622,
#   'spoken_languages': ['English', 'French'],
#   'production_countries': ['Belgium',
#    'France',
#    'Germany',
#    'Greece',
#    'Japan',
#    'Mexico',
#    'Switzerland']},
#  {'title': 'Alone Together',
#   'original_title': 'Alone Together',
#   'budget': 0,
#   'id': 826113,
#   'genre': ['Romance', 'Drama'],
#   'language': 'en',
#   'homepage': '',
#   'overview': 'Strangers June and Charlie wind up double-booked in the same upstate New York Airbnb during the start of COVID-19. Exasperating the situation, the lockdown forces them both to stay and confront the unexpected feelings that develop between them.',
#   'popularity': 7.586,
#   'runtime': 101,
#   'revenue': 0,
#   'release_date': '2022-07-22',
#   'vote_average': 5.067,
#   'vote_count': 30,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'City of Gold',
#   'original_title': 'Dora and the Lost City of Gold',
#   'budget': 49000000,
#   'id': 499701,
#   'genre': ['Adventure', 'Comedy', 'Family', 'Fantasy'],
#   'language': 'en',
#   'homepage': 'https://www.paramount.com/movies/dora-and-lost-city-gold',
#   'overview': 'Dora, a girl who has spent most of her life exploring the jungle with her parents, now must navigate her most dangerous adventure yet: high school. Always the explorer, Dora quickly finds herself leading Boots (her best friend, a monkey), Diego, and a rag tag group of teens on an adventure to save her parents and solve the impossible mystery behind a lost Inca civilization.',
#   'popularity': 36.091,
#   'runtime': 102,
#   'revenue': 120600000,
#   'release_date': '2019-08-08',
#   'vote_average': 6.7,
#   'vote_count': 1595,
#   'spoken_languages': ['Spanish', 'English'],
#   'production_countries': ['Australia', 'United States of America']},
#  {'title': 'Love After Love',
#   'original_title': 'Love After Love',
#   'budget': 0,
#   'id': 426251,
#   'genre': ['Drama'],
#   'language': 'en',
#   'homepage': '',
#   'overview': 'A sixty-something mother and her two adult sons cope and move onward following the death of their larger-than-life father/husband.',
#   'popularity': 1.694,
#   'runtime': 93,
#   'revenue': 0,
#   'release_date': '2018-03-30',
#   'vote_average': 5.6,
#   'vote_count': 19,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Sorry Angel',
#   'original_title': 'Plaire, aimer et courir vite',
#   'budget': 0,
#   'id': 485189,
#   'genre': ['Comedy', 'Drama', 'Romance'],
#   'language': 'fr',
#   'homepage': '',
#   'overview': "Jacques is a writer living in Paris. He hasn't turned 40 but already mistrusts that the best in life is yet to come. Arthur is a student living in Brittany. He reads and smiles a lot and refuses to think that everything in life might not be possible. Jacques and Arthur will like each other. Just like in a lovely dream. Just like in a sad story.",
#   'popularity': 11.329,
#   'runtime': 132,
#   'revenue': 1631910,
#   'release_date': '2018-05-09',
#   'vote_average': 6.831,
#   'vote_count': 207,
#   'spoken_languages': ['Spanish', 'French'],
#   'production_countries': ['France']},
#  {'title': 'About Fate',
#   'original_title': 'About Fate',
#   'budget': 0,
#   'id': 828613,
#   'genre': ['Romance', 'Comedy'],
#   'language': 'en',
#   'homepage': '',
#   'overview': "Two strangers believe in love but never seem to be able to find its true meaning. In a wild twist of events, fate puts each in the other's path on one stormy New Year's Eve.",
#   'popularity': 20.384,
#   'runtime': 100,
#   'revenue': 0,
#   'release_date': '2022-09-08',
#   'vote_average': 7.447,
#   'vote_count': 276,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Love & Gelato',
#   'original_title': 'ลอง ลีฟ เลิฟว์',
#   'budget': 0,
#   'id': 1026961,
#   'genre': ['Romance', 'Comedy'],
#   'language': 'th',
#   'homepage': 'https://longlivelovethailanddrama.splashthat.com',
#   'overview': 'A story about a party-animal Sati, a man whose attitude has left a broken family at home. Meta, his wife, is preparing to leave him. At age 15, his daughter, Namo is already jaded from a lifetime of broken promises.',
#   'popularity': 25.972,
#   'runtime': 135,
#   'revenue': 2122023,
#   'release_date': '2023-06-29',
#   'vote_average': 8.133,
#   'vote_count': 15,
#   'spoken_languages': ['Thai'],
#   'production_countries': ['Thailand']},
#  {'title': 'First Love',
#   'original_title': 'かぐや様は告らせたい-ファーストキッスは終わらない-',
#   'budget': 0,
#   'id': 997317,
#   'genre': ['Animation', 'Comedy', 'Romance'],
#   'language': 'ja',
#   'homepage': 'https://kaguyasama-anime.com',
#   'overview': 'After pining for one another and plotting for so long, Kaguya Shinomiya and Miyuki Shirogane finally have their climactic first kiss. However, they struggle to define their relationship. After all, how much of their true selves have they really shown to one another?',
#   'popularity': 41.416,
#   'runtime': 96,
#   'revenue': 0,
#   'release_date': '2022-12-17',
#   'vote_average': 7.917,
#   'vote_count': 48,
#   'spoken_languages': ['Japanese'],
#   'production_countries': ['Japan']},
#  {'title': 'Ride or Die',
#   'original_title': '彼女',
#   'budget': 0,
#   'id': 796849,
#   'genre': ['Drama', 'Romance', 'Thriller'],
#   'language': 'ja',
#   'homepage': 'https://www.netflix.com/title/81261676',
#   'overview': "Rei helps the woman she's been in love with for years escape her abusive husband. While on the run, their feelings for each other catch fire.",
#   'popularity': 23.307,
#   'runtime': 142,
#   'revenue': 0,
#   'release_date': '2021-04-15',
#   'vote_average': 6.794,
#   'vote_count': 143,
#   'spoken_languages': ['English', 'Japanese'],
#   'production_countries': ['Japan']},
#  {'title': 'Happier Than Ever',
#   'original_title': 'Happier Than Ever: A Love Letter to Los Angeles',
#   'budget': 0,
#   'id': 853088,
#   'genre': ['Music', 'Documentary'],
#   'language': 'en',
#   'homepage': 'https://www.disneyplus.com/movies/happier-than-ever-a-love-letter-to-los-angeles/21VAuvZk4Ssk',
#   'overview': 'Fresh off the heels of her brand-new album, "Happier Than Ever," this cinematic concert experience features an intimate performance of every song in the album\'s sequential order – for the first and only time – from the stage of the legendary Hollywood Bowl.',
#   'popularity': 10.997,
#   'runtime': 65,
#   'revenue': 0,
#   'release_date': '2021-09-03',
#   'vote_average': 7.9,
#   'vote_count': 113,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Love Wedding Repeat',
#   'original_title': 'Love Wedding Repeat',
#   'budget': 0,
#   'id': 624808,
#   'genre': ['Comedy', 'Romance'],
#   'language': 'en',
#   'homepage': 'https://www.netflix.com/title/80227754',
#   'overview': "While trying to make his sister's wedding day go smoothly, Jack finds himself juggling an angry ex-girlfriend, an uninvited guest with a secret, a misplaced sleep sedative, and the girl that got away in alternate versions of the same day.",
#   'popularity': 10.686,
#   'runtime': 100,
#   'revenue': 0,
#   'release_date': '2020-04-10',
#   'vote_average': 5.648,
#   'vote_count': 665,
#   'spoken_languages': ['English', 'Italian'],
#   'production_countries': ['United Kingdom', 'Italy']},
#  {'title': 'Black Mother',
#   'original_title': 'Black Mother',
#   'budget': 0,
#   'id': 500859,
#   'genre': ['Documentary'],
#   'language': 'en',
#   'homepage': 'https://dogwoof.com/blackmother',
#   'overview': 'Part film, part baptism, in BLACK MOTHER director Khalik Allah brings us on a spiritual journey through Jamaica. Soaking up its bustling metropolises and tranquil countryside, Allah introduces us to a succession of vividly rendered souls who call this island home. Their candid testimonies create a polyphonic symphony, set against a visual prayer of indelible portraiture. Thoroughly immersed between the sacred and profane, BLACK MOTHER channels rebellion and reverence into a deeply personal ode informed by Jamaica’s turbulent history but existing in the urgent present.',
#   'popularity': 1.756,
#   'runtime': 77,
#   'revenue': 0,
#   'release_date': '2018-11-02',
#   'vote_average': 6.6,
#   'vote_count': 16,
#   'spoken_languages': ['English'],
#   'production_countries': ['Jamaica', 'United States of America']},
#  {'title': 'I Love America',
#   'original_title': 'I Love America',
#   'budget': 0,
#   'id': 846238,
#   'genre': ['Comedy', 'Romance'],
#   'language': 'fr',
#   'homepage': '',
#   'overview': 'A single woman who decides to take a chance on love again by catapulting her life from Paris to Los Angeles. From awkward dates to touching surprise encounters, she understands the journey to love is a journey towards herself.',
#   'popularity': 7.619,
#   'runtime': 102,
#   'revenue': 0,
#   'release_date': '2022-03-11',
#   'vote_average': 5.171,
#   'vote_count': 70,
#   'spoken_languages': ['French'],
#   'production_countries': ['United States of America']},
#  {'title': 'My Love, Don’t Cross That River',
#   'original_title': '님아, 그 강을 건너지 마오',
#   'budget': 0,
#   'id': 306598,
#   'genre': ['Documentary', 'Romance', 'Drama'],
#   'language': 'ko',
#   'homepage': 'http://anata-river.com/',
# ...
#   'overview': 'A rural American town suffering economically from factory closures finds an unconventional route to recovery with the help of MASS MoCA.',
#   'popularity': 0.643,
#   'runtime': 75,
#   'revenue': 0,
#   'release_date': '2019-03-10',
#   'vote_average': 0.0,
#   'vote_count': 0,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Future People',
#   'original_title': 'Future People: The Family of Donor 5114',
#   'budget': 0,
#   'id': 816819,
#   'genre': ['Documentary'],
#   'language': 'en',
#   'homepage': '',
#   'overview': 'Filmed over eight years, Rothman follows a group of adolescents who discover that they were conceived from the same sperm donor, forming an unlikely family of familiar strangers. There are presently 37 half-siblings, and counting. This documentary explores the complexities of alternative conception while defining a new realm of modern family.',
#   'popularity': 0.6,
#   'runtime': 102,
#   'revenue': 0,
#   'release_date': '2021-04-09',
#   'vote_average': 0.0,
#   'vote_count': 0,
#   'spoken_languages': ['English'],
#   'production_countries': []},
#  {'title': 'Marguerite & Julien,’ a Tale of Siblings in Lov',
#   'original_title': 'Le Théorème de Marguerite',
#   'budget': 2470000,
#   'id': 960033,
#   'genre': ['Drama'],
#   'language': 'fr',
#   'homepage': '',
#   'overview': 'Marguerite is a young and brilliant mathematician, the only girl in her class at the ENS, entirely devoted to her passion. The day she discovers an error in her thesis, she is devastated. In a dizzy spell, she leaves the school, wipes out the past. She then dives into the real world, discovers autonomy, befriends the young Léa, and makes love for the first time. Grown by her experiences, it is in this new momentum that she will find the solution to her theorem.',
#   'popularity': 4.368,
#   'runtime': 112,
#   'revenue': 0,
#   'release_date': '2023-11-01',
#   'vote_average': 6.583,
#   'vote_count': 18,
#   'spoken_languages': ['French'],
#   'production_countries': ['France', 'Switzerland']},
#  {'title': 'The Party',
#   'original_title': 'The Party',
#   'budget': 1500000,
#   'id': 10794,
#   'genre': ['Comedy'],
#   'language': 'en',
#   'homepage': '',
#   'overview': 'Hrundi V. Bakshi, an accident-prone actor from India, is accidentally put on the guest list for an upcoming party at the home of a Hollywood film producer. Unfortunately, from the moment he arrives, one thing after another goes wrong with compounding effect.',
#   'popularity': 12.948,
#   'runtime': 99,
#   'revenue': 2900000,
#   'release_date': '1968-04-04',
#   'vote_average': 7.277,
#   'vote_count': 691,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'To All the Boys: Always and Forever',
#   'original_title': 'To All the Boys: Always and Forever',
#   'budget': 0,
#   'id': 614409,
#   'genre': ['Romance', 'Comedy', 'Drama'],
#   'language': 'en',
#   'homepage': 'https://www.netflix.com/title/81040397',
#   'overview': 'Senior year of high school takes center stage as Lara Jean returns from a family trip to Korea and considers her college plans — with and without Peter.',
#   'popularity': 25.615,
#   'runtime': 115,
#   'revenue': 0,
#   'release_date': '2021-02-12',
#   'vote_average': 7.588,
#   'vote_count': 1776,
#   'spoken_languages': ['English', 'Korean'],
#   'production_countries': ['United States of America']},
#  {'title': '69: The Saga of Danny Hernandez',
#   'original_title': '69: The Saga of Danny Hernandez',
#   'budget': 0,
#   'id': 765057,
#   'genre': ['Music', 'Documentary'],
#   'language': 'en',
#   'homepage': 'https://www.hulu.com/movie/69-the-saga-of-danny-hernandez-345025ec-5022-4cca-a5f7-d3870fce96b3',
#   'overview': 'Part investigative documentary, part real-life gangster movie, this film unpacks the life of polarizing rap sensation and internet troll Tekashi69, aka 69, while chronicling his meteoric rise and fall from fame.',
#   'popularity': 2.321,
#   'runtime': 101,
#   'revenue': 0,
#   'release_date': '2021-04-29',
#   'vote_average': 6.9,
#   'vote_count': 10,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'The Lost Weekend: A Love Story',
#   'original_title': 'The Lost Weekend: A Love Story',
#   'budget': 0,
#   'id': 965042,
#   'genre': ['Documentary'],
#   'language': 'en',
#   'homepage': 'https://thelostweekendmovie.com/',
#   'overview': 'May Pang lovingly recounts her life in rock & roll and the whirlwind 18 months spent as friend, lover, and confidante to one of the towering figures of popular culture, John Lennon, in this funny, touching, and vibrant portrait of first love.',
#   'popularity': 2.071,
#   'runtime': 95,
#   'revenue': 0,
#   'release_date': '2023-04-13',
#   'vote_average': 6.0,
#   'vote_count': 2,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Art of Love',
#   'original_title': "L'Art d'aimer",
#   'budget': 0,
#   'id': 92424,
#   'genre': ['Romance', 'Comedy'],
#   'language': 'fr',
#   'homepage': '',
#   'overview': 'The Art of Love is composed of several chapters, which follows several Parisian couples.',
#   'popularity': 4.527,
#   'runtime': 85,
#   'revenue': 0,
#   'release_date': '2011-11-23',
#   'vote_average': 5.855,
#   'vote_count': 55,
#   'spoken_languages': ['French'],
#   'production_countries': ['France']},
#  {'title': 'Asher',
#   'original_title': 'Asher',
#   'budget': 0,
#   'id': 529982,
#   'genre': ['Thriller', 'Action', 'Drama'],
#   'language': 'en',
#   'homepage': '',
#   'overview': "Asher is a former Mossad agent turned gun for hire, living an austere life in an ever-changing Brooklyn. Approaching the end of his career, he breaks the oath he took as a young man when he meets Sophie on a hit gone wrong. In order to have love in his life before it's too late, he must kill the man he was, for a chance at becoming the man he wants to be.",
#   'popularity': 10.283,
#   'runtime': 117,
#   'revenue': 0,
#   'release_date': '2018-12-07',
#   'vote_average': 5.788,
#   'vote_count': 132,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Wild Mountain Thyme',
#   'original_title': 'Wild Mountain Thyme',
#   'budget': 0,
#   'id': 628333,
#   'genre': ['Romance', 'Drama'],
#   'language': 'en',
#   'homepage': '',
#   'overview': "Headstrong farmer Rosemary Muldoon has her heart set on winning her neighbour Anthony Reilly's love. The problem is, Anthony seems to have inherited a family curse, and remains oblivious to his beautiful admirer. Stung by his father's plans to sell the family farm to his American nephew, Anthony is jolted into pursuing his dreams.",
#   'popularity': 10.971,
#   'runtime': 102,
#   'revenue': 0,
#   'release_date': '2020-12-11',
#   'vote_average': 5.141,
#   'vote_count': 142,
#   'spoken_languages': ['English'],
#   'production_countries': ['Ireland', 'United Kingdom']},
#  {'title': 'Diane',
#   'original_title': 'Diane',
#   'budget': 0,
#   'id': 510034,
#   'genre': ['Drama'],
#   'language': 'en',
#   'homepage': '',
#   'overview': 'Diane is a devoted friend and caretaker, particularly to her drug-addicted son. But as those around her begin to drift away in the last quarter of her life, she is left to reckon with past choices and long-dormant memories.',
#   'popularity': 3.588,
#   'runtime': 96,
#   'revenue': 0,
#   'release_date': '2019-03-28',
#   'vote_average': 6.206,
#   'vote_count': 34,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Luz',
#   'original_title': 'Luz',
#   'budget': 0,
#   'id': 1193055,
#   'genre': [],
#   'language': 'es',
#   'homepage': '',
#   'overview': '',
#   'popularity': 1.778,
#   'runtime': 0,
#   'revenue': 0,
#   'release_date': '2023-10-31',
#   'vote_average': 0.0,
#   'vote_count': 0,
#   'spoken_languages': [],
#   'production_countries': []},
#  {'title': 'Lingui, the Sacred Bonds',
#   'original_title': 'Lingui : les liens sacrés',
#   'budget': 0,
#   'id': 820693,
#   'genre': ['Drama'],
#   'language': 'fr',
#   'homepage': '',
#   'overview': 'On the outskirts of the capital of Chad, determined single mother Amina works tirelessly to provide for herself and her 15-year old daughter Maria. When Amina discovers Maria is pregnant and does not want a child, the two women begin to seek out an abortion, condemned by both religion and law. In the process, mother and daughter forge a connection stronger than any they’ve ever known.',
#   'popularity': 5.164,
#   'runtime': 88,
#   'revenue': 0,
#   'release_date': '2021-12-08',
#   'vote_average': 6.661,
#   'vote_count': 28,
#   'spoken_languages': ['Arabic', 'French'],
#   'production_countries': ['Germany', 'Belgium', 'Chad', 'France']},
#  {'title': 'Preparations to Be Together',
#   'original_title': 'Felkészülés meghatározatlan ideig tartó együttlétre',
#   'budget': 1000000,
#   'id': 727002,
#   'genre': ['Drama'],
#   'language': 'hu',
#   'homepage': '',
#   'overview': 'Márta, a 40-year-old neurosurgeon, falls in love. She leaves her shining American career behind and returns to Budapest to start a new life with the man she loves. But she waits for him at the Liberty Bridge in vain - he does not appear at their rendezvous. Márta starts to search for him desperately, but when she finally finds him, the love of her life claims that they have never met before.',
#   'popularity': 4.452,
#   'runtime': 95,
#   'revenue': 117368,
#   'release_date': '2020-09-24',
#   'vote_average': 6.6,
#   'vote_count': 25,
#   'spoken_languages': ['English', 'Hungarian'],
#   'production_countries': ['Hungary']},
#  {'title': 'Atlantis',
#   'original_title': 'Atlantis',
#   'budget': 0,
#   'id': 15466,
#   'genre': ['Music', 'Documentary'],
#   'language': 'fr',
#   'homepage': '',
#   'overview': 'Atmospheric soundtrack follows this compilation of nature footage that focuses on the ocean and various life forms that live, mate and die in it.',
#   'popularity': 6.512,
#   'runtime': 74,
#   'revenue': 138,
#   'release_date': '1991-08-21',
#   'vote_average': 6.2,
#   'vote_count': 41,
#   'spoken_languages': ['French'],
#   'production_countries': ['France', 'Italy']},
#  {'title': 'Thor: Love and Thunder',
#   'original_title': 'Thor: Love and Thunder',
#   'budget': 250000000,
#   'id': 616037,
#   'genre': ['Fantasy', 'Action', 'Comedy'],
#   'language': 'en',
#   'homepage': 'https://www.marvel.com/movies/thor-love-and-thunder',
#   'overview': 'After his retirement is interrupted by Gorr the God Butcher, a galactic killer who seeks the extinction of the gods, Thor Odinson enlists the help of King Valkyrie, Korg, and ex-girlfriend Jane Foster, who now wields Mjolnir as the Mighty Thor. Together they embark upon a harrowing cosmic adventure to uncover the mystery of the God Butcher’s vengeance and stop him before it’s too late.',
#   'popularity': 133.692,
#   'runtime': 119,
#   'revenue': 760928081,
#   'release_date': '2022-07-06',
#   'vote_average': 6.502,
#   'vote_count': 6693,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'A Tuba to Cuba',
#   'original_title': 'A Tuba To Cuba',
#   'budget': 0,
#   'id': 502190,
#   'genre': ['Documentary', 'Music', 'History'],
#   'language': 'en',
#   'homepage': 'https://www.atubatocuba.com/',
#   'overview': 'A son seeking to fulfill his late father’s dream takes his band from the storied city of New Orleans to the shores of Cuba, where — through the universal language of music — dark and ancient connections between their peoples reveal the roots of jazz.',
#   'popularity': 1.086,
#   'runtime': 82,
#   'revenue': 0,
#   'release_date': '2019-02-15',
#   'vote_average': 6.6,
#   'vote_count': 8,
#   'spoken_languages': ['English'],
#   'production_countries': ['Cuba', 'United States of America']},
#  {'title': 'The Woman Who Loves Giraffes',
#   'original_title': 'The Woman Who Loves Giraffes',
#   'budget': 0,
#   'id': 544825,
#   'genre': ['Documentary'],
#   'language': 'en',
#   'homepage': '',
#   'overview': 'Dr. Anne Innis Dagg re-traces the steps of her groundbreaking 1956 journey to South Africa to study giraffes in the wild. Now, at 85 years old, Anne sees a startling contrast between the world of giraffes she once knew and the one it has become. Weaving through the past and present, her harrowing journey gives us an intimate look into the factors that destroyed her career and the forces that brought her back.',
#   'popularity': 1.651,
#   'runtime': 81,
#   'revenue': 0,
#   'release_date': '2018-10-03',
#   'vote_average': 7.0,
#   'vote_count': 12,
#   'spoken_languages': [],
#   'production_countries': ['Canada',
#    'South Africa',
#    'United States of America']},
#  {'title': 'In From the Side',
#   'original_title': 'In from the Side',
#   'budget': 0,
#   'id': 622082,
#   'genre': ['Drama', 'Romance'],
#   'language': 'en',
#   'homepage': 'http://www.infromthesidemovie.com',
#   'overview': 'Mark, a new and inexperienced rugby club member, finds himself drawn to Warren, a seasoned first team player. When a series of happenstances at an away fixture lead to a drunken encounter, Mark and Warren unwittingly embark on a romantic affair they struggle to hide from their partners and teammates.',
#   'popularity': 12.489,
#   'runtime': 134,
#   'revenue': 0,
#   'release_date': '2022-09-16',
#   'vote_average': 7.068,
#   'vote_count': 44,
#   'spoken_languages': ['English'],
#   'production_countries': ['United Kingdom']},
#  {'title': 'Hot Air',
#   'original_title': 'Hot Air',
#   'budget': 0,
#   'id': 479315,
#   'genre': ['Drama'],
#   'language': 'en',
#   'homepage': '',
#   'overview': "A right-wing talk show host's life takes a sudden turn when his 16-year-old niece comes crashing into his life.",
#   'popularity': 3.088,
#   'runtime': 99,
#   'revenue': 0,
#   'release_date': '2018-04-10',
#   'vote_average': 5.219,
#   'vote_count': 16,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'Casanova, Last Love',
#   'original_title': 'Dernier amour',
#   'budget': 0,
#   'id': 504605,
#   'genre': ['Drama', 'Romance'],
#   'language': 'fr',
#   'homepage': 'https://lesfilmsdufleuve.be/en/movies/dernier-amour',
#   'overview': 'Year 1763. Forced into exile, the famous libertine Giacomo Casanova leaves Paris and travels to London, where he meets Marianne de Charpillon, a young prostitute to whom he is so attracted that he forgets about the other women.',
#   'popularity': 9.66,
#   'runtime': 99,
#   'revenue': 0,
#   'release_date': '2019-03-20',
#   'vote_average': 4.9,
#   'vote_count': 33,
#   'spoken_languages': ['English', 'French', 'German', 'Italian'],
#   'production_countries': ['Belgium', 'France', 'United States of America']},
#  {'title': 'Dinner in America',
#   'original_title': 'Dinner in America',
#   'budget': 0,
#   'id': 653664,
#   'genre': ['Comedy', 'Drama', 'Music', 'Romance'],
#   'language': 'en',
#   'homepage': '',
#   'overview': 'An on-the-lam punk rocker and a young woman obsessed with his band go on an unexpected and epic journey together through the decaying suburbs of the American Midwest.',
#   'popularity': 12.923,
#   'runtime': 106,
#   'revenue': 0,
#   'release_date': '2020-05-27',
#   'vote_average': 6.8,
#   'vote_count': 68,
#   'spoken_languages': ['English'],
#   'production_countries': ['United States of America']},
#  {'title': 'The Inspection',
#   'original_title': 'The Inspection',
#   'budget': 0,
#   'id': 837938,
#   'genre': ['Drama'],
#   'language': 'en',
#   'homepage': 'https://a24films.com/films/inspection',
#   'overview': 'Ellis French is a young, gay Black man, rejected by his mother and with few options for his future, decides to join the Marines, doing whatever it takes to succeed in a system that would cast him aside. But even as he battles deep-seated prejudice and the grueling routines of basic training, he finds unexpected camaraderie, strength, and support in this new community, giving him a hard-earned sense of belonging that will shape his identity and forever change his life.',
#   'popularity': 9.399,
#   'runtime': 95,
#   'revenue': 0,
#   'release_date': '2022-11-18',
#   'vote_average': 6.356,
#   'vote_count': 45,
#   'spoken_languages': ['Arabic', 'Spanish', 'English'],
#   'production_countries': ['United States of America']}]

# %%
# Convert the results to a DataFrame
# Create an empty dataframe
movies_dataframe = pd.DataFrame(tmdb_movies_list)

"""
# Loop through pages in the dataframe
for page in tmdb_movies_list:
    movies_dataframe = pd.concat([tmdb_movies_list, pd.json_normalize(page)])

# Reset the index of the DataFrame
movies_dataframe = movies_dataframe.reset_index(drop=True)
"""
# Display the final DataFrame
movies_dataframe
# Out:
#                     title        original_title    budget      id  \
# 0        The Tomorrow Man      The Tomorrow Man         0  565391
# 1          Marriage Story        Marriage Story  18000000  492188
# 2           Bones and All         Bones and All  18000000  791177
# 3           Love, Antosha         Love, Antosha         0  565276
# 4    You Can Live Forever  You Can Live Forever         0  887580
# ..                    ...                   ...       ...     ...
# 98       In From the Side      In from the Side         0  622082
# 99                Hot Air               Hot Air         0  479315
# 100   Casanova, Last Love         Dernier amour         0  504605
# 101     Dinner in America     Dinner in America         0  653664
# 102        The Inspection        The Inspection         0  837938
#
#                                genre language  \
# 0                   [Drama, Romance]       en
# 1                            [Drama]       en
# 2           [Drama, Horror, Romance]       it
# 3                      [Documentary]       en
# 4                   [Drama, Romance]       en
# ..                               ...      ...
# 98                  [Drama, Romance]       en
# 99                           [Drama]       en
# 100                 [Drama, Romance]       fr
# 101  [Comedy, Drama, Music, Romance]       en
# 102                          [Drama]       en
#
#                                               homepage  \
# 0       https://bleeckerstreetmedia.com/thetomorrowman
# 1                  https://www.marriagestorymovie.com/
# 2                     https://www.bonesandallfilm.net/
# 3                         https://antonyelchindoc.com/
# 4    https://gooddeedentertainment.com/you-can-live...
# ..                                                 ...
# 98                   http://www.infromthesidemovie.com
# 99
# 100  https://lesfilmsdufleuve.be/en/movies/dernier-...
# 101
# 102              https://a24films.com/films/inspection
#
#                                               overview  popularity  runtime  \
# 0    Ed Hemsler spends his life preparing for a dis...       5.507       94
# 1    A stage director and an actress struggle throu...      25.424      137
# 2    Abandoned by her father, a young woman embarks...      22.870      131
# 3    From a prolific career in film and television,...      10.220       92
# 4    When Jaime, a gay teenager, is sent to live in...       7.338       96
# ..                                                 ...         ...      ...
# 98   Mark, a new and inexperienced rugby club membe...      12.489      134
# 99   A right-wing talk show host's life takes a sud...       3.088       99
# 100  Year 1763. Forced into exile, the famous liber...       9.660       99
# 101  An on-the-lam punk rocker and a young woman ob...      12.923      106
# 102  Ellis French is a young, gay Black man, reject...       9.399       95
#
#       revenue release_date  vote_average  vote_count  \
# 0           0   2019-05-22         5.630          50
# 1     2300000   2019-09-28         7.749        6545
# 2    15100000   2022-11-18         7.128        1070
# 3           0   2019-08-02         7.400          48
# 4           0   2022-06-11         7.263          38
# ..        ...          ...           ...         ...
# 98          0   2022-09-16         7.068          44
# 99          0   2018-04-10         5.219          16
# 100         0   2019-03-20         4.900          33
# 101         0   2020-05-27         6.800          68
# 102         0   2022-11-18         6.356          45
#
#                        spoken_languages  \
# 0                             [English]
# 1                             [English]
# 2                             [English]
# 3                    [English, Russian]
# 4                     [French, English]
# ..                                  ...
# 98                            [English]
# 99                            [English]
# 100  [English, French, German, Italian]
# 101                           [English]
# 102          [Arabic, Spanish, English]
#
#                             production_countries
# 0                     [United States of America]
# 1                               [United Kingdom]
# 2              [Italy, United States of America]
# 3                     [United States of America]
# 4                                       [Canada]
# ..                                           ...
# 98                              [United Kingdom]
# 99                    [United States of America]
# 100  [Belgium, France, United States of America]
# 101                   [United States of America]
# 102                   [United States of America]
#
# [103 rows x 16 columns]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_movie_review = pd.merge(movies_dataframe, reviews_dataframe, on='title')
merged_movie_review
# Out:
#                     title        original_title    budget      id  \
# 0        The Tomorrow Man      The Tomorrow Man         0  565391
# 1          Marriage Story        Marriage Story  18000000  492188
# 2           Bones and All         Bones and All  18000000  791177
# 3           Love, Antosha         Love, Antosha         0  565276
# 4    You Can Live Forever  You Can Live Forever         0  887580
# ..                    ...                   ...       ...     ...
# 98       In From the Side      In from the Side         0  622082
# 99                Hot Air               Hot Air         0  479315
# 100   Casanova, Last Love         Dernier amour         0  504605
# 101     Dinner in America     Dinner in America         0  653664
# 102        The Inspection        The Inspection         0  837938
#
#                                genre language  \
# 0                   [Drama, Romance]       en
# 1                            [Drama]       en
# 2           [Drama, Horror, Romance]       it
# 3                      [Documentary]       en
# 4                   [Drama, Romance]       en
# ..                               ...      ...
# 98                  [Drama, Romance]       en
# 99                           [Drama]       en
# 100                 [Drama, Romance]       fr
# 101  [Comedy, Drama, Music, Romance]       en
# 102                          [Drama]       en
#
#                                               homepage  \
# 0       https://bleeckerstreetmedia.com/thetomorrowman
# 1                  https://www.marriagestorymovie.com/
# 2                     https://www.bonesandallfilm.net/
# 3                         https://antonyelchindoc.com/
# 4    https://gooddeedentertainment.com/you-can-live...
# ..                                                 ...
# 98                   http://www.infromthesidemovie.com
# 99
# 100  https://lesfilmsdufleuve.be/en/movies/dernier-...
# 101
# 102              https://a24films.com/films/inspection
#
#                                               overview  popularity  runtime  \
# 0    Ed Hemsler spends his life preparing for a dis...       5.507       94
# 1    A stage director and an actress struggle throu...      25.424      137
# 2    Abandoned by her father, a young woman embarks...      22.870      131
# 3    From a prolific career in film and television,...      10.220       92
# 4    When Jaime, a gay teenager, is sent to live in...       7.338       96
# ..                                                 ...         ...      ...
# 98   Mark, a new and inexperienced rugby club membe...      12.489      134
# 99   A right-wing talk show host's life takes a sud...       3.088       99
# 100  Year 1763. Forced into exile, the famous liber...       9.660       99
# 101  An on-the-lam punk rocker and a young woman ob...      12.923      106
# 102  Ellis French is a young, gay Black man, reject...       9.399       95
#
#      ...                                      headline.main headline.kicker  \
# 0    ...  ‘The Tomorrow Man’ Review: Love Among the Neur...            None
# 1    ...  ‘Marriage Story’ Review: Dance Me to the End o...   critic’s pick
# 2    ...       ‘Bones and All’ Review: You Eat What You Are            None
# 3    ...  ‘Love, Antosha’ Review: A Heartbreaking Look a...   Critic’s Pick
# 4    ...  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# ..   ...                                                ...             ...
# 98   ...  ‘In From the Side’ Review: Love and Rugby Play...            None
# 99   ...  ‘Hot Air’ Review: A Right-Wing Radio Host Lear...            None
# 100  ...  ‘Casanova, Last Love’ Review: Reappraising a P...            None
# 101  ...  ‘Dinner in America’ Review: A Punk-Rock Love S...            None
# 102  ...   ‘The Inspection’ Review: Boot Camp, a Love Story   critic’s pick
#
#      headline.content_kicker  \
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# ..                       ...
# 98                      None
# 99                      None
# 100                     None
# 101                     None
# 102                     None
#
#                                headline.print_headline headline.name  \
# 0                   They Whirl, They Twirl, They Tango          None
# 1                     Friendly Split, Shattering Break          None
# 2    It’s Eat, Prey, Love on a Journey of Self-Disc...          None
# 3                                        Love, Antosha          None
# 4                                 You Can Live Forever          None
# ..                                                 ...           ...
# 98                                    In From the Side          None
# 99                                             Hot Air          None
# 100                                Casanova, Last Love          None
# 101                                  Dinner in America          None
# 102                  A Few Good Men, Some With Secrets          None
#
#     headline.seo headline.sub           byline.original  \
# 0           None         None    By Jeannette Catsoulis
# 1           None         None             By A.O. Scott
# 2           None         None             By A.O. Scott
# 3           None         None            By Glenn Kenny
# 4           None         None  By Elisabeth Vincentelli
# ..           ...          ...                       ...
# 98          None         None            By Kyle Turner
# 99          None         None            By Bilge Ebiri
# 100         None         None        By Beatrice Loayza
# 101         None         None     By Concepción de León
# 102         None         None             By A.O. Scott
#
#                                          byline.person byline.organization
# 0    [{'firstname': 'Jeannette', 'middlename': None...                None
# 1    [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 2    [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
# 3    [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 4    [{'firstname': 'Elisabeth', 'middlename': None...                None
# ..                                                 ...                 ...
# 98   [{'firstname': 'Kyle', 'middlename': None, 'la...                None
# 99   [{'firstname': 'Bilge', 'middlename': None, 'l...                None
# 100  [{'firstname': 'Beatrice', 'middlename': None,...                None
# 101  [{'firstname': 'Concepción', 'middlename': Non...                None
# 102  [{'firstname': 'A.', 'middlename': 'O.', 'last...                None
#
# [103 rows x 32 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing


# Create a list of characters to remove


# Loop through the list of columns to fix

    # Convert the column to type 'str'


    # Loop through characters to remove


# Display the fixed DataFrame
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#                               genre language spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror       es          Spanish
# 1                    Drama, Romance       en  French, English
# 2            Romance, Drama, Comedy       en          English
# 3                       Documentary       en
# 4                             Drama       en          English
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# 4  https://www.focusfeatures.com/a-thousand-and-one/
#
#                                             overview  popularity  runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...       0.708      102
# 1  When Jaime, a gay teenager, is sent to live in...      12.027       96
# 2  Emma and Jesse are living the perfect life tog...      28.872      100
# 3  May Pang lovingly recounts her life in rock & ...       2.368       97
# 4  Struggling but unapologetically living on her ...      11.704      116
#
#    ...                                      headline.main headline.kicker  \
# 0  ...        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ...  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2  ...     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 3  ...  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 4  ...  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
#
#    headline.content_kicker                  headline.print_headline  \
# 0                     None                   The Attachment Diaries
# 1                     None                     You Can Live Forever
# 2                     None                           One True Loves
# 3                     None          The Lost Weekend:  A Love Story
# 4                     None  An Unbending Will Meets a Shifting City
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None  By Elisabeth Vincentelli
# 2          None         None         None             By Brandon Yu
# 3          None         None         None            By Glenn Kenny
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 2  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 3  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
# [5 rows x 31 columns]

# %%
# Drop "byline.person" column

# %%
# Delete duplicate rows and reset index
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#                               genre language spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror       es          Spanish
# 1                    Drama, Romance       en  French, English
# 2            Romance, Drama, Comedy       en          English
# 3                       Documentary       en
# 4                             Drama       en          English
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# 4  https://www.focusfeatures.com/a-thousand-and-one/
#
#                                             overview  popularity  runtime  \
# 0  Argentina, 1970s. A desperate young woman goes...       0.708      102
# 1  When Jaime, a gay teenager, is sent to live in...      12.027       96
# 2  Emma and Jesse are living the perfect life tog...      28.872      100
# 3  May Pang lovingly recounts her life in rock & ...       2.368       97
# 4  Struggling but unapologetically living on her ...      11.704      116
#
#    ...  word_count                                      headline.main  \
# 0  ...         295        ‘The Attachment Diaries’ Review: Love, Sick
# 1  ...         294  ‘You Can Live Forever’ Review: Do You Love Me ...
# 2  ...         320     ‘One True Loves’ Review: A Romance Lost at Sea
# 3  ...         327  ‘The Lost Weekend: A Love Story’ Review: When ...
# 4  ...         971  ‘A Thousand and One’ Review: A New York Love S...
#
#    headline.kicker  headline.content_kicker  \
# 0             None                     None
# 1             None                     None
# 2             None                     None
# 3             None                     None
# 4    Critic’s Pick                     None
#
#                    headline.print_headline headline.name headline.seo  \
# 0                   The Attachment Diaries          None         None
# 1                     You Can Live Forever          None         None
# 2                           One True Loves          None         None
# 3          The Lost Weekend:  A Love Story          None         None
# 4  An Unbending Will Meets a Shifting City          None         None
#
#   headline.sub           byline.original byline.organization
# 0         None    By Jeannette Catsoulis                None
# 1         None  By Elisabeth Vincentelli                None
# 2         None             By Brandon Yu                None
# 3         None            By Glenn Kenny                None
# 4         None         By Manohla Dargis                None
#
# [5 rows x 30 columns]

# %%
# Export data to CSV without the index
